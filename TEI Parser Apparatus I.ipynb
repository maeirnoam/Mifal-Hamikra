# %%
import xml.etree.ElementTree as ET
import re
import pandas as pd
import unicodedata
from docx import Document
from lxml import etree
import zipfile
import os
from win32com import client

# %%
from lxml import etree
import re

def convert_custom_xml_to_tei(input_file, output_file, appid=1):
    """ Main function: Converts APPI_CH_01.xml into TEI format. """
    
    # Define TEI and XML namespaces
    tei_ns = "http://www.tei-c.org/ns/1.0"
    xml_ns = "http://www.w3.org/XML/1998/namespace"

    # Parse input XML
    tree = etree.parse(input_file)
    root = tree.getroot()

    # Create TEI root
    tei = etree.Element(f"{{{tei_ns}}}TEI", nsmap={None: tei_ns, "xml": xml_ns})
    
    # Add TEI Header
    teiHeader = etree.SubElement(tei, f"{{{tei_ns}}}teiHeader")
    fileDesc = etree.SubElement(teiHeader, f"{{{tei_ns}}}fileDesc")
    titleStmt = etree.SubElement(fileDesc, f"{{{tei_ns}}}titleStmt")
    title = etree.SubElement(titleStmt, f"{{{tei_ns}}}title")
    title.text = "Converted TEI Document"
    pubStmt = etree.SubElement(fileDesc, f"{{{tei_ns}}}publicationStmt")
    pubStmt.text = "Generated from custom XML"
    sourceDesc = etree.SubElement(fileDesc, f"{{{tei_ns}}}sourceDesc")
    sourceDesc.text = "Converted from APPI_CH_01.xml"

    # Add <text> structure
    text = etree.SubElement(tei, f"{{{tei_ns}}}text")
    body = etree.SubElement(text, f"{{{tei_ns}}}body")
    listApp = etree.SubElement(body, f"{{{tei_ns}}}listApp")

    # Witness and Sigla Sections
    listWit = etree.SubElement(tei, f"{{{tei_ns}}}listWit")
    listPrefixDef = etree.SubElement(tei, f"{{{tei_ns}}}listPrefixDef")

    # Process each entry in the XML
    for entry in root.findall(".//Entry"):
        process_entry(entry, listApp, listWit, listPrefixDef, tei_ns, xml_ns, appid)

    # Save the TEI XML
    tree = etree.ElementTree(tei)
    tree.write(output_file, pretty_print=True, xml_declaration=True, encoding="UTF-8")


def process_entry(entry, listApp, listWit, listPrefixDef, tei_ns, xml_ns, appid):
    """ Processes an individual <Entry> and converts it into <app>. """
    
    entry_id = entry.get("ID")  # Unique ID for the entry

    # ✅ Find the <Chapter> parent
    chapter_element = entry
    while chapter_element is not None and chapter_element.tag != "Chapter":
        chapter_element = chapter_element.getparent()

    # ✅ Extract "Number" attribute safely from <Chapter>
    chapter = chapter_element.get("Number") if chapter_element is not None else "unknown_chap"

    # ✅ Extract <Verse> information from **nested** structure
    verse_element = entry.find(".//Verse/Verse")  # ✅ Extracts inner <Verse>
    verse = verse_element.text.strip() if verse_element is not None else "unknown_verse"

    verse_from = entry.findtext(".//From_verse")  # ✅ Ensure correct placement
    verse_to = entry.findtext(".//To_verse")  # ✅ Ensure correct placement

    # ✅ Build XML ID with range support
    if verse_from and verse_to:
        app_id = f"app{appid}-{chapter}-{verse_from}-{verse_to}-{entry_id}"
    else:
        app_id = f"app{appid}-{chapter}-{verse}-{entry_id}"

    # ✅ Set attributes
    app_attributes = {f"{{{xml_ns}}}id": app_id}
    if verse_from:
        app_attributes["from"] = verse_from
    if verse_to:
        app_attributes["to"] = verse_to

    # ✅ Create <app> element
    app = etree.SubElement(listApp, f"{{{tei_ns}}}app", app_attributes)

    # Add components
    add_lemmas(entry, app, tei_ns)
    add_readings(entry, app, listWit, listPrefixDef, tei_ns, xml_ns)
    add_cross_references(entry, app, tei_ns, chapter, verse, entry_id)  # ✅ Now `verse` is correctly assigned
    add_import_note(entry, app, tei_ns)


def add_cross_references(entry, app, tei_ns, chapter, verse, entry_number):
    """ Converts cross-references into TEI format with proper ID structure. """
    
    roman_numerals = {
        "I": "1", "II": "2", "III": "3", "IV": "4", "V": "5", "VI": "6"
    }

    cross_refs = entry.findall(".//Cross_references/Item")
    
    if cross_refs:
        listRef = etree.SubElement(app, f"{{{tei_ns}}}listRef")
        
        for ref in cross_refs:
            ref_text = ref.text.strip()
            
            # ✅ Convert Roman numeral to app ID format
            ref_appid = roman_numerals.get(ref_text, ref_text)  # Default to text if no match
            
            # ✅ Create <ref> element with correct target
            ref_el = etree.SubElement(
                listRef, f"{{{tei_ns}}}ref",
                {"target": f"app{ref_appid}-{chapter}-{verse}-{entry_number}"}
            )
            ref_el.text = ref_text  # Keep the original Roman numeral for display

    
    
    
def add_lemmas(entry, app, tei_ns):
    """ Extracts and formats lemmas, including handling ranges. """
    lemma_section = entry.find("Lemma")
    
    if lemma_section is not None:
        from_lemmas = lemma_section.findall("From/Detail")
        to_lemmas = lemma_section.findall("To/Detail")

        if from_lemmas and to_lemmas:
            lemGrp = etree.SubElement(app, f"{{{tei_ns}}}lemGrp", {"type": "range"})

            from_grp = etree.SubElement(lemGrp, f"{{{tei_ns}}}lemGrp", {"type": "from"})
            from_lem = etree.SubElement(from_grp, f"{{{tei_ns}}}lem")
            for lemma in from_lemmas:
                text = lemma.text
                if text:
                    etree.SubElement(from_lem, f"{{{tei_ns}}}w").text = text

            to_grp = etree.SubElement(lemGrp, f"{{{tei_ns}}}lemGrp", {"type": "to"})
            to_lem = etree.SubElement(to_grp, f"{{{tei_ns}}}lem")
            for lemma in to_lemmas:
                text = lemma.text
                if text:
                    etree.SubElement(to_lem, f"{{{tei_ns}}}w").text = text

        else:
            lem = etree.SubElement(app, f"{{{tei_ns}}}lem")
            for detail in lemma_section.findall("Detail"):
                text = detail.text
                if text:
                    etree.SubElement(lem, f"{{{tei_ns}}}w").text = text


def add_readings(entry, app, listWit, listPrefixDef, tei_ns, xml_ns):
    """ Processes readings, witness mapping, and sigla handling. """
    rdgGrp = etree.SubElement(app, f"{{{tei_ns}}}rdgGrp", {"type": "variant"})

    for reading in entry.findall(".//Reading"):
        rdg = etree.SubElement(rdgGrp, f"{{{tei_ns}}}rdg")

        text, sigla_ref = handle_sigla(reading.text, listPrefixDef, tei_ns, xml_ns)
        if sigla_ref:
            rdg.set("ref", sigla_ref)

        seg = etree.SubElement(rdg, f"{{{tei_ns}}}seg")
        seg.text = text

        
def add_import_note(entry, app, tei_ns):
    """ Extracts footnotes or commentary and adds them as <note type='import'> inside <app>. """
    
    footnote_text = entry.findtext(".//Footnotes/Footnote")  # Find footnote text if available
    
    if footnote_text:
        note_import = etree.SubElement(app, f"{{{tei_ns}}}note", {"type": "import"})
        note_import.text = footnote_text
        

def handle_sigla(text, listPrefixDef, tei_ns, xml_ns):
    """ Detects, removes, and maps sigla. """
    sigla_map = {"!": "uncertain", "+": "addition", ">": "omission"}
    sigla_refs = []

    for sig, desc in sigla_map.items():
        if sig in text:
            sig_id = f"sig-{desc}"
            if not listPrefixDef.xpath(f"//tei:prefixDef[@xml:id='{sig_id}']", namespaces={"tei": tei_ns}):
                prefix_def = etree.SubElement(listPrefixDef, f"{{{tei_ns}}}prefixDef", {f"{{{xml_ns}}}id": sig_id})
                etree.SubElement(prefix_def, f"{{{tei_ns}}}prefix").text = sig
                etree.SubElement(prefix_def, f"{{{tei_ns}}}desc").text = desc
            sigla_refs.append(f"#{sig_id}")
            text = text.replace(sig, "").strip()

    return text, " ".join(sigla_refs) if sigla_refs else None

# %%
# Run the conversion with appid = 1
input_xml = "flattened_verse_with_to_check.xml"
output_tei = "app1_tei.xml"
convert_custom_xml_to_tei(input_xml, output_tei, appid=1)

# %%
######## custome-xml parser

# %%
def process_footnotes(docx_path):
    # Dictionary to store footnote data
    footnotes_dict = {}

    # Step 1: Extract the footnotes XML from the .docx file
    with zipfile.ZipFile(docx_path, 'r') as docx:
        # Look for footnotes XML part
        if 'word/footnotes.xml' in docx.namelist():
            footnote_xml = docx.read('word/footnotes.xml').decode('utf-8')
        else:
            print("No footnotes.xml found in this document.")
            return footnotes_dict

    # Step 2: Parse the footnote XML and store in dictionary
    if footnote_xml:
        root = ET.fromstring(footnote_xml)
        namespaces = {'w': 'http://schemas.openxmlformats.org/wordprocessingml/2006/main'}
        
        non_blank_count = 1  # Start counting footnotes for non-blank lines only

        for footnote in root.findall('w:footnote', namespaces):
            footnote_text = ""

            # Extract each run's text, font, and superscript/subscript information in the footnote
            for run in footnote.findall('.//w:r', namespaces):
                text_elem = run.find('w:t', namespaces)
                font_elem = run.find('.//w:rPr//w:rFonts', namespaces)
                vert_align_elem = run.find('.//w:rPr//w:vertAlign', namespaces)

                if text_elem is not None:
                    text = text_elem.text
                    font = font_elem.get(f'{{{namespaces["w"]}}}ascii') if font_elem is not None else "Unknown"

                    # Check for superscript or subscript alignment
                    if vert_align_elem is not None:
                        align_val = vert_align_elem.get(f'{{{namespaces["w"]}}}val')
                        if align_val == "superscript":
                            text = f"<superscript {text} >"
                        elif align_val == "subscript":
                            text = f"<subscript {text} >"

                    # Wrap the text in <specialFont ...> if it’s in the special font
                    if font == "HUBPSigla":  # Replace with your actual font name if different
                        footnote_text += f"<specialFont {text} >"
                    else:
                        footnote_text += text

            # Only store non-blank footnotes in the dictionary
            if footnote_text.strip():  # Check if footnote text is non-blank
                footnotes_dict[f'footnote-{non_blank_count}'] = footnote_text.strip()
                non_blank_count += 1  # Increment count only for non-blank footnotes

    return footnotes_dict


def process_main_text_with_normalized_footnotes(docx_path):
    document_xml = None

    # Step 1: Extract and normalize valid footnotes
    normalized_footnotes = {}  # Map of normalized ID -> actual footnote text
    id_mapping = {}  # Map of actual ID -> normalized ID
    with zipfile.ZipFile(docx_path, 'r') as docx:
        if 'word/footnotes.xml' in docx.namelist():
            footnotes_xml = docx.read('word/footnotes.xml').decode('utf-8')
            root = ET.fromstring(footnotes_xml)
            namespaces = {'w': 'http://schemas.openxmlformats.org/wordprocessingml/2006/main'}

            normalized_id = 1
            for footnote in root.findall('w:footnote', namespaces):
                actual_id = int(footnote.get(f'{{{namespaces["w"]}}}id'))
                footnote_type = footnote.get(f'{{{namespaces["w"]}}}type', 'regular')
                text = ''.join(run.text or '' for run in footnote.findall('.//w:t', namespaces))

                # Include only regular footnotes with valid IDs
                if actual_id > 0 and footnote_type == 'regular':
                    normalized_footnotes[normalized_id] = text.strip()
                    id_mapping[actual_id] = normalized_id
                    normalized_id += 1

    # Step 2: Process `document.xml` with normalized IDs
    with zipfile.ZipFile(docx_path, 'r') as docx:
        if 'word/document.xml' in docx.namelist():
            document_xml = docx.read('word/document.xml').decode('utf-8')

    namespaces = {'w': 'http://schemas.openxmlformats.org/wordprocessingml/2006/main'}
    main_text_dict = {}

    if document_xml:
        document_root = ET.fromstring(document_xml)
        title_and_chapter = ""
        first_row_processed = False

        for i, paragraph in enumerate(document_root.findall('.//w:p', namespaces), start=1):
            paragraph_text = ""
            if not first_row_processed:
                title_and_chapter = ''.join(
                    run.find('w:t', namespaces).text or ''
                    for run in paragraph.findall('.//w:r', namespaces)
                    if run.find('w:t', namespaces) is not None
                ).strip()
                first_row_processed = True
                continue

            if not any(run.find('w:t', namespaces) is not None for run in paragraph.findall('.//w:r', namespaces)):
                continue

            app_id = f"app-{i-2}"
            combined_special_fonts = []  # To collect specialFont text for merging

            for run in paragraph.findall('.//w:r', namespaces):
                text_elem = run.find('w:t', namespaces)
                footnote_ref = run.find('.//w:footnoteReference', namespaces)
                font_elem = run.find('.//w:rPr//w:rFonts', namespaces)
                vert_align_elem = run.find('.//w:rPr//w:vertAlign', namespaces)

                if text_elem is not None:
                    text = text_elem.text
                    font = font_elem.get(f'{{{namespaces["w"]}}}ascii') if font_elem is not None else "Unknown"

                    # Check for superscript or subscript alignment
                    if vert_align_elem is not None:
                        align_val = vert_align_elem.get(f'{{{namespaces["w"]}}}val')
                        if align_val == "superscript":
                            text = f"<superscript {text}>"
                        elif align_val == "subscript":
                            text = f"<subscript {text}>"

                    # Collect special font text instead of appending immediately
                    if font == "HUBPSigla":  # Replace with your actual font name if different
                        combined_special_fonts.append(text)
                    else:
                        # If there's non-specialFont text, finalize combined_special_fonts
                        if combined_special_fonts:
                            paragraph_text += f"<specialFont {''.join(combined_special_fonts)}>"
                            combined_special_fonts = []  # Reset buffer
                        paragraph_text += text

                elif footnote_ref is not None:
                    actual_id = int(footnote_ref.get(f'{{{namespaces["w"]}}}id'))
                    # Use the normalized ID if the actual ID exists in the mapping
                    if actual_id in id_mapping:
                        normalized_id = id_mapping[actual_id]
                        paragraph_text += f"<ref {normalized_id}>"

            # Finalize any remaining combined_special_fonts
            if combined_special_fonts:
                paragraph_text += f"<specialFont {''.join(combined_special_fonts)}>"

            main_text_dict[app_id] = paragraph_text

    return {
        'title': title_and_chapter.split()[0],
        'chapter': title_and_chapter.split()[1],
        'content': main_text_dict
    }

def split_full_entry(text):
    """
    Splits a full entry into lemma and entry. Processes sequences of <subscript> tags
    into a single concatenated <subscript> tag.
    """

    # Split at the first occurrence of ']'
    sliced_entry = text.split(sep=']', maxsplit=1)
    
    # Initialize `lemma` and `entry`
    lemma = sliced_entry[0]
    entry = sliced_entry[1] if len(sliced_entry) > 1 else ""

    # Process subscript sequences in the entry
    subscript_pattern = r'(?:<subscript\s*([^>]+)>)+'
    
    def merge_subscripts(match):
        subscripts = match.group(0)
        combined_content = ''.join(re.findall(r'<subscript\s*([^>]+)>', subscripts))
        return f'<subscript {combined_content}>'

    entry = re.sub(subscript_pattern, merge_subscripts, entry)

    # Check if a superscript follows immediately after the `]`
    superscript_pattern = re.compile(r'^\s*<ref\s*([^>]+)>')
    match = superscript_pattern.match(entry)
    lemma_dict = {'lemma': lemma}
    if match:
        # Append the superscript to the lemma
        lemma_dict.update({'ref': match.group(0)})
        
        # Remove the superscript from the start of the entry
        entry = entry[len(match.group(0)):].strip()

    # Check for specific patterns in the lemma
    to_check_patterns = [
        r'<specialFont\s*<subscript\s*v>>',  # Pattern for subscript v
        r'<specialFont\s*,'                 # Pattern for specialFont ,
        r'<specialFont\s*v'
    ]
    if any(re.search(pattern, lemma) for pattern in to_check_patterns):
        lemma_dict['to_check'] = True  # Add "to_check" flag if any pattern matches
        
    return lemma_dict, entry


def extract_initial_sigla(reading):
       
    # Pattern to match one or more sigla at the start of the reading
    sigla_pattern = re.compile(r'^[\+\>\~]+')
    
    # Dictionary to store extracted sigla and cleaned reading
    result = {
        'sigla': "",
        'cleaned_reading': reading.strip()  # Initialize cleaned reading as the full reading
    }
    
    # Find initial sigla if present
    match = sigla_pattern.match(reading)
    if match:
        # Extract sigla and set them in the result dictionary
        result['sigla'] = match.group(0)
        
        # Remove the matched sigla from the beginning of the reading
        result['cleaned_reading'] = reading[len(result['sigla']):].strip()

    return result

def extract_cross_references(reading):
    # Pattern to find all <subscript ...> tags
    subscript_pattern = re.compile(r'<subscript\s*([^>]+)>')
    
    # List to store cross-references and clean reading with subscripts
    cross_references = []
    cleaned_reading = reading

    # Define a pattern to identify Roman numerals with only I's and V's (e.g., I, II, III, IV, V, VI, VII, VIII)
    roman_numeral_pattern = re.compile(r'[IV\s]{0,}$')

    # Process each subscript match
    matches = subscript_pattern.findall(reading)
    for match in matches:
        if roman_numeral_pattern.match(match):
            for item in match.split():
                cross_references.append(item)  # Store as cross-reference if it's a valid Roman numeral with I's and V's
            cleaned_reading = cleaned_reading.replace(f"<subscript {match}>", "")
        
    # Remove duplicates in cross-references and retain order
    unique_references = sorted(set(cross_references), key=cross_references.index)
    
    # Final cleanup of <subscript ...> tags for Roman numerals in cleaned reading
#     cleaned_reading = roman_numeral_pattern.sub('', cleaned_reading).strip()

    return {
        'cross_references': unique_references,
        'reading': cleaned_reading
    }


def parse_and_classify_entry(entry):
    # Define splitting characters with classifications
    splitters = {
        '|': 'additional_variant',
        '=': 'synonymous_variant',
        ',': 'related_variant',
        '<specialFont +>': 'similar_variant'
    }
    
    special_font_pattern = re.compile(r'<specialFont\s*([^>+]+)>')

    
    # Preprocess: Replace <specialFont ...> with placeholders
    special_font_placeholders = []
    def replace_special_font(match):
        special_font_placeholders.append(match.group(0))  # Store the full tag
        return f"__SPECIAL_FONT_{len(special_font_placeholders) - 1}__"

    entry = special_font_pattern.sub(replace_special_font, entry)

    # Compile regex to split by any of the splitters
    splitter_pattern = re.compile(r'(\||=|<specialFont\s\+>|,)')

    # List to store parsed entries with classifications
    parsed_entries = []

    # Split the entry by the main split characters, keeping split characters separate
    parts = splitter_pattern.split(entry)

    # Initialize a default classification for the first part
    current_classification = "variant"

    # Process each part separately
    for part in parts:
        part = part.strip()  # Remove leading/trailing whitespace
        
        # Skip if the part is a splitter, set classification for the next part
        if part in splitters:
            current_classification = splitters[part]
            continue  # Skip to the next part

        # Restore <specialFont ...> tags in this part
        for i, placeholder in enumerate(special_font_placeholders):
            part = part.replace(f"__SPECIAL_FONT_{i}__", placeholder)

        # Initialize dictionaries to store witnesses, reading, classification, and cross-references
        entry_data = {
            'classification': current_classification,
            'witnesses': [],
            'reading': "",
            'cross_references': [],
            'sigla': ""
        }
                
        combined_witnesses = []  # Collect all witness contents

        i = 0
        while i < len(part):
            # Match <specialFont ...>
            special_font_match = special_font_pattern.match(part, i)
            if special_font_match:
                combined_witnesses.append(special_font_match.group(1))  # Collect witness content
                i = special_font_match.end()
            else:
                # Once done collecting witnesses, finalize the <specialFont> wrapper
                if combined_witnesses:
                    combined_witness_text = ''.join(combined_witnesses)
                    entry_data['witnesses'].append(f"<specialFont {combined_witness_text}>")
                    combined_witnesses = []  # Reset the buffer
                # Anything else becomes the reading
                entry_data['reading'] = part[i:].strip()
                break

        # If any witnesses remain in the buffer, finalize them
        if combined_witnesses:
            combined_witness_text = ''.join(combined_witnesses)
            entry_data['witnesses'].append(f"<specialFont {combined_witness_text}>")
        # process witnesses
        entry_data['witnesses'] = process_combined_witnesses(entry_data['witnesses'])
        
        # Extract cross-references from the reading
        result = extract_cross_references(entry_data['reading'])
        entry_data['cross_references'] = result['cross_references']
        entry_data['reading'] = result['reading']  # Cleaned reading without <subscript ...> tags

        
        sigla_result = extract_initial_sigla(entry_data['reading'])
        entry_data['sigla'] = sigla_result['sigla']
        entry_data['reading'] = sigla_result['cleaned_reading']  # Cleaned reading without sigla

        # Add entry data to the parsed entries list
        parsed_entries.append(entry_data)

    return parsed_entries


def split_and_process_witnesses(witness_text):
    """
    Split witnesses from text, attaching 'h' or '-' to the preceding witness.
    """
    processed_witnesses = []
    
    for char in witness_text:
        if char in ['h', '-'] and processed_witnesses:
            # Attach 'h' or '-' to the last witness
            processed_witnesses[-1] += char
        else:
            # Start a new witness
            processed_witnesses.append(char)

    return processed_witnesses


def process_combined_witnesses(witnesses):
    """
    Process combined witnesses, splitting and wrapping them in <specialFont> tags.
    """
    processed_witnesses = []

    for witness in witnesses:
        # Extract the content within <specialFont>
        match = re.match(r'<specialFont\s*(.*?)>', witness)
        if match:
            content = match.group(1)
            # Split the content into individual witnesses
            split_witnesses = split_and_process_witnesses(content)
            # Wrap each witness back in <specialFont> tags
            processed_witnesses.extend([f"<specialFont {w}>" for w in split_witnesses])
        else:
            # If no <specialFont>, just append as-is
            processed_witnesses.append(witness)

    return processed_witnesses

# %%
# def split_verse_lemma(entry_text, previous_verse=None):
#     """
#     Splits the entry into verse and lemma. If a verse range is found, splits into from_verse and to_verse.
#     If no verse is found, it uses the previous entry's verse.
#     Adds a `to_check` flag to the lemma if specific patterns are detected.
#     """
#     # Regex to match verse patterns: digits optionally followed by a dash or range
#     pattern = re.match(r'^(\d+(?:–\d+)?)(.*)$', entry_text.strip())
#     if pattern:
#         verse_part = pattern.group(1).strip()  # Extract verse
#         lemma = pattern.group(2).strip()  # Extract lemma

#         # Check if the verse contains a range
#         if '–' in verse_part:
#             from_verse, to_verse = map(str.strip, verse_part.split('–', 1))
#             verse = {'from_verse': from_verse, 'to_verse': to_verse}
#         else:
#             verse = {'verse': verse_part}  # Single verse
#     else:
#         verse = {'verse': previous_verse}  # Use previous verse if no verse found
#         lemma = entry_text.strip()  # Assume the rest is lemma

#     # Check for specific patterns in the lemma
#     to_check_patterns = [
#         r'<specialFont\s*<subscript\s*v>>',  # Pattern for subscript v
#         r'<specialFont\s*,>'                 # Pattern for specialFont comma
#     ]
#     to_check = any(re.search(pattern, lemma) for pattern in to_check_patterns)

#     # Return the structured data, including `to_check` if applicable
#     return {
#         'verse': verse,
#         'lemma': {'text': lemma, 'to_check': to_check} if to_check else lemma
#     }

def split_verse_lemma(lemma_dict, previous_verse=None):
    """
    Splits the entry into verse and lemma. If a verse range is found, splits into from_verse and to_verse.
    If no verse is found, it uses the previous entry's verse.
    Also carries `ref` and `to_check` from the lemma if present.
    """
    # Extract text and ref from the input dictionary
    lemma_text = lemma_dict.get("lemma", "")
    ref = lemma_dict.get("ref", None)

    # Regex to match verse patterns: digits optionally followed by a dash or range
    pattern = re.match(r'^(\d+(?:–\d+)?)(.*)$', lemma_text.strip())
    if pattern:
        verse_part = pattern.group(1).strip()  # Extract verse
        lemma_text = pattern.group(2).strip()  # Extract lemma

        # Check if the verse contains a range
        if '–' in verse_part:
            from_verse, to_verse = map(str.strip, verse_part.split('–', 1))
            verse = {'from_verse': from_verse, 'to_verse': to_verse}
        else:
            verse = {'verse': verse_part}  # Single verse
    else:
        verse = {'verse': previous_verse}  # Use previous verse if no verse found
        lemma_text = lemma_text.strip()  # Assume the rest is lemma

    # Check for specific patterns in the lemma for `to_check`
    to_check_patterns = [
        r'<specialFont\s*<subscript\s*v>>',  # Pattern for subscript v
        r'<specialFont\s*,>',               # Pattern for specialFont comma
        r'<specialFont\s*v>',               # Standalone specialFont with "v"
        r'<specialFont\s*[^>]+>',           # General case for specialFont with content
    ]
    to_check = any(re.search(pattern, lemma_text) for pattern in to_check_patterns)

    # Return structured data, including `ref` and `to_check` if applicable
    return {
        'verse': verse,
        'lemma': [{'text': lemma_text, 'to_check': to_check, 'ref': ref}]
    }


def process_lemma_specific_range(lemma_text):
    """
    Process a lemma with one or multiple specific ranges (...).
    Handles cases like 'word ... word ... word ... word'.
    """
    # Split the lemma by '...'
    parts = [part.strip() for part in lemma_text.split('...') if part.strip()]

    # Handle cases with multiple specific ranges
    processed_ranges = []
    for i, part in enumerate(parts):
        if i == 0:
            # The first part is the start
            processed_ranges.append({'tag': 'start lemma', 'content': part})
        elif i == len(parts) - 1:
            # The last part is the end
            processed_ranges.append({'tag': 'end lemma', 'content': part})
        else:
            # Intermediate parts are tagged as middle ranges
            processed_ranges.append({'tag': f'middle lemma {i}', 'content': part})

    # Return the processed range structure
    return {
        'type': 'specific_range',
        'parts': processed_ranges
    }

def process_lemma_range(lemma_text):
    """
    Process a lemma with a range (–).
    """
    parts = lemma_text.split('–', 1)
    part_from = parts[0].strip()
    part_to = parts[1].strip()

    return {
        'type': 'full_range',
        'from': part_from,
        'to': part_to
    }

def process_lemma_transposition(lemma_text):
    """
    Process a lemma with a transposition (~).
    """
    parts = lemma_text.split('~', 1)
    part_a = parts[0].strip()
    part_b = parts[1].strip()

    return {
        'type': 'transposition',
        'parts': {
            'a': process_lemma(part_a),
            'b': process_lemma(part_b)
        }
    }

def process_lemma_lex(lemma_text):
    """
    Process a lemma containing 'lex'.
    Removes 'lex' (as a whole word) and processes the remainder.
    """
    # Remove the first occurrence of 'lex' and optional trailing punctuation (e.g., ':', '-', '–', or spaces)
    cleaned_text = re.sub(r'\blex\b[\s:–-]*', '', lemma_text, count=1, flags=re.IGNORECASE)

    return {
        'type': 'lex',
        'text': cleaned_text.strip()
    }



def split_k_q_lemmas(lemma_text): ### check this function. maybe use replace with regex instead of match
    """
    Splits lemmas prefixed by k and q (e.g., 'k עינתם / q עוֹנֹתם')
    into distinct lemmas with their respective tags, dropping k/q prefixes.
    """
    # Regex to match prefixed lemmas and split them
    pattern = r'\b[kq]\s+([^\s/]+)\s*/\s*\b[kq]\s+([^\s]+)'
    match = re.match(pattern, lemma_text)

    if match:
        lemma_k = match.group(1).strip()  # Extract the lemma content after 'k'
        lemma_q = match.group(2).strip()  # Extract the lemma content after 'q'

        return [
            {'tag': 'lemma_k', 'content': lemma_k},
            {'tag': 'lemma_q', 'content': lemma_q}
        ]

    # If no match, return the lemma as-is
    return [{'tag': 'lemma', 'content': lemma_text}]


def process_lemma(lemma_text):
    """
    Process the lemma string. Checks for transposition, range, or specific range
    and delegates to specialized functions. If none found, processes individual lemmas.
    """
    if not lemma_text:
        return None  # Return if lemma is empty
    
    if '/' in lemma_text and re.search(r'\b[kq]\s', lemma_text):
        return split_k_q_lemmas(lemma_text)
    elif '~' in lemma_text:
        return process_lemma_transposition(lemma_text)
    elif '–' in lemma_text:
        return process_lemma_range(lemma_text)
    elif '...' in lemma_text:
        return process_lemma_specific_range(lemma_text)
    elif 'lex' in lemma_text:
        return process_lemma_lex(lemma_text)

    # Default: Process individual lemmas
    return process_individual_lemma(lemma_text)


def process_individual_lemma(lemma_dict):
    """
    Process individual lemmas, handling parentheses, concatenating multiple superscripts
    into a single number if present, and constructing `full_lemma` where appropriate.
    If a `to_check` flag is already present in the lemma_dict, return it unchanged.
    """
    # If `to_check` is present, return the dictionary unchanged
    if isinstance(lemma_dict, dict) and lemma_dict.get("to_check", False):
        return [lemma_dict]

    individual_lemma = lemma_dict.get('lemma', '') if isinstance(lemma_dict, dict) else lemma_dict

    # Regex to match words, parentheses, and superscripts
    lemma_regex = r'([^\s<\(\)]+|\([^\)]+\)|<superscript\s*[^>]+>|>|\s+)'
    superscript_regex = r'<superscript\s*([^>]+)>'

    matches = re.findall(lemma_regex, individual_lemma)

    processed_lemmas = []
    combined_parenthesis_content = ""
    inside_parentheses = False
    outside_parts = []  # Track parts outside parentheses
    inside_parts = []  # Track parts inside parentheses
    has_split_lemma = False  # Flag for split lemmas
    lemma_counter = 1  # Counter for normal lemmas
    parenthesis_first = False  # Flag to check if parentheses are first

    for i, word in enumerate(matches):
        if word.startswith("(") and not word.endswith(")"):
            # Start a parenthetical group
            inside_parentheses = True
            combined_parenthesis_content = word
            has_split_lemma = True
            if i == 0:
                parenthesis_first = True
        elif word.endswith(")") and inside_parentheses:
            # End a parenthetical group
            inside_parentheses = False
            combined_parenthesis_content += f" {word}"
            processed_lemmas.append({'tag': 'parenthesis', 'content': combined_parenthesis_content})
            inside_parts.append(combined_parenthesis_content[1:-1])  # Content inside parentheses
            combined_parenthesis_content = ""
        elif inside_parentheses:
            # Inside a parenthetical group
            combined_parenthesis_content += f" {word}"
        elif word.startswith("(") and word.endswith(")"):
            # Complete parenthetical group
            processed_lemmas.append({'tag': 'parenthesis', 'content': word})
            inside_parts.append(word[1:-1])  # Content inside parentheses
            has_split_lemma = True
            if i == 0:
                parenthesis_first = True
        elif word.startswith("<superscript"):
            # Handle superscripts
            if processed_lemmas and 'content' in processed_lemmas[-1]:
                current_lemma = processed_lemmas[-1]
                superscript_values = re.findall(superscript_regex, word)
                if 'numbers' not in current_lemma:
                    current_lemma['numbers'] = ''.join(superscript_values)
                else:
                    current_lemma['numbers'] += ''.join(superscript_values)
        elif word.strip():
            # Normal word processing
            lemma_dict = {'tag': f'lemma{lemma_counter}', 'content': word}
            processed_lemmas.append(lemma_dict)
            lemma_counter += 1
            outside_parts.append(word)

    # If parentheses remain open, finalize them
    if inside_parentheses and combined_parenthesis_content:
        processed_lemmas.append({'tag': 'parenthesis', 'content': combined_parenthesis_content})
        inside_parts.append(combined_parenthesis_content[1:])  # Remaining content without leading '('

    # Add `full_lemma` if necessary
    if has_split_lemma and outside_parts and inside_parts:
        # Concatenate inside and outside parts based on order
        if parenthesis_first:
            full_lemma_content = ''.join(inside_parts + outside_parts).strip()
        else:
            full_lemma_content = ''.join(outside_parts + inside_parts).strip()

        # Only create `full_lemma` if parentheses are part of a split lemma
        if len(outside_parts) > 0 and len(inside_parts) == 1 and ' ' not in inside_parts[0]:
            processed_lemmas.append({'tag': 'full_lemma', 'content': full_lemma_content})

    return processed_lemmas

# %%
import os
import pandas as pd
from docx import Document
import zipfile
import xml.etree.ElementTree as ET
import re
import unicodedata
from lxml import etree
from win32com import client


def process_docx_files(folder_path):
    # Initialize an empty list to collect data for each file
    data = []

    # Iterate over each .docx file in the folder
    for filename in sorted(os.listdir(folder_path)):
        if filename.endswith('.docx'):
            if filename.startswith('~$'):
                continue  # Skip temporary files
            docx_path = os.path.join(folder_path, filename)
            
            # Extract main text and footnotes
            main_text_data = process_main_text_with_normalized_footnotes(docx_path)
            footnotes_data = process_footnotes(docx_path)
            
            # Extract title and chapter from main text data
            title = main_text_data.get('title', 'Unknown Title')
            chapter = main_text_data.get('chapter', 'Unknown Chapter')
            
            # Append to data list with structured dictionary
            data.append({
                'Title': title,
                'Chapter': int(chapter),
                'Main Text': main_text_data.get('content', {}),
                'Footnotes': footnotes_data
            })

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(data).sort_values(by=['Title', 'Chapter']).reset_index(drop=True)
    return df

# Folder path containing .docx files
folder_path = 'Hosea.App.1'

# Process and get DataFrame
df = process_docx_files(folder_path)

# Display the DataFrame
df.head()
# Out:
#    Title  Chapter                                          Main Text  \
# 0  Hosea        1  {'app-1': '1 יותם אחז יחזקיה] <specialFont ][>...
# 1  Hosea        2  {'app-1': '1–2] <specialFont ]*> 1<subscript 1...
# 2  Hosea        3  {'app-1': '1 אהב] <specialFont ]*h> <specialFo...
# 3  Hosea        4  {'app-0': '1 (ל)יהוה] <specialFont ]h> div', '...
# 4  Hosea        5  {'app-1': '1 לְמצפָּה] <specialFont ]> τῇ σκοπ...
#
#                                            Footnotes
# 0  {'footnote-1': 'cf app Mic 1<subscript 1 >', '...
# 1  {'footnote-1': '“there”, for במקום אשר ... שם ...
# 2  {'footnote-1': 'voc אֹהֶבֶת רָע; cf Mic 3<subs...
# 3  {'footnote-1': '“(in) the fear of (God)”, theo...
# 4  {'footnote-1': '“to the lookout”, similarly <s...

# %%
df[:1]['Main Text'].values[0]
# Out:
# {'app-1': '1 יותם אחז יחזקיה] <specialFont ][> <specialFont &>',
#  'app-2': 'מלכי] <specialFont ]h> num<subscript II><ref 1>',
#  'app-3': '2 דִּבֶּר] <specialFont ]> λόγου<ref 2> = <specialFont [T>',
#  'app-4': 'ב(הושע)] <specialFont ]h> πρός<ref 3> <specialFont +> <specialFont [>ܕܗܘܐ ܥܠ<ref 4>',
#  'app-5': 'ו(יאמר)] <specialFont ]h[> >',
#  'app-6': 'לֵךְ] <specialFont ]h> ><subscript II>',
#  'app-7': '3 ויקח] <specialFont [> + ܠܗ<ref 5>',
#  'app-8': 'לו] <specialFont ]h*-> ><subscript II III><subscript  IV><ref 6>',
#  'app-9': '4 יהוא] <specialFont ]h> Ιουδα<ref 7>',
#  'app-10': '(ו)הִשְׁבַּתִּי] <specialFont ]-> ἀποστρέψω<ref 8>',
#  'app-11': 'בית<superscript 2>] <specialFont ]h*hT-> + prep<ref 9>',
#  'app-12': '5 והיה (ביום ההוא)] <specialFont [> ><ref 10>',
#  'app-13': '(ו)היה] <specialFont *> >',
#  'app-14': 'ההוא] <specialFont ]h> + dicit dominus<ref 11>',
#  'app-15': '6 עוד<superscript 1>] <specialFont *hT-> ><subscript II><subscript  III IV>',
#  'app-16': 'לו] <specialFont ]h> + κύριος<subscript II><ref 12> = <specialFont [>| <specialFont [> pron<ref 13>',
#  'app-17': 'נשׂא אשׂא] <specialFont ]> ἀντιτασσόμενος ἀντιτάξομαι<ref 14> | <specialFont *> oblivione obliviscar<ref 15> <specialFont +> <specialFont ~>',
#  'app-18': '7 בית] <specialFont ]> υἱούς<ref 16>',
#  'app-19': 'יהודה] <specialFont ]h> >',
#  'app-20': 'ולא] <specialFont ][> rep',
#  'app-21': '(ו)במלחמה] <specialFont ]-> + (οὐδὲ) ἐν ἅρμασιν<ref 17>',
#  'app-22': 'בסוסים] <specialFont ]*[> <specialFont &><subscript III><subscript  IV>',
#  'app-23': '8 ותהר] <specialFont ]-> + ἔτι<subscript II><ref 18> = <specialFont [>',
#  'app-24': 'ותלד] <specialFont ]h> + αὐτῷ<subscript IV><ref 19> = <specialFont *h>',
#  'app-25': '9 ויאמר] <specialFont ]h> + κύριος (αὐτῷ)<subscript II><ref 20> = <specialFont Th> <specialFont +> <specialFont [>',
#  'app-26': 'כי – עמי ~ ואנכי – לכם] <specialFont 9> ~',
#  'app-27': 'לכם] <specialFont ]h> + θεός<ref 21> = <specialFont *h> <specialFont + [h>'}

# %%
df['Footnotes'][:1].values
# Out:
# array([{'footnote-1': 'cf app Mic 1<subscript 1 >', 'footnote-2': '(a) voc דְּבַר (יהוה), formula, cf v<subscript 1 > 4<subscript 1 > et al; cf app 13<subscript 1 >; cf תחלת דִּבְרֵי Qoh 10<subscript 13 >; note seq; (b) noun דִּבֵּר, cf app Jer 5<subscript 13 > and Rabb Heb; cf gerund in <specialFont * > loquendi “of speaking”', 'footnote-3': '“to”; main evid, cf v<subscript 1 >', 'footnote-4': '“which was to”, ex v<subscript 1 >', 'footnote-5': '“for himself”, cf v<subscript 2 >', 'footnote-6': 'cf vv<subscript 6,8 >; contrast Hier 10<subscript 154 >', 'footnote-7': 'main evid; inner-Grk (בית יהודה common collocation), cf Hier 12<subscript 208−211 >', 'footnote-8': 'voc הֲשִׁבֹתִי, similarly app 2<subscript 13 > Ezek 7<subscript 24 >; for parall השיב//פקד cf 4<subscript 9 > 12<subscript 3 >; main evid <specialFont ]h ><subscript   >καταπαύσω (=<specialFont x >)', 'footnote-9': 'common formula השבית מן, cf e.g. Lev 26<subscript 6 > Jer 7<subscript 34 >', 'footnote-10': 'formulaic change, cf app Joel 4<subscript 18 > Mic 5<subscript 9 > et al', 'footnote-11': '“says the Lord”, formula (נאם יהוה), cf 2<subscript 18,23 > et al', 'footnote-12': '“the Lord”, cf v<subscript 4 >, app v<subscript 9 > (ויאמר)', 'footnote-13': '1sg, cf 3<subscript 1 >', 'footnote-14': '“opposing I shall oppose” (= <specialFont ] > 1Kgs 11<subscript 34 >); p etym <specialFont \\ > נשׁא“oppress, set against” (cf Ps 89<subscript 23 >), cf Obad <subscript 7 > הִשִּׁיאוּךָ <specialFont J > <specialFont ] > ἀντέστησάν σοι “they opposed you” (for interchange of ἀντιτάσσεσθαι “to oppose” / ἀνθίστασθαι “to stand against” cf <specialFont ]i > 4Macc 16<subscript 23 >); cf also Jer 49<subscript 16 > הִשִּׁיא = <specialFont ] > [29<subscript 17 >] ἐνεχείρησε “(it) attacked” (contrast etym <specialFont \\ >נשׂא<specialFont  ~9 > and <subscript p >Obad <subscript 3 > <specialFont ] >)', 'footnote-15': '“by forgetfulness I shall forget”, etym <specialFont \\ >נשׁה, contrast app Jer 23<subscript 39 >', 'footnote-16': '“sons (of)”, for בני/בית cf app Amos 1<subscript 5 > 3<subscript 1 > Zeph 1<subscript 8 >', 'footnote-17': 'p (ו)ברכב; common collocation, cf e.g. Ezek 26<subscript 7 > בסוס וברכב ובפרשים', 'footnote-18': '“again”, cf v<subscript 6 >', 'footnote-19': '“(to) him”, cf v<subscript 3 >', 'footnote-20': '“the Lord (to him)”, cf app v<subscript 6 > (לו); for <specialFont [ > pron cf n14', 'footnote-21': '“God”, cf e.g. Exod 6<subscript 7 > Lev 26<subscript 12 > Zech 8<subscript 8 >; note diverse word-order in <specialFont ]h >'}],
#       dtype=object)

# %%
df.to_json('App.1.FULL.json')

# %%
#processing trials

# %%
import re

def process_lemma(lemma_text):
    if not lemma_text:
        return {"type": None, "parts": []}

    # lex
    if re.search(r'\blex\b', lemma_text, flags=re.IGNORECASE):
        return process_lemma_lex(lemma_text)

    # k/q
    if '/' in lemma_text and re.search(r'\b[kq]\s', lemma_text):
        return process_lemma_kq(lemma_text)

    # transposition
    if '~' in lemma_text:
        return process_lemma_transposition(lemma_text)

    # specific range
    if '...' in lemma_text:
        return process_lemma_specific_range(lemma_text)

    # full range
    if '–' in lemma_text:
        return process_lemma_range(lemma_text)

    # fallback
    return {
        "type": 'Standard',
        "parts": [{
            "content": lemma_text,
            "detail": process_individual_lemma(lemma_text)
        }]
    }


def process_lemma_lex(lemma_text):
    cleaned = re.sub(r'\blex\b[\s:–-]*', '', lemma_text, count=1, flags=re.IGNORECASE)
    return {
        "type": "lex",
        "parts": [{
            "content": cleaned,
            "detail": process_individual_lemma(cleaned)
        }]
    }


def process_lemma_specific_range(lemma_text):
    # split into start/end
    start, end = map(str.strip, lemma_text.split('...', 1))
    return {
        "type": "specific_range",
        "parts": [
            {
                "tag": "start_lemma",
                "content": start,
                "detail": process_individual_lemma(start)
            },
            {
                "tag": "end_lemma",
                "content": end,
                "detail": process_individual_lemma(end)
            }
        ]
    }


def process_lemma_range(lemma_text):
    frm, to = map(str.strip, lemma_text.split('–', 1))
    return {
        "type": "full_range",
        "parts": [
            {
                "tag": "range_from",
                "content": frm,
                "detail": process_individual_lemma(frm)
            },
            {
                "tag": "range_to",
                "content": to,
                "detail": process_individual_lemma(to)
            }
        ]
    }


def process_lemma_transposition(lemma_text):
    a, b = map(str.strip, lemma_text.split('~', 1))
    return {
        "type": "transposition",
        "parts": [
            {
                "tag": "transposition_a",
                "content": a,
                "detail": process_individual_lemma(a)
            },
            {
                "tag": "transposition_b",
                "content": b,
                "detail": process_individual_lemma(b)
            }
        ]
    }


def process_lemma_kq(lemma_text):
    m = re.match(r'\b[kq]\s+([^\s/]+)\s*/\s*\b[kq]\s+([^\s]+)', lemma_text)
    if not m:
        # fallback single
        return {
            "type": "K\Q",
            "parts": [{
                "tag": "lemma",
                "content": lemma_text,
                "detail": process_individual_lemma(lemma_text)
            }]
        }
    k, q = m.group(1), m.group(2)
    return {
        "type": "K\Q",
        "parts": [
            {"tag": "lemma_k", "content": k, "detail": process_individual_lemma(k)},
            {"tag": "lemma_q", "content": q, "detail": process_individual_lemma(q)}
        ]
    }

# %%
def enrich_df_with_processed_lemmas(df):
    """
    Given a DataFrame with a 'Main Text' column (dict of entry_id → raw string),
    adds a 'ProcessedEntries' column where each row is a list of dicts:
      - EntryID
      - Verse      : the verse dict from split_verse_lemma
      - LemmaMeta  : original lemma metadata (text, to_check, ref)
      - ProcessedLemma : structured { type, parts } from process_lemma
      - EntryText  : the raw entry string
      - ClassifiedEntry (optional) : output of parse_and_classify_entry
      - ClassifyError   (optional) : error message if classification failed
    """
    processed_rows = []
    
    for idx, row in df.iterrows():
        main_text = row.get("Main Text", {})
        previous_verse = None
        row_entries = []
        
        if isinstance(main_text, dict):
            for entry_id, raw_value in main_text.items():
                try:
                    # 1) split out lemma text vs. entry text
                    lemma_block, entry_text = split_full_entry(raw_value)
                    
                    # 2) extract verse + carry-over
                    split = split_verse_lemma(lemma_block, previous_verse)
                    verse_info = split["verse"]
                    if verse_info.get("verse") or verse_info.get("to_verse"):
                        previous_verse = verse_info
                    
                    # 3) pull off the raw lemma metadata
                    lemma_meta = split["lemma"][0]
                    raw_lemma_text = lemma_meta["text"]
                    
                    # 4) process the lemma into structured parts
                    processed = process_lemma(raw_lemma_text)
                    
                    # 5) build the entry dict
                    entry_dict = {
                        "EntryID": entry_id,
                        "Verse": verse_info,
                        "LemmaMeta": lemma_meta,
                        "ProcessedLemma": processed,
                        "EntryText": entry_text
                    }
                    
                    # 6) classify the entry text if possible
                    try:
                        entry_dict["ClassifiedEntry"] = parse_and_classify_entry(entry_text)
                    except Exception as ce:
                        entry_dict["ClassifiedEntry"] = None
                        entry_dict["ClassifyError"] = str(ce)
                    
                    row_entries.append(entry_dict)
                
                except Exception as e:
                    # On any failure, record the entry ID and error
                    row_entries.append({
                        "EntryID": entry_id,
                        "Error": str(e)
                    })
        
        processed_rows.append(row_entries)
    
    df["ProcessedEntries"] = processed_rows
    return df

# %%
enrich_df_with_processed_lemmas(df[:8])['ProcessedEntries'][0]
# Out:
# <ipython-input-7-4c3923b95333>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ProcessedEntries"] = processed_rows
# [{'EntryID': 'app-1',
#   'Verse': {'verse': '1'},
#   'LemmaMeta': {'text': 'יותם אחז יחזקיה', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'יותם אחז יחזקיה',
#      'detail': [{'tag': 'lemma1', 'content': 'יותם'},
#       {'tag': 'lemma2', 'content': 'אחז'},
#       {'tag': 'lemma3', 'content': 'יחזקיה'}]}]},
#   'EntryText': ' <specialFont ][> <specialFont &>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]>', '<specialFont [>'],
#     'reading': '<specialFont &>',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-2',
#   'Verse': {'verse': {'verse': '1'}},
#   'LemmaMeta': {'text': 'מלכי', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'מלכי',
#      'detail': [{'tag': 'lemma1', 'content': 'מלכי'}]}]},
#   'EntryText': ' <specialFont ]h> num<subscript II><ref 1>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'num<ref 1>',
#     'cross_references': ['II'],
#     'sigla': ''}]},
#  {'EntryID': 'app-3',
#   'Verse': {'verse': '2'},
#   'LemmaMeta': {'text': 'דִּבֶּר', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'דִּבֶּר',
#      'detail': [{'tag': 'lemma1', 'content': 'דִּבֶּר'}]}]},
#   'EntryText': ' <specialFont ]> λόγου<ref 2> = <specialFont [T>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]>'],
#     'reading': 'λόγου<ref 2>',
#     'cross_references': [],
#     'sigla': ''},
#    {'classification': 'synonymous_variant',
#     'witnesses': ['<specialFont [>', '<specialFont T>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-4',
#   'Verse': {'verse': {'verse': '2'}},
#   'LemmaMeta': {'text': 'ב(הושע)', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ב(הושע)',
#      'detail': [{'tag': 'lemma1', 'content': 'ב'},
#       {'tag': 'parenthesis', 'content': '(הושע)'},
#       {'tag': 'full_lemma', 'content': 'בהושע'}]}]},
#   'EntryText': ' <specialFont ]h> πρός<ref 3> <specialFont +> <specialFont [>ܕܗܘܐ ܥܠ<ref 4>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'πρός<ref 3>',
#     'cross_references': [],
#     'sigla': ''},
#    {'classification': 'similar_variant',
#     'witnesses': ['<specialFont [>'],
#     'reading': 'ܕܗܘܐ ܥܠ<ref 4>',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-5',
#   'Verse': {'verse': {'verse': {'verse': '2'}}},
#   'LemmaMeta': {'text': 'ו(יאמר)', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ו(יאמר)',
#      'detail': [{'tag': 'lemma1', 'content': 'ו'},
#       {'tag': 'parenthesis', 'content': '(יאמר)'},
#       {'tag': 'full_lemma', 'content': 'ויאמר'}]}]},
#   'EntryText': ' <specialFont ]h[> >',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>', '<specialFont [>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': '>'}]},
#  {'EntryID': 'app-6',
#   'Verse': {'verse': {'verse': {'verse': {'verse': '2'}}}},
#   'LemmaMeta': {'text': 'לֵךְ', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'לֵךְ',
#      'detail': [{'tag': 'lemma1', 'content': 'לֵךְ'}]}]},
#   'EntryText': ' <specialFont ]h> ><subscript II>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': '',
#     'cross_references': ['II'],
#     'sigla': '>'}]},
#  {'EntryID': 'app-7',
#   'Verse': {'verse': '3'},
#   'LemmaMeta': {'text': 'ויקח', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ויקח',
#      'detail': [{'tag': 'lemma1', 'content': 'ויקח'}]}]},
#   'EntryText': ' <specialFont [> + ܠܗ<ref 5>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont [>'],
#     'reading': 'ܠܗ<ref 5>',
#     'cross_references': [],
#     'sigla': '+'}]},
#  {'EntryID': 'app-8',
#   'Verse': {'verse': {'verse': '3'}},
#   'LemmaMeta': {'text': 'לו', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'לו',
#      'detail': [{'tag': 'lemma1', 'content': 'לו'}]}]},
#   'EntryText': ' <specialFont ]h*-> ><subscript II IIIIV><ref 6>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>', '<specialFont *->'],
#     'reading': '<ref 6>',
#     'cross_references': ['II', 'IIIIV'],
#     'sigla': '>'}]},
#  {'EntryID': 'app-9',
#   'Verse': {'verse': '4'},
#   'LemmaMeta': {'text': 'יהוא', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'יהוא',
#      'detail': [{'tag': 'lemma1', 'content': 'יהוא'}]}]},
#   'EntryText': ' <specialFont ]h> Ιουδα<ref 7>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'Ιουδα<ref 7>',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-10',
#   'Verse': {'verse': {'verse': '4'}},
#   'LemmaMeta': {'text': '(ו)הִשְׁבַּתִּי', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': '(ו)הִשְׁבַּתִּי',
#      'detail': [{'tag': 'parenthesis', 'content': '(ו)'},
#       {'tag': 'lemma1', 'content': 'הִשְׁבַּתִּי'},
#       {'tag': 'full_lemma', 'content': 'והִשְׁבַּתִּי'}]}]},
#   'EntryText': ' <specialFont ]-> ἀποστρέψω<ref 8>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]->'],
#     'reading': 'ἀποστρέψω<ref 8>',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-11',
#   'Verse': {'verse': {'verse': {'verse': '4'}}},
#   'LemmaMeta': {'text': 'בית<superscript 2>', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'בית<superscript 2>',
#      'detail': [{'tag': 'lemma1', 'content': 'בית', 'numbers': '2'}]}]},
#   'EntryText': ' <specialFont ]h*hT-> + prep<ref 9>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>', '<specialFont *h>', '<specialFont T->'],
#     'reading': 'prep<ref 9>',
#     'cross_references': [],
#     'sigla': '+'}]},
#  {'EntryID': 'app-12',
#   'Verse': {'verse': '5'},
#   'LemmaMeta': {'text': 'והיה (ביום ההוא)', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'והיה (ביום ההוא)',
#      'detail': [{'tag': 'lemma1', 'content': 'והיה'},
#       {'tag': 'parenthesis', 'content': '(ביום ההוא)'}]}]},
#   'EntryText': ' <specialFont [> ><ref 10>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont [>'],
#     'reading': '<ref 10>',
#     'cross_references': [],
#     'sigla': '>'}]},
#  {'EntryID': 'app-13',
#   'Verse': {'verse': {'verse': '5'}},
#   'LemmaMeta': {'text': '(ו)היה', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': '(ו)היה',
#      'detail': [{'tag': 'parenthesis', 'content': '(ו)'},
#       {'tag': 'lemma1', 'content': 'היה'},
#       {'tag': 'full_lemma', 'content': 'והיה'}]}]},
#   'EntryText': ' <specialFont *> >',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont *>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': '>'}]},
#  {'EntryID': 'app-14',
#   'Verse': {'verse': {'verse': {'verse': '5'}}},
#   'LemmaMeta': {'text': 'ההוא', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ההוא',
#      'detail': [{'tag': 'lemma1', 'content': 'ההוא'}]}]},
#   'EntryText': ' <specialFont ]h> + dicit dominus<ref 11>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'dicit dominus<ref 11>',
#     'cross_references': [],
#     'sigla': '+'}]},
#  {'EntryID': 'app-15',
#   'Verse': {'verse': '6'},
#   'LemmaMeta': {'text': 'עוד<superscript 1>', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'עוד<superscript 1>',
#      'detail': [{'tag': 'lemma1', 'content': 'עוד', 'numbers': '1'}]}]},
#   'EntryText': ' <specialFont *hT-> ><subscript IIIII IV>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont *h>', '<specialFont T->'],
#     'reading': '',
#     'cross_references': ['IIIII', 'IV'],
#     'sigla': '>'}]},
#  {'EntryID': 'app-16',
#   'Verse': {'verse': {'verse': '6'}},
#   'LemmaMeta': {'text': 'לו', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'לו',
#      'detail': [{'tag': 'lemma1', 'content': 'לו'}]}]},
#   'EntryText': ' <specialFont ]h> + κύριος<subscript II><ref 12> = <specialFont [>| <specialFont [> pron<ref 13>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'κύριος<ref 12>',
#     'cross_references': ['II'],
#     'sigla': '+'},
#    {'classification': 'synonymous_variant',
#     'witnesses': ['<specialFont [>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': ''},
#    {'classification': 'additional_variant',
#     'witnesses': ['<specialFont [>'],
#     'reading': 'pron<ref 13>',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-17',
#   'Verse': {'verse': {'verse': {'verse': '6'}}},
#   'LemmaMeta': {'text': 'נשׂא אשׂא', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'נשׂא אשׂא',
#      'detail': [{'tag': 'lemma1', 'content': 'נשׂא'},
#       {'tag': 'lemma2', 'content': 'אשׂא'}]}]},
#   'EntryText': ' <specialFont ]> ἀντιτασσόμενος ἀντιτάξομαι<ref 14> | <specialFont *> oblivione obliviscar<ref 15> <specialFont +> <specialFont ~>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]>'],
#     'reading': 'ἀντιτασσόμενος ἀντιτάξομαι<ref 14>',
#     'cross_references': [],
#     'sigla': ''},
#    {'classification': 'additional_variant',
#     'witnesses': ['<specialFont *>'],
#     'reading': 'oblivione obliviscar<ref 15>',
#     'cross_references': [],
#     'sigla': ''},
#    {'classification': 'similar_variant',
#     'witnesses': ['<specialFont ~>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-18',
#   'Verse': {'verse': '7'},
#   'LemmaMeta': {'text': 'בית', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'בית',
#      'detail': [{'tag': 'lemma1', 'content': 'בית'}]}]},
#   'EntryText': ' <specialFont ]> υἱούς<ref 16>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]>'],
#     'reading': 'υἱούς<ref 16>',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-19',
#   'Verse': {'verse': {'verse': '7'}},
#   'LemmaMeta': {'text': 'יהודה', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'יהודה',
#      'detail': [{'tag': 'lemma1', 'content': 'יהודה'}]}]},
#   'EntryText': ' <specialFont ]h> >',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': '>'}]},
#  {'EntryID': 'app-20',
#   'Verse': {'verse': {'verse': {'verse': '7'}}},
#   'LemmaMeta': {'text': 'ולא', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ולא',
#      'detail': [{'tag': 'lemma1', 'content': 'ולא'}]}]},
#   'EntryText': ' <specialFont ][> rep',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]>', '<specialFont [>'],
#     'reading': 'rep',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-21',
#   'Verse': {'verse': {'verse': {'verse': {'verse': '7'}}}},
#   'LemmaMeta': {'text': '(ו)במלחמה', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': '(ו)במלחמה',
#      'detail': [{'tag': 'parenthesis', 'content': '(ו)'},
#       {'tag': 'lemma1', 'content': 'במלחמה'},
#       {'tag': 'full_lemma', 'content': 'ובמלחמה'}]}]},
#   'EntryText': ' <specialFont ]-> + (οὐδὲ) ἐν ἅρμασιν<ref 17>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]->'],
#     'reading': '(οὐδὲ) ἐν ἅρμασιν<ref 17>',
#     'cross_references': [],
#     'sigla': '+'}]},
#  {'EntryID': 'app-22',
#   'Verse': {'verse': {'verse': {'verse': {'verse': {'verse': '7'}}}}},
#   'LemmaMeta': {'text': 'בסוסים', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'בסוסים',
#      'detail': [{'tag': 'lemma1', 'content': 'בסוסים'}]}]},
#   'EntryText': ' <specialFont ]*[> <specialFont &><subscript IIIIV>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]>', '<specialFont *>', '<specialFont [>'],
#     'reading': '<specialFont &>',
#     'cross_references': ['IIIIV'],
#     'sigla': ''}]},
#  {'EntryID': 'app-23',
#   'Verse': {'verse': '8'},
#   'LemmaMeta': {'text': 'ותהר', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ותהר',
#      'detail': [{'tag': 'lemma1', 'content': 'ותהר'}]}]},
#   'EntryText': ' <specialFont ]-> + ἔτι<subscript II><ref 18> = <specialFont [>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]->'],
#     'reading': 'ἔτι<ref 18>',
#     'cross_references': ['II'],
#     'sigla': '+'},
#    {'classification': 'synonymous_variant',
#     'witnesses': ['<specialFont [>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-24',
#   'Verse': {'verse': {'verse': '8'}},
#   'LemmaMeta': {'text': 'ותלד', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ותלד',
#      'detail': [{'tag': 'lemma1', 'content': 'ותלד'}]}]},
#   'EntryText': ' <specialFont ]h> + αὐτῷ<subscript IV><ref 19> = <specialFont *h>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'αὐτῷ<ref 19>',
#     'cross_references': ['IV'],
#     'sigla': '+'},
#    {'classification': 'synonymous_variant',
#     'witnesses': ['<specialFont *h>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-25',
#   'Verse': {'verse': '9'},
#   'LemmaMeta': {'text': 'ויאמר', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'ויאמר',
#      'detail': [{'tag': 'lemma1', 'content': 'ויאמר'}]}]},
#   'EntryText': ' <specialFont ]h> + κύριος (αὐτῷ)<subscript II><ref 20> = <specialFont Th> <specialFont +> <specialFont [>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'κύριος (αὐτῷ)<ref 20>',
#     'cross_references': ['II'],
#     'sigla': '+'},
#    {'classification': 'synonymous_variant',
#     'witnesses': ['<specialFont Th>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': ''},
#    {'classification': 'similar_variant',
#     'witnesses': ['<specialFont [>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': ''}]},
#  {'EntryID': 'app-26',
#   'Verse': {'verse': {'verse': '9'}},
#   'LemmaMeta': {'text': 'כי – עמי ~ ואנכי – לכם',
#    'to_check': False,
#    'ref': None},
#   'ProcessedLemma': {'type': 'transposition',
#    'parts': [{'tag': 'transposition_a',
#      'content': 'כי – עמי',
#      'detail': [{'tag': 'lemma1', 'content': 'כי'},
#       {'tag': 'lemma2', 'content': '–'},
#       {'tag': 'lemma3', 'content': 'עמי'}]},
#     {'tag': 'transposition_b',
#      'content': 'ואנכי – לכם',
#      'detail': [{'tag': 'lemma1', 'content': 'ואנכי'},
#       {'tag': 'lemma2', 'content': '–'},
#       {'tag': 'lemma3', 'content': 'לכם'}]}]},
#   'EntryText': ' <specialFont 9> ~',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont 9>'],
#     'reading': '',
#     'cross_references': [],
#     'sigla': '~'}]},
#  {'EntryID': 'app-27',
#   'Verse': {'verse': {'verse': {'verse': '9'}}},
#   'LemmaMeta': {'text': 'לכם', 'to_check': False, 'ref': None},
#   'ProcessedLemma': {'type': 'Standard',
#    'parts': [{'content': 'לכם',
#      'detail': [{'tag': 'lemma1', 'content': 'לכם'}]}]},
#   'EntryText': ' <specialFont ]h> + θεός<ref 21> = <specialFont *h> <specialFont + [h>',
#   'ClassifiedEntry': [{'classification': 'variant',
#     'witnesses': ['<specialFont ]h>'],
#     'reading': 'θεός<ref 21>',
#     'cross_references': [],
#     'sigla': '+'},
#    {'classification': 'synonymous_variant',
#     'witnesses': ['<specialFont *h>'],
#     'reading': '<specialFont + [h>',
#     'cross_references': [],
#     'sigla': ''}]}]

# %%
#old processing and flatenning

# %%
def df_to_xml_with_flattened_verse_and_to_check(df, output_file):
    def extract_innermost_verse(verse_data):
        """
        Recursively extract the innermost 'verse' value from a nested structure.
        """
        if isinstance(verse_data, dict) and "verse" in verse_data:
            return extract_innermost_verse(verse_data["verse"])
        return verse_data

    root = ET.Element("root")

    for row_idx, row in df.iterrows():
        try:
            print(f"Processing Row: {row_idx}, Title: {row['Title']}, Chapter: {row['Chapter']}")

            # Create a Book element for each title
            book_element = ET.SubElement(root, "Book", {"Title": row["Title"]})
            chapter_element = ET.SubElement(book_element, "Chapter", {"Number": str(row["Chapter"])})
            main_text_data = row["Main Text"]

            if isinstance(main_text_data, dict):
                main_text_element = ET.SubElement(chapter_element, "MainText")
                previous_verse = None  # Initialize previous verse
                for key, value in main_text_data.items():
                    try:
                        print(f"Processing Entry ID: {key}")
                        entry_element = ET.SubElement(main_text_element, "Entry", {"ID": key})

                        # Split lemma and entry
                        lemma, entry = split_full_entry(value)
                        print(f"Split Lemma: {lemma}, Entry: {entry}")
                        
#                         lemma, entry = split_full_entry(value)

                        # --- quick sanity check ---------------------------------
                        if not isinstance(entry, str):
                            print(f"[DEBUG] entry for {key!r} is {type(entry).__name__}: {entry}")
                        if not isinstance(value, str):
                            print(f"[DEBUG] value for {key!r} is {type(value).__name__}")
                        # ---------------------------------------------------------
                        
                        if isinstance(lemma, dict) and "lemma" in lemma:
                            # Add Verse to Entry
                            split_verse = split_verse_lemma(lemma, previous_verse)  # Pass the full lemma dict
                            print(f"Split Verse Lemma: {split_verse}")

                            if split_verse["verse"].get("verse") or split_verse["verse"].get("to_verse"):
                                previous_verse = split_verse["verse"]

                            verse_element = ET.SubElement(entry_element, "Verse")
                            for verse_key, verse_value in split_verse["verse"].items():
                                # Flatten the verse structure if necessary
                                flattened_value = extract_innermost_verse(verse_value)
                                ET.SubElement(verse_element, verse_key.capitalize()).text = str(flattened_value)

                            # Extract processed lemma type, if any
                            processed_lemma = process_lemma(split_verse["lemma"][0]["text"])  # Pass only the lemma text
                            print(f"Processed Lemma: {processed_lemma}")

                            # Determine lemma type for the overall Lemma tag
                            lemma_type = processed_lemma.get("type") if isinstance(processed_lemma, dict) else None
                            lemma_attributes = {"Type": lemma_type} if lemma_type else {}

                            # Include `to_check` and `ref` flags if present
                            if split_verse["lemma"][0].get("to_check", False):
                                lemma_attributes["ToCheck"] = "true"
                            if split_verse["lemma"][0].get("ref"):
                                lemma_attributes["Ref"] = split_verse["lemma"][0]["ref"]

                            lemma_element = ET.SubElement(entry_element, "Lemma", lemma_attributes)

                            # Process the lemma content
                            if isinstance(processed_lemma, list):
                                for lemma_detail in processed_lemma:
                                    lemma_detail_element = ET.SubElement(lemma_element, "Detail")
                                    for field, field_value in lemma_detail.items():
                                        ET.SubElement(lemma_detail_element, field.capitalize()).text = str(field_value)
                            elif isinstance(processed_lemma, dict):
                                if processed_lemma.get("type") == "specific_range":
                                    for part in processed_lemma.get("parts", []):
                                        part_element = ET.SubElement(lemma_element, "Part")
                                        part_element.set("Type", processed_lemma["type"])
                                        for field, field_value in part.items():
                                            ET.SubElement(part_element, field.capitalize()).text = str(field_value)
                                elif processed_lemma.get("type") == "transposition":
                                    for part_key, part_value in processed_lemma["parts"].items():
                                        part_element = ET.SubElement(lemma_element, "Part", {"Type": part_key})
                                        if isinstance(part_value, list):
                                            for item in part_value:
                                                detail_element = ET.SubElement(part_element, "Detail")
                                                for sub_key, sub_value in item.items():
                                                    ET.SubElement(detail_element, sub_key.capitalize()).text = str(sub_value)
                                        elif isinstance(part_value, dict):
                                            for field, field_value in part_value.items():
                                                ET.SubElement(part_element, field.capitalize()).text = str(field_value)
                                        else:
                                            ET.SubElement(part_element, "Content").text = str(part_value)
                                elif processed_lemma.get("type") == "full_range":
                                    range_element = ET.SubElement(lemma_element, "Range")
                                    ET.SubElement(range_element, "From").text = str(processed_lemma.get("from"))
                                    ET.SubElement(range_element, "To").text = str(processed_lemma.get("to"))

                        # Step 2: Process Entry
                        if entry:
                            try:
                                classified_entry = parse_and_classify_entry(entry)
                                print(f"Classified Entry: {classified_entry}")

                                entry_details_element = ET.SubElement(entry_element, "EntryDetails")
                                for classified in classified_entry:
                                    classified_element = ET.SubElement(entry_details_element, "ClassifiedEntry")
                                    for field, field_value in classified.items():
                                        if isinstance(field_value, list):  # Handle lists (e.g., witnesses)
                                            list_element = ET.SubElement(classified_element, field.capitalize())
                                            for item in field_value:
                                                ET.SubElement(list_element, "Item").text = str(item)
                                        elif field_value:  # Skip empty fields
                                            ET.SubElement(classified_element, field.capitalize()).text = str(field_value)

                            except Exception as entry_error:
                                print(f"Error processing Entry for ID {key}: {entry_error}")
                                ET.SubElement(entry_element, "Error").text = f"Failed to process entry: {entry_error}"

                    except Exception as entry_id_error:
                        print(f"Error processing Entry ID {key}: {entry_id_error}")
                        ET.SubElement(main_text_element, "Error").text = f"Failed to process Entry ID {key}: {entry_id_error}"

            # Process Footnotes
            footnotes_data = row["Footnotes"]
            if isinstance(footnotes_data, dict):
                footnotes_element = ET.SubElement(chapter_element, "Footnotes")
                for key, value in footnotes_data.items():
                    footnote_element = ET.SubElement(footnotes_element, "Footnote", {"ID": key})
                    footnote_element.text = value

        except Exception as row_error:
            print(f"Error processing Row {row_idx}: {row_error}")
            ET.SubElement(root, "Error").text = f"Failed to process Row {row_idx}: {row_error}"

    # Write to XML file
    tree = ET.ElementTree(root)
    tree.write(output_file, encoding="utf-8", xml_declaration=True)

# %%
output_file = "flattened_verse_with_to_check.xml"
df_to_xml_with_flattened_verse_and_to_check(df, output_file)
print(f"XML saved to {output_file}")
# Out:
# Processing Row: 0, Title: Hosea, Chapter: 1
# Processing Entry ID: app-1
# Split Lemma: {'lemma': '1 יותם אחז יחזקיה'}, Entry:  <specialFont ][> <specialFont &>
# Split Verse Lemma: {'verse': {'verse': '1'}, 'lemma': [{'text': 'יותם אחז יחזקיה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'יותם'}, {'tag': 'lemma2', 'content': 'אחז'}, {'tag': 'lemma3', 'content': 'יחזקיה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>'], 'reading': '<specialFont &>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-2
# Split Lemma: {'lemma': 'מלכי'}, Entry:  <specialFont ]h> num<subscript II><ref 1>
# Split Verse Lemma: {'verse': {'verse': {'verse': '1'}}, 'lemma': [{'text': 'מלכי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'מלכי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'num<ref 1>', 'cross_references': ['II'], 'sigla': ''}]
# Processing Entry ID: app-3
# Split Lemma: {'lemma': '2 דִּבֶּר'}, Entry:  <specialFont ]> λόγου<ref 2> = <specialFont [T>
# Split Verse Lemma: {'verse': {'verse': '2'}, 'lemma': [{'text': 'דִּבֶּר', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'דִּבֶּר'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'λόγου<ref 2>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>', '<specialFont T>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-4
# Split Lemma: {'lemma': 'ב(הושע)'}, Entry:  <specialFont ]h> πρός<ref 3> <specialFont +> <specialFont [>ܕܗܘܐ ܥܠ<ref 4>
# Split Verse Lemma: {'verse': {'verse': {'verse': '2'}}, 'lemma': [{'text': 'ב(הושע)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ב'}, {'tag': 'parenthesis', 'content': '(הושע)'}, {'tag': 'full_lemma', 'content': 'בהושע'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'πρός<ref 3>', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont [>'], 'reading': 'ܕܗܘܐ ܥܠ<ref 4>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-5
# Split Lemma: {'lemma': 'ו(יאמר)'}, Entry:  <specialFont ]h[> >
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '2'}}}, 'lemma': [{'text': 'ו(יאמר)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ו'}, {'tag': 'parenthesis', 'content': '(יאמר)'}, {'tag': 'full_lemma', 'content': 'ויאמר'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-6
# Split Lemma: {'lemma': 'לֵךְ'}, Entry:  <specialFont ]h> ><subscript II>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '2'}}}}, 'lemma': [{'text': 'לֵךְ', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לֵךְ'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': '', 'cross_references': ['II'], 'sigla': '>'}]
# Processing Entry ID: app-7
# Split Lemma: {'lemma': '3 ויקח'}, Entry:  <specialFont [> + ܠܗ<ref 5>
# Split Verse Lemma: {'verse': {'verse': '3'}, 'lemma': [{'text': 'ויקח', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ויקח'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': 'ܠܗ<ref 5>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-8
# Split Lemma: {'lemma': 'לו'}, Entry:  <specialFont ]h*-> ><subscript II IIIIV><ref 6>
# Split Verse Lemma: {'verse': {'verse': {'verse': '3'}}, 'lemma': [{'text': 'לו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont *->'], 'reading': '<ref 6>', 'cross_references': ['II', 'IIIIV'], 'sigla': '>'}]
# Processing Entry ID: app-9
# Split Lemma: {'lemma': '4 יהוא'}, Entry:  <specialFont ]h> Ιουδα<ref 7>
# Split Verse Lemma: {'verse': {'verse': '4'}, 'lemma': [{'text': 'יהוא', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'יהוא'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'Ιουδα<ref 7>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-10
# Split Lemma: {'lemma': '(ו)הִשְׁבַּתִּי'}, Entry:  <specialFont ]-> ἀποστρέψω<ref 8>
# Split Verse Lemma: {'verse': {'verse': {'verse': '4'}}, 'lemma': [{'text': '(ו)הִשְׁבַּתִּי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'הִשְׁבַּתִּי'}, {'tag': 'full_lemma', 'content': 'והִשְׁבַּתִּי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': 'ἀποστρέψω<ref 8>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-11
# Split Lemma: {'lemma': 'בית<superscript 2>'}, Entry:  <specialFont ]h*hT-> + prep<ref 9>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '4'}}}, 'lemma': [{'text': 'בית<superscript 2>', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'בית', 'numbers': '2'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont *h>', '<specialFont T->'], 'reading': 'prep<ref 9>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-12
# Split Lemma: {'lemma': '5 והיה (ביום ההוא)'}, Entry:  <specialFont [> ><ref 10>
# Split Verse Lemma: {'verse': {'verse': '5'}, 'lemma': [{'text': 'והיה (ביום ההוא)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'והיה'}, {'tag': 'parenthesis', 'content': '(ביום ההוא)'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': '<ref 10>', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-13
# Split Lemma: {'lemma': '(ו)היה'}, Entry:  <specialFont *> >
# Split Verse Lemma: {'verse': {'verse': {'verse': '5'}}, 'lemma': [{'text': '(ו)היה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'היה'}, {'tag': 'full_lemma', 'content': 'והיה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>'], 'reading': '', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-14
# Split Lemma: {'lemma': 'ההוא'}, Entry:  <specialFont ]h> + dicit dominus<ref 11>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '5'}}}, 'lemma': [{'text': 'ההוא', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ההוא'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'dicit dominus<ref 11>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-15
# Split Lemma: {'lemma': '6 עוד<superscript 1>'}, Entry:  <specialFont *hT-> ><subscript IIIII IV>
# Split Verse Lemma: {'verse': {'verse': '6'}, 'lemma': [{'text': 'עוד<superscript 1>', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'עוד', 'numbers': '1'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *h>', '<specialFont T->'], 'reading': '', 'cross_references': ['IIIII', 'IV'], 'sigla': '>'}]
# Processing Entry ID: app-16
# Split Lemma: {'lemma': 'לו'}, Entry:  <specialFont ]h> + κύριος<subscript II><ref 12> = <specialFont [>| <specialFont [> pron<ref 13>
# Split Verse Lemma: {'verse': {'verse': {'verse': '6'}}, 'lemma': [{'text': 'לו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'κύριος<ref 12>', 'cross_references': ['II'], 'sigla': '+'}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont [>'], 'reading': 'pron<ref 13>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-17
# Split Lemma: {'lemma': 'נשׂא אשׂא'}, Entry:  <specialFont ]> ἀντιτασσόμενος ἀντιτάξομαι<ref 14> | <specialFont *> oblivione obliviscar<ref 15> <specialFont +> <specialFont ~>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '6'}}}, 'lemma': [{'text': 'נשׂא אשׂא', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'נשׂא'}, {'tag': 'lemma2', 'content': 'אשׂא'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'ἀντιτασσόμενος ἀντιτάξομαι<ref 14>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont *>'], 'reading': 'oblivione obliviscar<ref 15>', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont ~>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-18
# Split Lemma: {'lemma': '7 בית'}, Entry:  <specialFont ]> υἱούς<ref 16>
# Split Verse Lemma: {'verse': {'verse': '7'}, 'lemma': [{'text': 'בית', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'בית'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'υἱούς<ref 16>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-19
# Split Lemma: {'lemma': 'יהודה'}, Entry:  <specialFont ]h> >
# Split Verse Lemma: {'verse': {'verse': {'verse': '7'}}, 'lemma': [{'text': 'יהודה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'יהודה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': '', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-20
# Split Lemma: {'lemma': 'ולא'}, Entry:  <specialFont ][> rep
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '7'}}}, 'lemma': [{'text': 'ולא', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ולא'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>'], 'reading': 'rep', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-21
# Split Lemma: {'lemma': '(ו)במלחמה'}, Entry:  <specialFont ]-> + (οὐδὲ) ἐν ἅρμασιν<ref 17>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '7'}}}}, 'lemma': [{'text': '(ו)במלחמה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'במלחמה'}, {'tag': 'full_lemma', 'content': 'ובמלחמה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': '(οὐδὲ) ἐν ἅρμασιν<ref 17>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-22
# Split Lemma: {'lemma': 'בסוסים'}, Entry:  <specialFont ]*[> <specialFont &><subscript IIIIV>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '7'}}}}}, 'lemma': [{'text': 'בסוסים', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'בסוסים'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>', '<specialFont [>'], 'reading': '<specialFont &>', 'cross_references': ['IIIIV'], 'sigla': ''}]
# Processing Entry ID: app-23
# Split Lemma: {'lemma': '8 ותהר'}, Entry:  <specialFont ]-> + ἔτι<subscript II><ref 18> = <specialFont [>
# Split Verse Lemma: {'verse': {'verse': '8'}, 'lemma': [{'text': 'ותהר', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ותהר'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': 'ἔτι<ref 18>', 'cross_references': ['II'], 'sigla': '+'}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-24
# Split Lemma: {'lemma': 'ותלד'}, Entry:  <specialFont ]h> + αὐτῷ<subscript IV><ref 19> = <specialFont *h>
# Split Verse Lemma: {'verse': {'verse': {'verse': '8'}}, 'lemma': [{'text': 'ותלד', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ותלד'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'αὐτῷ<ref 19>', 'cross_references': ['IV'], 'sigla': '+'}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont *h>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-25
# Split Lemma: {'lemma': '9 ויאמר'}, Entry:  <specialFont ]h> + κύριος (αὐτῷ)<subscript II><ref 20> = <specialFont Th> <specialFont +> <specialFont [>
# Split Verse Lemma: {'verse': {'verse': '9'}, 'lemma': [{'text': 'ויאמר', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ויאמר'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'κύριος (αὐτῷ)<ref 20>', 'cross_references': ['II'], 'sigla': '+'}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont Th>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-26
# Split Lemma: {'lemma': 'כי – עמי ~ ואנכי – לכם'}, Entry:  <specialFont 9> ~
# Split Verse Lemma: {'verse': {'verse': {'verse': '9'}}, 'lemma': [{'text': 'כי – עמי ~ ואנכי – לכם', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'transposition', 'parts': {'a': {'type': 'full_range', 'from': 'כי', 'to': 'עמי'}, 'b': {'type': 'full_range', 'from': 'ואנכי', 'to': 'לכם'}}}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont 9>'], 'reading': '', 'cross_references': [], 'sigla': '~'}]
# Processing Entry ID: app-27
# Split Lemma: {'lemma': 'לכם'}, Entry:  <specialFont ]h> + θεός<ref 21> = <specialFont *h> <specialFont + [h>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '9'}}}, 'lemma': [{'text': 'לכם', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לכם'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'θεός<ref 21>', 'cross_references': [], 'sigla': '+'}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont *h>'], 'reading': '<specialFont + [h>', 'cross_references': [], 'sigla': ''}]
# Processing Row: 1, Title: Hosea, Chapter: 2
# Processing Entry ID: app-1
# Split Lemma: {'lemma': '1–2'}, Entry:  <specialFont ]*> 1<subscript 10–11>
# Split Verse Lemma: {'verse': {'from_verse': '1', 'to_verse': '2'}, 'lemma': [{'text': '', 'to_check': False, 'ref': None}]}
# Processed Lemma: None
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>'], 'reading': '1<subscript 10–11>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-2
# Split Lemma: {'lemma': '1 ימד'}, Entry:  <specialFont *> verb/nom
# Split Verse Lemma: {'verse': {'verse': '1'}, 'lemma': [{'text': 'ימד', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ימד'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>'], 'reading': 'verb/nom', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-3
# Split Lemma: {'lemma': 'ולא יספר'}, Entry:  <specialFont ]h> >
# Split Verse Lemma: {'verse': {'verse': {'verse': '1'}}, 'lemma': [{'text': 'ולא יספר', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ולא'}, {'tag': 'lemma2', 'content': 'יספר'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': '', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-4
# Split Lemma: {'lemma': 'יֵאָמֵר להם<superscript 2>'}, Entry:  <specialFont ][> diath | <specialFont ]h> pr ἐκεῖ<ref 1> = <specialFont [>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '1'}}}, 'lemma': [{'text': 'יֵאָמֵר להם<superscript 2>', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'יֵאָמֵר'}, {'tag': 'lemma2', 'content': 'להם', 'numbers': '2'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>'], 'reading': 'diath', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'pr ἐκεῖ<ref 1>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-5
# Split Lemma: {'lemma': '3 לַאֲחֵיכם'}, Entry:  <specialFont ]> num<ref 2>
# Split Verse Lemma: {'verse': {'verse': '3'}, 'lemma': [{'text': 'לַאֲחֵיכם', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לַאֲחֵיכם'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'num<ref 2>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-6
# Split Lemma: {'lemma': 'ולאחותיכם'}, Entry:  <specialFont ]*> num<ref 3>
# Split Verse Lemma: {'verse': {'verse': {'verse': '3'}}, 'lemma': [{'text': 'ולאחותיכם', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ולאחותיכם'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>'], 'reading': 'num<ref 3>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-7
# Split Lemma: {'lemma': '4 ו(תסר)'}, Entry:  <specialFont *[> >
# Split Verse Lemma: {'verse': {'verse': '4'}, 'lemma': [{'text': 'ו(תסר)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ו'}, {'tag': 'parenthesis', 'content': '(תסר)'}, {'tag': 'full_lemma', 'content': 'ותסר'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>', '<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-8
# Split Lemma: {'lemma': '(ו)תסר ... מפניה'}, Entry:  <specialFont ]> ἐξαρῶ … ἐκ προσώπου μου<ref 4>
# Split Verse Lemma: {'verse': {'verse': {'verse': '4'}}, 'lemma': [{'text': '(ו)תסר ... מפניה', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': '(ו)תסר'}, {'tag': 'end lemma', 'content': 'מפניה'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'ἐξαρῶ … ἐκ προσώπου μου<ref 4>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-9
# Split Lemma: {'lemma': '5 פן'}, Entry:  <specialFont ]> ὅπως ἂν<ref 5>
# Split Verse Lemma: {'verse': {'verse': '5'}, 'lemma': [{'text': 'פן', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'פן'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'ὅπως ἂν<ref 5>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-10
# Split Lemma: {'lemma': 'כ(יום)'}, Entry:  <specialFont ]h> καθὼς ἐν<ref 6>
# Split Verse Lemma: {'verse': {'verse': {'verse': '5'}}, 'lemma': [{'text': 'כ(יום)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'כ'}, {'tag': 'parenthesis', 'content': '(יום)'}, {'tag': 'full_lemma', 'content': 'כיום'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'καθὼς ἐν<ref 6>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-11
# Split Lemma: {'lemma': 'ושמתיה ... ושתה'}, Entry:  <specialFont [> condens
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '5'}}}, 'lemma': [{'text': 'ושמתיה ... ושתה', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'ושמתיה'}, {'tag': 'end lemma', 'content': 'ושתה'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': 'condens', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-12
# Split Lemma: {'lemma': 'כ(מדבר) ... כ(ארץ)'}, Entry:  <specialFont ]h> prep
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '5'}}}}, 'lemma': [{'text': 'כ(מדבר) ... כ(ארץ)', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'כ(מדבר)'}, {'tag': 'end lemma', 'content': 'כ(ארץ)'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'prep', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-13
# Split Lemma: {'lemma': '7 נתני'}, Entry:  <specialFont ]> + μοι<ref 7>
# Split Verse Lemma: {'verse': {'verse': '7'}, 'lemma': [{'text': 'נתני', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'נתני'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'μοι<ref 7>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-14
# Split Lemma: {'lemma': 'שמני'}, Entry:  <specialFont ]-[> <specialFont &> | <specialFont ]h> pr καὶ τὸν οἶνόν μου<ref 8> | <specialFont T-> > pron
# Split Verse Lemma: {'verse': {'verse': {'verse': '7'}}, 'lemma': [{'text': 'שמני', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'שמני'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->', '<specialFont [>'], 'reading': '<specialFont &>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'pr καὶ τὸν οἶνόν μου<ref 8>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont T->'], 'reading': 'pron', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-15
# Split Lemma: {'lemma': '(ו)שקויָי'}, Entry:  <specialFont ]> πάντα ὅσα μοι καθήκει<ref 9> = <specialFont [>, <specialFont T> <specialFont 8>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '7'}}}, 'lemma': [{'text': '(ו)שקויָי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'שקויָי'}, {'tag': 'full_lemma', 'content': 'ושקויָי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'πάντα ὅσα μοι καθήκει<ref 9>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'related_variant', 'witnesses': ['<specialFont T>'], 'reading': '<specialFont 8>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-16
# Split Lemma: {'lemma': '8 דרכך'}, Entry:  <specialFont ][> pron<ref 10> | <specialFont *h[T> num
# Split Verse Lemma: {'verse': {'verse': '8'}, 'lemma': [{'text': 'דרכך', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'דרכך'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>'], 'reading': 'pron<ref 10>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont *h>', '<specialFont [>', '<specialFont T>'], 'reading': 'num', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-17
# Split Lemma: {'lemma': 'גדרהּ'}, Entry:  <specialFont ]> τὰς ὁδοὺς αὐτῆς<ref 11> = <specialFont [> | <specialFont ]hT> > pron
# Split Verse Lemma: {'verse': {'verse': {'verse': '8'}}, 'lemma': [{'text': 'גדרהּ', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'גדרהּ'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'τὰς ὁδοὺς αὐτῆς<ref 11>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]h>', '<specialFont T>'], 'reading': 'pron', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-18
# Split Lemma: {'lemma': 'ונתיבותיה'}, Entry:  <specialFont ][> num | <specialFont [Th> > pron
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '8'}}}, 'lemma': [{'text': 'ונתיבותיה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ונתיבותיה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>'], 'reading': 'num', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont [>', '<specialFont Th>'], 'reading': 'pron', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-19
# Split Lemma: {'lemma': '9 תמצא'}, Entry:  <specialFont ][> + pron<ref 12>
# Split Verse Lemma: {'verse': {'verse': '9'}, 'lemma': [{'text': 'תמצא', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'תמצא'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>'], 'reading': 'pron<ref 12>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-20
# Split Lemma: {'lemma': 'אלכה ואשובה'}, Entry:  <specialFont [> ~<ref 13>
# Split Verse Lemma: {'verse': {'verse': {'verse': '9'}}, 'lemma': [{'text': 'אלכה ואשובה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'אלכה'}, {'tag': 'lemma2', 'content': 'ואשובה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': '<ref 13>', 'cross_references': [], 'sigla': '~'}]
# Processing Entry ID: app-21
# Split Lemma: {'lemma': '10 וכסף'}, Entry:  <specialFont ]h> + καὶ χρυσίον<ref 14>
# Split Verse Lemma: {'verse': {'verse': '10'}, 'lemma': [{'text': 'וכסף', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'וכסף'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'καὶ χρυσίον<ref 14>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-22
# Split Lemma: {'lemma': '<specialFont <subscript v>>וזהב<specialFont ,>', 'to_check': True}, Entry:  <specialFont ]> <specialFont v>αὐτὴ δὲ<specialFont ,>ἀργυρᾶ καὶ χρυσᾶ<ref 15>
# Split Verse Lemma: {'verse': {'verse': {'verse': '10'}}, 'lemma': [{'text': '<specialFont <subscript v>>וזהב<specialFont ,>', 'to_check': True, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'specialFont'}, {'tag': 'lemma2', 'content': 'subscript'}, {'tag': 'lemma3', 'content': 'v>>וזהב'}, {'tag': 'lemma4', 'content': 'specialFont'}, {'tag': 'lemma5', 'content': ',>'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': '<specialFont v>αὐτὴ δὲ<specialFont ,>ἀργυρᾶ καὶ χρυσᾶ<ref 15>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-23
# Split Lemma: {'lemma': 'עשו'}, Entry:  <specialFont ]> pers<ref 16> | <specialFont [> pr ܘܡܢܗ<ref 17> <specialFont +> <specialFont T>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '10'}}}, 'lemma': [{'text': 'עשו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'עשו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'pers<ref 16>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont [>'], 'reading': 'pr ܘܡܢܗ<ref 17>', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont T>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-24
# Split Lemma: {'lemma': 'ל(בעל)'}, Entry:  <specialFont ]> τῇ<ref 18>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '10'}}}}, 'lemma': [{'text': 'ל(בעל)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ל'}, {'tag': 'parenthesis', 'content': '(בעל)'}, {'tag': 'full_lemma', 'content': 'לבעל'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'τῇ<ref 18>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-25
# Split Lemma: {'lemma': '11 ותירושי'}, Entry:  <specialFont ]h> + καὶ τὸ ἔλαιόν μου<ref 19>
# Split Verse Lemma: {'verse': {'verse': '11'}, 'lemma': [{'text': 'ותירושי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ותירושי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'καὶ τὸ ἔλαιόν μου<ref 19>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-26
# Split Lemma: {'lemma': 'לכסות', 'ref': '<ref 20>'}, Entry: <specialFont ]> τοῦ μὴ καλύπτειν<ref 21> | <specialFont *> quae operiebant<ref 22>
# Split Verse Lemma: {'verse': {'verse': {'verse': '11'}}, 'lemma': [{'text': 'לכסות', 'to_check': False, 'ref': '<ref 20>'}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לכסות'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'τοῦ μὴ καλύπτειν<ref 21>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont *>'], 'reading': 'quae operiebant<ref 22>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-27
# Split Lemma: {'lemma': '12 נבלתה'}, Entry:  <specialFont ]h> τὴν ἀσχημοσύνην αὐτῆς<ref 23> = <specialFont [T>
# Split Verse Lemma: {'verse': {'verse': '12'}, 'lemma': [{'text': 'נבלתה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'נבלתה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'τὴν ἀσχημοσύνην αὐτῆς<ref 23>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>', '<specialFont T>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-28
# Split Lemma: {'lemma': 'מידי'}, Entry:  <specialFont ~> pron<ref 24>
# Split Verse Lemma: {'verse': {'verse': {'verse': '12'}}, 'lemma': [{'text': 'מידי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'מידי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ~>'], 'reading': 'pron<ref 24>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-29
# Split Lemma: {'lemma': '13 (ו)הִשְׁבַּתִּי'}, Entry:  <specialFont ]> ἀποστρέψω<ref 25>
# Split Verse Lemma: {'verse': {'verse': '13'}, 'lemma': [{'text': '(ו)הִשְׁבַּתִּי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'הִשְׁבַּתִּי'}, {'tag': 'full_lemma', 'content': 'והִשְׁבַּתִּי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'ἀποστρέψω<ref 25>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-30
# Split Lemma: {'lemma': 'חגה – מועדה'}, Entry:  <specialFont ][T> num<ref 26>
# Split Verse Lemma: {'verse': {'verse': {'verse': '13'}}, 'lemma': [{'text': 'חגה – מועדה', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'full_range', 'from': 'חגה', 'to': 'מועדה'}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>', '<specialFont T>'], 'reading': 'num<ref 26>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-31
# Split Lemma: {'lemma': 'חגה'}, Entry:  <specialFont ]h> <specialFont &>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '13'}}}, 'lemma': [{'text': 'חגה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'חגה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': '<specialFont &>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-32
# Split Lemma: {'lemma': 'ו(שבתה)'}, Entry:  <specialFont *-> >
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '13'}}}}, 'lemma': [{'text': 'ו(שבתה)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ו'}, {'tag': 'parenthesis', 'content': '(שבתה)'}, {'tag': 'full_lemma', 'content': 'ושבתה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *->'], 'reading': '', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-33
# Split Lemma: {'lemma': 'מועדה'}, Entry:  <specialFont *> num<subscript II>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '13'}}}}}, 'lemma': [{'text': 'מועדה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'מועדה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>'], 'reading': 'num', 'cross_references': ['II'], 'sigla': ''}]
# Processing Entry ID: app-34
# Split Lemma: {'lemma': '14 לי ... לי'}, Entry:  <specialFont [> reduct
# Split Verse Lemma: {'verse': {'verse': '14'}, 'lemma': [{'text': 'לי ... לי', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'לי'}, {'tag': 'end lemma', 'content': 'לי'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': 'reduct', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-35
# Split Lemma: {'lemma': 'ושמתים ... ואכלתם'}, Entry:  <specialFont *> pron<ref 27>
# Split Verse Lemma: {'verse': {'verse': {'verse': '14'}}, 'lemma': [{'text': 'ושמתים ... ואכלתם', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'ושמתים'}, {'tag': 'end lemma', 'content': 'ואכלתם'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>'], 'reading': 'pron<ref 27>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-36
# Split Lemma: {'lemma': 'ליער'}, Entry:  <specialFont ]> εἰς μαρτύριον<ref 28>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '14'}}}, 'lemma': [{'text': 'ליער', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ליער'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'εἰς μαρτύριον<ref 28>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-37
# Split Lemma: {'lemma': 'השדה'}, Entry:  <specialFont ]-> + καὶ τὰ πετεινὰ τοῦ οὐρανοῦ καὶ τὰ ἑρπετὰ τῆς γῆς<ref 29>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '14'}}}}, 'lemma': [{'text': 'השדה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'השדה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': 'καὶ τὰ πετεινὰ τοῦ οὐρανοῦ καὶ τὰ ἑρπετὰ τῆς γῆς<ref 29>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-38
# Split Lemma: {'lemma': '15 אשר ... להם'}, Entry:  <specialFont ]-> ἐν αἷς … αὐτοῖς<ref 30> <specialFont +> <specialFont ]h>
# Split Verse Lemma: {'verse': {'verse': '15'}, 'lemma': [{'text': 'אשר ... להם', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'אשר'}, {'tag': 'end lemma', 'content': 'להם'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': 'ἐν αἷς … αὐτοῖς<ref 30>', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont ]h>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-39
# Split Lemma: {'lemma': 'להם'}, Entry:  <specialFont [> ܒܗܘܢ<ref 31>
# Split Verse Lemma: {'verse': {'verse': {'verse': '15'}}, 'lemma': [{'text': 'להם', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'להם'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': 'ܒܗܘܢ<ref 31>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-40
# Split Lemma: {'lemma': '(ו)תעד'}, Entry:  <specialFont ~> + pron<ref 32> | <specialFont [> ܫܩܠܬ<ref 33>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '15'}}}, 'lemma': [{'text': '(ו)תעד', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'תעד'}, {'tag': 'full_lemma', 'content': 'ותעד'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ~>'], 'reading': 'pron<ref 32>', 'cross_references': [], 'sigla': '+'}, {'classification': 'additional_variant', 'witnesses': ['<specialFont [>'], 'reading': 'ܫܩܠܬ<ref 33>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-41
# Split Lemma: {'lemma': 'נזמה וחליתה'}, Entry:  <specialFont ][T> num
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '15'}}}}, 'lemma': [{'text': 'נזמה וחליתה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'נזמה'}, {'tag': 'lemma2', 'content': 'וחליתה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>', '<specialFont T>'], 'reading': 'num', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-42
# Split Lemma: {'lemma': '16 והלכתיה המדבר'}, Entry:  <specialFont ]h> καὶ τάξω αὐτὴν ὡς ἔρημον<ref 34>
# Split Verse Lemma: {'verse': {'verse': '16'}, 'lemma': [{'text': 'והלכתיה המדבר', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'והלכתיה'}, {'tag': 'lemma2', 'content': 'המדבר'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'καὶ τάξω αὐτὴν ὡς ἔρημον<ref 34>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-43
# Split Lemma: {'lemma': '17 כְּרָמיה'}, Entry:  <specialFont *> vinitores eius<ref 35> = <specialFont ~>
# Split Verse Lemma: {'verse': {'verse': '17'}, 'lemma': [{'text': 'כְּרָמיה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'כְּרָמיה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>'], 'reading': 'vinitores eius<ref 35>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont ~>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-44
# Split Lemma: {'lemma': 'לְפֶתַח'}, Entry:  <specialFont ]> διανοῖξαι<ref 36> <specialFont +> <specialFont *[>
# Split Verse Lemma: {'verse': {'verse': {'verse': '17'}}, 'lemma': [{'text': 'לְפֶתַח', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לְפֶתַח'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'διανοῖξαι<ref 36>', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont *>', '<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-45
# Split Lemma: {'lemma': 'תקוה'}, Entry:  <specialFont ]> σύνεσιν αὐτῆς<ref 37> | <specialFont [> <ref 38>ܣܘܟܠܗܿ
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '17'}}}, 'lemma': [{'text': 'תקוה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'תקוה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'σύνεσιν αὐτῆς<ref 37>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont [>'], 'reading': '<ref 38>ܣܘܟܠܗܿ', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-46
# Split Lemma: {'lemma': 'וכיום'}, Entry:  <specialFont ]*> num<ref 39>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '17'}}}}, 'lemma': [{'text': 'וכיום', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'וכיום'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>'], 'reading': 'num<ref 39>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-47
# Split Lemma: {'lemma': 'עלותה'}, Entry:  <specialFont ]h> τῆς ἐξόδου αὐτῆς<ref 40>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '17'}}}}}, 'lemma': [{'text': 'עלותה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'עלותה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'τῆς ἐξόδου αὐτῆς<ref 40>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-48
# Split Lemma: {'lemma': '18 תקראי<superscript 1, 2>'}, Entry:  <specialFont ]*[> pers<ref 41> | <specialFont ]*[> + pron<subscript IIIII><ref 42>
# Split Verse Lemma: {'verse': {'verse': '18'}, 'lemma': [{'text': 'תקראי<superscript 1, 2>', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'תקראי', 'numbers': '1, 2'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>', '<specialFont [>'], 'reading': 'pers<ref 41>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]>', '<specialFont *>', '<specialFont [>'], 'reading': 'pron<ref 42>', 'cross_references': ['IIIII'], 'sigla': '+'}]
# Processing Entry ID: app-49
# Split Lemma: {'lemma': 'בעלי'}, Entry:  <specialFont ]> Βααλιμ<ref 43> = <specialFont *h>
# Split Verse Lemma: {'verse': {'verse': {'verse': '18'}}, 'lemma': [{'text': 'בעלי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'בעלי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'Βααλιμ<ref 43>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont *h>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-50
# Split Lemma: {'lemma': '19 והסרתי'}, Entry:  <specialFont [h> ܘܐܘܒܕ<ref 44>
# Split Verse Lemma: {'verse': {'verse': '19'}, 'lemma': [{'text': 'והסרתי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'והסרתי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [h>'], 'reading': 'ܘܐܘܒܕ<ref 44>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-51
# Split Lemma: {'lemma': 'שמות'}, Entry:  <specialFont ]h*h[T> num<ref 45>
# Split Verse Lemma: {'verse': {'verse': {'verse': '19'}}, 'lemma': [{'text': 'שמות', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'שמות'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont *h>', '<specialFont [>', '<specialFont T>'], 'reading': 'num<ref 45>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-52
# Split Lemma: {'lemma': 'מפיה'}, Entry:  <specialFont ]h> pron<ref 46>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '19'}}}, 'lemma': [{'text': 'מפיה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'מפיה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'pron<ref 46>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-53
# Split Lemma: {'lemma': 'יִזָּכרו ... בשמם'}, Entry:  <specialFont ]> μνησθῶσιν … τὰ ὀνόματα αὐτῶν<ref 47> <specialFont +> <specialFont *[>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '19'}}}}, 'lemma': [{'text': 'יִזָּכרו ... בשמם', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'יִזָּכרו'}, {'tag': 'end lemma', 'content': 'בשמם'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'μνησθῶσιν … τὰ ὀνόματα αὐτῶν<ref 47>', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont *>', '<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-54
# Split Lemma: {'lemma': '20 ועם ... ו(רמש)'}, Entry:  <specialFont ]-*> rep
# Split Verse Lemma: {'verse': {'verse': '20'}, 'lemma': [{'text': 'ועם ... ו(רמש)', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'ועם'}, {'tag': 'end lemma', 'content': 'ו(רמש)'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->', '<specialFont *>'], 'reading': 'rep', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-55
# Split Lemma: {'lemma': 'ומלחמה'}, Entry:  <specialFont ]h> >
# Split Verse Lemma: {'verse': {'verse': {'verse': '20'}}, 'lemma': [{'text': 'ומלחמה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ומלחמה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': '', 'cross_references': [], 'sigla': '>'}]
# Processing Entry ID: app-56
# Split Lemma: {'lemma': 'אשבור'}, Entry:  <specialFont [> ܐܒܛܠ<ref 48> = <specialFont T>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '20'}}}, 'lemma': [{'text': 'אשבור', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'אשבור'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': 'ܐܒܛܠ<ref 48>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont T>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-57
# Split Lemma: {'lemma': '(ו)השכבתי(ם)'}, Entry:  <specialFont ]> κατοικιῶ<ref 49> = <specialFont [T>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '20'}}}}, 'lemma': [{'text': '(ו)השכבתי(ם)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'השכבתי'}, {'tag': 'parenthesis', 'content': '(ם)'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'κατοικιῶ<ref 49>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>', '<specialFont T>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-58
# Split Lemma: {'lemma': '(והשכבתי)ם'}, Entry:  <specialFont ]-> pron<ref 50>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '20'}}}}}, 'lemma': [{'text': '(והשכבתי)ם', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(והשכבתי)'}, {'tag': 'lemma1', 'content': 'ם'}, {'tag': 'full_lemma', 'content': 'והשכבתים'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': 'pron<ref 50>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-59
# Split Lemma: {'lemma': '21 ב(צדק ו)ב(משפט)'}, Entry:  <specialFont *-> reduct
# Split Verse Lemma: {'verse': {'verse': '21'}, 'lemma': [{'text': 'ב(צדק ו)ב(משפט)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ב'}, {'tag': 'parenthesis', 'content': '(צדק ו)'}, {'tag': 'lemma2', 'content': 'ב'}, {'tag': 'parenthesis', 'content': '(משפט)'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *->'], 'reading': 'reduct', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-60
# Split Lemma: {'lemma': 'וב(חסד ו)ב(רחמים)'}, Entry:  <specialFont ]h*-> reduct
# Split Verse Lemma: {'verse': {'verse': {'verse': '21'}}, 'lemma': [{'text': 'וב(חסד ו)ב(רחמים)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'וב'}, {'tag': 'parenthesis', 'content': '(חסד ו)'}, {'tag': 'lemma2', 'content': 'ב'}, {'tag': 'parenthesis', 'content': '(רחמים)'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont *->'], 'reading': 'reduct', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-61
# Split Lemma: {'lemma': '22 את יהוה'}, Entry:  <specialFont *> quia ego Dominus<subscript II IIIIV><ref 51>
# Split Verse Lemma: {'verse': {'verse': '22'}, 'lemma': [{'text': 'את יהוה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'את'}, {'tag': 'lemma2', 'content': 'יהוה'}]
# ...
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '4'}}}}}}, 'lemma': [{'text': '(ל)מעשה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ל)'}, {'tag': 'lemma1', 'content': 'מעשה'}, {'tag': 'full_lemma', 'content': 'למעשה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>', '<specialFont T>'], 'reading': 'num', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-23
# Split Lemma: {'lemma': 'ירֻחם'}, Entry:  <specialFont ]*[> diath
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '4'}}}}}}}, 'lemma': [{'text': 'ירֻחם', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ירֻחם'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>', '<specialFont [>'], 'reading': 'diath', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-24
# Split Lemma: {'lemma': '5 משובתם'}, Entry:  <specialFont ]*:> num<subscript II> | <specialFont ]> τὰς κατοικίας αὐτῶν<ref 25> | <specialFont *> contritiones eorum<ref 26> | <specialFont :> ܡܬܦܢ̈ܝܢܘܬܐ<ref 27>
# Split Verse Lemma: {'verse': {'verse': '5'}, 'lemma': [{'text': 'משובתם', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'משובתם'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont *>', '<specialFont :>'], 'reading': 'num', 'cross_references': ['II'], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]>'], 'reading': 'τὰς κατοικίας αὐτῶν<ref 25>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont *>'], 'reading': 'contritiones eorum<ref 26>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont :>'], 'reading': 'ܡܬܦܢ̈ܝܢܘܬܐ<ref 27>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-25
# Split Lemma: {'lemma': 'שב'}, Entry:  <specialFont ]h> diath
# Split Verse Lemma: {'verse': {'verse': {'verse': '5'}}, 'lemma': [{'text': 'שב', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'שב'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'diath', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-26
# Split Lemma: {'lemma': 'ממנו'}, Entry:  <specialFont ]-*h[T> pron<subscript II><ref 28>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '5'}}}, 'lemma': [{'text': 'ממנו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ממנו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->', '<specialFont *h>', '<specialFont [>', '<specialFont T>'], 'reading': 'pron<ref 28>', 'cross_references': ['II'], 'sigla': ''}]
# Processing Entry ID: app-27
# Split Lemma: {'lemma': '6 אהיה'}, Entry:  <specialFont ]h[> <specialFont &>
# Split Verse Lemma: {'verse': {'verse': '6'}, 'lemma': [{'text': 'אהיה', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'אהיה'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont [>'], 'reading': '<specialFont &>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-28
# Split Lemma: {'lemma': 'שרשיו'}, Entry:  <specialFont *> num<ref 29>
# Split Verse Lemma: {'verse': {'verse': {'verse': '6'}}, 'lemma': [{'text': 'שרשיו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'שרשיו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>'], 'reading': 'num<ref 29>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-29
# Split Lemma: {'lemma': '7 ילכו'}, Entry:  <specialFont ]h[> <specialFont &>
# Split Verse Lemma: {'verse': {'verse': '7'}, 'lemma': [{'text': 'ילכו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ילכו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont [>'], 'reading': '<specialFont &>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-30
# Split Lemma: {'lemma': 'הודו<specialFont v>כזית', 'to_check': True}, Entry:  <specialFont ]> ὡς ἐλαία<specialFont ,>κατάκαρπος<ref 30> <specialFont +> <specialFont [>
# Split Verse Lemma: {'verse': {'verse': {'verse': '7'}}, 'lemma': [{'text': 'הודו<specialFont v>כזית', 'to_check': True, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'הודו'}, {'tag': 'lemma2', 'content': 'specialFont'}, {'tag': 'lemma3', 'content': 'v>כזית'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'ὡς ἐλαία<specialFont ,>κατάκαρπος<ref 30>', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-31
# Split Lemma: {'lemma': '(כ)לבנון'}, Entry:  <specialFont ]h> pr οἶνος<ref 31> | <specialFont T> כריח קטורת בסמיא<ref 32>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '7'}}}, 'lemma': [{'text': '(כ)לבנון', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(כ)'}, {'tag': 'lemma1', 'content': 'לבנון'}, {'tag': 'full_lemma', 'content': 'כלבנון'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'pr οἶνος<ref 31>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont T>'], 'reading': 'כריח קטורת בסמיא<ref 32>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-32
# Split Lemma: {'lemma': '8 ישבו'}, Entry:  <specialFont [> ܘܢܬܒܢܘܢ<ref 33>
# Split Verse Lemma: {'verse': {'verse': '8'}, 'lemma': [{'text': 'ישבו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ישבו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont [>'], 'reading': 'ܘܢܬܒܢܘܢ<ref 33>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-33
# Split Lemma: {'lemma': 'ישְׁבֵי'}, Entry:  <specialFont ]> καὶ καθιοῦνται<ref 34> = <specialFont [> <specialFont +> <specialFont T> | <specialFont ]h> + ἕκαστος<ref 35>
# Split Verse Lemma: {'verse': {'verse': {'verse': '8'}}, 'lemma': [{'text': 'ישְׁבֵי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ישְׁבֵי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'καὶ καθιοῦνται<ref 34>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'similar_variant', 'witnesses': ['<specialFont T>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'ἕκαστος<ref 35>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-34
# Split Lemma: {'lemma': 'יְחַיּוּ'}, Entry:  <specialFont ]h[Th> <specialFont &> | <specialFont ]> ζήσονται<ref 36> = <specialFont *[T-> | <specialFont ]-> + καὶ μεθυσθήσονται,<ref 37> <specialFont ]h> + καὶ στηριχθήσονται<ref 38>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '8'}}}, 'lemma': [{'text': 'יְחַיּוּ', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'יְחַיּוּ'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>', '<specialFont [>', '<specialFont Th>'], 'reading': '<specialFont &>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]>'], 'reading': 'ζήσονται<ref 36>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont *>', '<specialFont [>', '<specialFont T->'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]->'], 'reading': 'καὶ μεθυσθήσονται', 'cross_references': [], 'sigla': '+'}, {'classification': 'related_variant', 'witnesses': [], 'reading': '<ref 37> <specialFont ]h> + καὶ στηριχθήσονται<ref 38>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-35
# Split Lemma: {'lemma': 'ויפרחו'}, Entry:  <specialFont ]> pers<ref 39>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '8'}}}}, 'lemma': [{'text': 'ויפרחו', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ויפרחו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'pers<ref 39>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-36
# Split Lemma: {'lemma': 'זכרו<specialFont v>', 'to_check': True}, Entry:  <specialFont ],> | <specialFont ]h[T> pron<ref 40>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '8'}}}}}, 'lemma': [{'text': 'זכרו<specialFont v>', 'to_check': True, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'זכרו'}, {'tag': 'lemma2', 'content': 'specialFont'}, {'tag': 'lemma3', 'content': 'v>'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont ,>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]h>', '<specialFont [>', '<specialFont T>'], 'reading': 'pron<ref 40>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-37
# Split Lemma: {'lemma': '9 אפרים ... לי'}, Entry:  <specialFont ]> τῷ Εφραιμ ... αὐτῷ<ref 41>
# Split Verse Lemma: {'verse': {'verse': '9'}, 'lemma': [{'text': 'אפרים ... לי', 'to_check': False, 'ref': None}]}
# Processed Lemma: {'type': 'specific_range', 'parts': [{'tag': 'start lemma', 'content': 'אפרים'}, {'tag': 'end lemma', 'content': 'לי'}]}
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'τῷ Εφραιμ ... αὐτῷ<ref 41>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-38
# Split Lemma: {'lemma': 'לעצבים'}, Entry:  <specialFont ][> <ref 42><specialFont &>
# Split Verse Lemma: {'verse': {'verse': {'verse': '9'}}, 'lemma': [{'text': 'לעצבים', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'לעצבים'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>', '<specialFont [>'], 'reading': '<ref 42><specialFont &>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-39
# Split Lemma: {'lemma': 'עָנִיתי'}, Entry:  <specialFont ]> ἐταπείνωσα<ref 43> = <specialFont [>| <specialFont ]> + αὐτόν<ref 44> = <specialFont *h[>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': '9'}}}, 'lemma': [{'text': 'עָנִיתי', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'עָנִיתי'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'ἐταπείνωσα<ref 43>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont ]>'], 'reading': 'αὐτόν<ref 44>', 'cross_references': [], 'sigla': '+'}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont *h>', '<specialFont [>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-40
# Split Lemma: {'lemma': 'ו(אשורנו)'}, Entry:  <specialFont ]-> + ἐγώ<ref 45>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': '9'}}}}, 'lemma': [{'text': 'ו(אשורנו)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ו'}, {'tag': 'parenthesis', 'content': '(אשורנו)'}, {'tag': 'full_lemma', 'content': 'ואשורנו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': 'ἐγώ<ref 45>', 'cross_references': [], 'sigla': '+'}]
# Processing Entry ID: app-41
# Split Lemma: {'lemma': '(ו)אשור(נו)'}, Entry:  <specialFont ]-> κατισχύσω<ref 46> | <specialFont *> dirigam<ref 47> | <specialFont [> ܐܫܒܚ(ܝܘܗܝ)<ref 48>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '9'}}}}}, 'lemma': [{'text': '(ו)אשור(נו)', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'parenthesis', 'content': '(ו)'}, {'tag': 'lemma1', 'content': 'אשור'}, {'tag': 'parenthesis', 'content': '(נו)'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->'], 'reading': 'κατισχύσω<ref 46>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont *>'], 'reading': 'dirigam<ref 47>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont [>'], 'reading': 'ܐܫܒܚ(ܝܘܗܝ)<ref 48>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-42
# Split Lemma: {'lemma': '<specialFont ,אניv(ואשורנו)>', 'to_check': True}, Entry:  <specialFont *> <specialFont ,>ego<specialFont v> | <specialFont [> (ܐܫܒܚܝܘܗܝ)<ref 49><specialFont ,ܘܐܢܐ> = <specialFont ]h>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '9'}}}}}}, 'lemma': [{'text': '<specialFont ,אניv(ואשורנו)>', 'to_check': True, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'specialFont'}, {'tag': 'lemma2', 'content': ',אניv'}, {'tag': 'parenthesis', 'content': '(ואשורנו)'}, {'tag': 'lemma3', 'content': '>'}, {'tag': 'full_lemma', 'content': 'specialFont,אניv>ואשורנו'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont *>'], 'reading': '<specialFont ,>ego<specialFont v>', 'cross_references': [], 'sigla': ''}, {'classification': 'additional_variant', 'witnesses': ['<specialFont [>'], 'reading': '(ܐܫܒܚܝܘܗܝ)<ref 49><specialFont ,ܘܐܢܐ>', 'cross_references': [], 'sigla': ''}, {'classification': 'synonymous_variant', 'witnesses': ['<specialFont ]h>'], 'reading': '', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-43
# Split Lemma: {'lemma': 'כברוש', 'ref': '<ref 50>'}, Entry: <specialFont T> pr אעבדיניה<ref 51>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '9'}}}}}}}, 'lemma': [{'text': 'כברוש', 'to_check': False, 'ref': '<ref 50>'}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'כברוש'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont T>'], 'reading': 'pr אעבדיניה<ref 51>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-44
# Split Lemma: {'lemma': 'פריךָ'}, Entry:  <specialFont ]h> pron<ref 52>
# Split Verse Lemma: {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': {'verse': '9'}}}}}}}}, 'lemma': [{'text': 'פריךָ', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'פריךָ'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]h>'], 'reading': 'pron<ref 52>', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-45
# Split Lemma: {'lemma': '10 נבון'}, Entry:  <specialFont ]-[> connect
# Split Verse Lemma: {'verse': {'verse': '10'}, 'lemma': [{'text': 'נבון', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'נבון'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]->', '<specialFont [>'], 'reading': 'connect', 'cross_references': [], 'sigla': ''}]
# Processing Entry ID: app-46
# Split Lemma: {'lemma': 'ופשעים'}, Entry:  <specialFont ]> det
# Split Verse Lemma: {'verse': {'verse': {'verse': '10'}}, 'lemma': [{'text': 'ופשעים', 'to_check': False, 'ref': None}]}
# Processed Lemma: [{'tag': 'lemma1', 'content': 'ופשעים'}]
# Classified Entry: [{'classification': 'variant', 'witnesses': ['<specialFont ]>'], 'reading': 'det', 'cross_references': [], 'sigla': ''}]
# XML saved to flattened_verse_with_to_check.xml

# %%
df['Footnotes'][2]['footnote-10']
# Out:
# 'theol diffic <specialFont 7 > different solutions in Vrs (for similar enumeration cf <specialFont ][ > Dan 3<subscript 37−38 >); cf Rofé, FS Weinfeld, 135−149'

# %%
df['Main Text'][6]['app-56']
# Out:
# 'מזעם lex] <specialFont ]> ἀπαιδευσία<ref 61> = <specialFont |> <specialFont +> <specialFont [>'

# %%
split_verse_lemma(lemma['lemma'])
# Out:
# {'verse': {'verse': '4'}, 'lemma': 'זֶבַח'}

# %%
df['Footnotes'][1]['footnote-44']
# Out:
# 'והכרַתי, cf Zech 13<subscript 2 >; cf also v<subscript 20 > וכרתי'

# %%
df['Main Text'][3]['app-14']
# Out:
# 'כמריבי כהן]<ref 13> <specialFont ]> ὡς ἀντιλεγόμενος ἱερεύς<ref 14> | <specialFont [> ܐܝܟ ܟܗܢܐ ܡܬܚܪܐ<ref 15> | <specialFont T> נצן עם מלפיהון<ref 16> | <specialFont *> sicut hii qui contradicunt sacerdoti<ref 17> <specialFont +> <specialFont ~9>'

# %%
lemma, entry = split_full_entry(df['Main Text'][6]['app-56'])
parse_and_classify_entry(entry)
# Out:
# [{'classification': 'variant',
#   'witnesses': ['<specialFont ]>'],
#   'reading': 'ἀπαιδευσία<ref 61>',
#   'cross_references': [],
#   'sigla': ''},
#  {'classification': 'synonymous_variant',
#   'witnesses': ['<specialFont |>'],
#   'reading': '',
#   'cross_references': [],
#   'sigla': ''},
#  {'classification': 'similar_variant',
#   'witnesses': ['<specialFont [>'],
#   'reading': '',
#   'cross_references': [],
#   'sigla': ''}]

# %%
lemma
# Out:
# {'lemma': 'מזעם lex'}

# %%
process_lemma_lex(lemma['lemma'])
# Out:
# {'type': 'lex', 'text': [{'tag': 'lemma1', 'content': 'מזעם'}]}

# %%
process_lemma_lex(lemma['lemma'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 process_lemma_lex(lemma['lemma'])
#
# Cell In[30], line 99, in process_lemma_lex(lemma_text)
#      97 match = re.search(r'\blex', lemma_text, re.IGNORECASE)
#      98 if match:
# ---> 99     content = match.group(1).strip()
#     100     return {
#     101         'type': 'lex',
#     102         'content': process_lemma(content)
#     103     }
#     104 else:
#     105     # Fallback if "lex" is not followed by usable content
#
# IndexError: no such group

# %%
entry
# Out:
# ' <specialFont T> (ד)דָבַח<ref 9>'

# %%
import re
from lxml import etree

# %%
# Hebrew letter to numerical value (based on gematria)
hebrew_to_num = {
    'א': '1', 'ב': '2', 'ג': '3', 'ד': '4', 'ה': '5', 'ו': '6', 'ז': '7', 'ח': '8', 'ט': '9', 'י': '10',
    'כ': '20', 'ך': '20', 'ל': '30', 'מ': '40', 'ם': '40', 'נ': '50', 'ן': '50', 'ס': '60', 'ע': '70',
    'פ': '80', 'ף': '80', 'צ': '90', 'ץ': '90', 'ק': '100', 'ר': '200', 'ש': '300', 'ת': '400'
}

def convert_hebrew_to_num(hebrew_str):
    # Convert each Hebrew character to its corresponding number
    num_str = ''.join(hebrew_to_num.get(char, char) for char in hebrew_str)
    return num_str

# %%
def create_tei_xml_from_text(text_lines):
    root = etree.Element('TEI', xmlns="http://www.tei-c.org/ns/1.0")
    teiHeader = create_tei_header(root)
    text_element = etree.SubElement(root, 'text')
    body = etree.SubElement(text_element, 'body')

    current_chapter = None
    current_verse = None
    verse_counter = 1

    for line in text_lines:
        line = line.strip()
        print(f"Processing line: {line}")

        if line.startswith('פרק'):
            if current_chapter:
                close_chapter(current_chapter)
            chapter_letter = line.split()[1]
            chapter_num = convert_hebrew_to_num(chapter_letter)
            current_chapter = etree.SubElement(body, 'div', type='chapter', n=chapter_num)
            verse_counter = 1
            print(f"Started chapter {chapter_num}")
        elif line:
            # Ensure we have a valid chapter before processing verses
            if current_chapter is None:
                print("Error: No chapter started before encountering text.")
                continue
            # Process each line for verses and markers
            process_text(line, current_chapter, chapter_num, verse_counter)
            verse_counter += 1

    if current_chapter:
        close_chapter(current_chapter)

    return etree.tostring(root, pretty_print=True, encoding='UTF-8', xml_declaration=True)

def create_tei_header(root):
    teiHeader = etree.SubElement(root, 'teiHeader')
    fileDesc = etree.SubElement(teiHeader, 'fileDesc')
    titleStmt = etree.SubElement(fileDesc, 'titleStmt')
    title = etree.SubElement(titleStmt, 'title')
    title.text = "Book of Hosea"
    publicationStmt = etree.SubElement(titleStmt, 'publicationStmt')
    publisher = etree.SubElement(publicationStmt, 'publisher')
    publisher.text = "Digital Edition"
    date = etree.SubElement(publicationStmt, 'date')
    date.text = "2024"
    sourceDesc = etree.SubElement(fileDesc, 'sourceDesc')
    source = etree.SubElement(sourceDesc, 'source')
    source.text = "Manuscript"
    return teiHeader

def close_chapter(chapter_element):
    print(f"Closed chapter {chapter_element.get('n')}")

def process_text(text, current_chapter, chapter_num, verse_counter):
    global word_counter  # This keeps track of the word within the verse

    # Reset the word counter for each new verse
    word_counter = 0  # Restart the word counter for each verse
    
    # Split the text into words and special markers
    parts = re.split(r'(\s+|:|\[פ\]|\[ס\]|\$[1]|־|׀)', text)

    current_verse = etree.SubElement(current_chapter, 'lg', type='verse', n=f'{chapter_num}:{verse_counter}')
    print(f"Started verse {verse_counter} in chapter {chapter_num}")

    for part in parts:
        part = part.strip()  # Remove unnecessary whitespace
        if not part:
            continue  # Skip empty parts

        if part in [':', '[פ]', '[ס]', '$1', '׀', '־']:
            add_special_marker(part, current_verse)
            if part in [':', '$1']:  # If a verse-ending marker is found
                verse_counter += 1
                current_verse = etree.SubElement(current_chapter, 'lg', type='verse', n=f'{chapter_num}:{verse_counter}')
                print(f"Started new verse {verse_counter} in chapter {chapter_num}")
                word_counter = 0  # Reset the word counter when a new verse starts

        else:
            # Treat overdots as part of the word, so they get processed here
            process_word(part, current_verse, chapter_num, verse_counter)

    return verse_counter  # Return the updated verse counter



def process_word(word, lg_element, chapter_num, verse_counter):
    global word_counter
    word_counter += 1  # Increment the counter for each word

    # Split the word based on the special overdots ($2, $3, $4, $5)
    parts = re.split(r'(\$[2-5])', word)  # Keep the overdot marker as part of the split

    # Create the <w> element for the word, including a unique ID with chapter and verse information
    w_element = etree.SubElement(lg_element, 'w', id=f'word_{chapter_num}_{verse_counter}_{word_counter}')
    print(f"Created <w> element with ID: word_{chapter_num}_{verse_counter}_{word_counter}")

    w_text = ""  # Buffer for word text

    for part in parts:
        if re.match(r'\$[2-5]', part):
            # Append the buffer to the <w> element before the overdot
            if w_text:
                w_element.text = (w_element.text or '') + w_text  # Set or append to the <w>'s text
                print(f"Appending text before overdot: '{w_text}' to <w> element")
                w_text = ""  # Reset buffer

            # Insert the overdot as a sub-element inside the same <w> element
            overdot_type = part[-1]  # Get the overdot type (2, 3, 4, or 5)
            overdot_element = etree.SubElement(w_element, 'overdot', type=overdot_type)
            print(f"Overdot encountered: {part} - Added overdot type {overdot_type} inside <w> element")
        else:
            # Accumulate text for the word
            w_text += part
            print(f"Accumulating text: '{part}' - Current buffer: '{w_text}'")

    # Append the remaining text after the overdot using the .tail property
    if w_text:
        if w_element.text:  # If text already exists, add the remaining text after the overdot
            overdot_element.tail = w_text  # Place text after the overdot
            print(f"Appending remaining text after overdot: '{w_text}' to <w> element")
        else:
            w_element.text = w_text  # If no text exists, just set the main text

    print(f"--- Final word text: '{w_element.text}', with ID: word_{chapter_num}_{verse_counter}_{word_counter} ---")

   
def add_special_marker(marker, current_verse):
    if marker == ':':
        verse_end = etree.SubElement(current_verse, 'verseEnd', type='standard')
        verse_end.text = marker
        print("Added standard verse end.")
    elif marker == '$1':
        verse_end = etree.SubElement(current_verse, 'verseEnd', type='special')
        verse_end.text = marker
        print("Added special verse end.")
    elif marker in ['[פ]', '[ס]', '׀', '־']:
        punctuation = etree.SubElement(current_verse, 'punctuation', type=marker.strip('[]'))
        punctuation.text = marker
        print(f"Added special marker: {marker}")

# Example usage
with open('hosea_full.txt', 'r', encoding='utf-8') as file:
    text_lines = file.readlines()

tei_xml = create_tei_xml_from_text(text_lines)

with open('output.tei.xml', 'wb') as output_file:
    output_file.write(tei_xml)
# Out:
# Processing line: ספר הושע
# Error: No chapter started before encountering text.
# Processing line: פרק א
# Started chapter 1
# Processing line: דְּבַר־יְהוָ֣ה ׀ אֲשֶׁ֣ר הָיָ֗ה אֶל־הוֹשֵׁעַ֙ בֶּן־בְּאֵ$2רִ֔י בִּימֵ֨י עֻזִּיָּ֥ה יוֹתָ֛ם אָחָ֥ז יְחִזְקִ$2יָּ֖ה מַלְכֵ֣י יְהוּדָ֑ה וּבִימֵ֛י יָרָבְעָ֥ם בֶּן־יוֹאָ֖שׁ מֶ֥לֶךְ יִשְׂרָאֵֽל$1 תְּחִלַּ֥$2ת דִּבֶּר־יְהוָ֖ה בְּ$2הוֹשֵׁ֑עַ     [פ]     וַיֹּ֨אמֶר יְהוָ֜ה אֶל־הוֹשֵׁ֗עַ לֵ֣ךְ קַח־לְךָ֞ אֵ֤שֶׁת זְנוּנִים֙ וְיַלְ$2דֵ֣י זְנוּנִ֔ים כִּֽי־זָנֹ֤ה$2 תִזְנֶה֙ הָאָ֔רֶץ מֵאַחֲרֵ֖י יְהוָֽה: וַיֵּ֙לֶךְ֙ וַיִּקַּ֔ח אֶת־גֹּ֖מֶר בַּת־דִּבְ$2לָ֑יִם וַתַּ֥הַר וַתֵּלֶד־$2ל֖וֹ $4בֵּֽן: וַיֹּ֤אמֶר $2יְהוָה֙ $4אֵלָ֔יו קְרָ֥א שְׁמ֖וֹ יִזְרְעֶ֑אל כִּי־ע֣וֹד מְעַ֗ט וּפָ֨קַדְתִּ֜י אֶת־דְּמֵ֤י יִזְרְעֶאל֙ עַל־בֵּ֣ית יֵה֔וּא וְהִ֨שְׁבַּתִּ֔י מַמְ$2לְכ֖וּת בֵּ֥ית יִשְׂרָאֵֽל: וְהָיָ֖ה בַּיּ֣וֹם הַה֑וּא וְשָֽׁבַרְתִּי֙ אֶת־קֶ֣שֶׁת יִשְׂרָאֵ֔ל בְּעֵ֖מֶק יִזְרְעֶֽאל$1 וַתַּ֤הַר $2עוֹד֙ $4וַתֵּ֣לֶד בַּ֔ת וַיֹּ֣אמֶר ל֔וֹ קְרָ֥א שְׁמָ֖הּ לֹ֣א רֻחָ֑מָה כִּי֩ לֹ֨א אוֹסִ֜יף ע֗וֹד אֲרַחֵם֙ אֶת־בֵּ֣ית יִשְׂרָאֵ֔ל כִּֽי־נָשֹׂ֥א אֶשָּׂ֖א לָהֶֽם: וְאֶת־בֵּ֤ית יְהוּדָה֙ אֲרַחֵ֔ם וְהוֹשַׁעְ$2תִּ֖ים בַּיהוָ֣ה אֱלֹהֵיהֶ֑ם וְלֹ֣א אוֹשִׁיעֵ֗ם בְּקֶ֤$2שֶׁת וּבְחֶ֙רֶב֙ וּבְמִלְ$2חָמָ֔ה בְּסוּסִ֖ים וּבְפָרָשִֽׁים$1 וַתִּגְמֹ֖ל אֶת־לֹ֣א רֻחָ֑מָה וַתַּ֖הַר וַתֵּ֥לֶד בֵּֽן: וַיֹּ֕אמֶר קְרָ֥א שְׁמ֖וֹ לֹ֣א עַמִּ֑י כִּ֤י אַתֶּם֙ לֹ֣א עַמִּ֔י וְאָנֹכִ֖י לֹא־אֶהְיֶ֥ה לָכֶֽם:     [פ]
# Started verse 1 in chapter 1
# Created <w> element with ID: word_1_1_1
# Accumulating text: 'דְּבַר' - Current buffer: 'דְּבַר'
# --- Final word text: 'דְּבַר', with ID: word_1_1_1 ---
# Added special marker: ־
# Created <w> element with ID: word_1_1_2
# Accumulating text: 'יְהוָ֣ה' - Current buffer: 'יְהוָ֣ה'
# --- Final word text: 'יְהוָ֣ה', with ID: word_1_1_2 ---
# Added special marker: ׀
# Created <w> element with ID: word_1_1_3
# Accumulating text: 'אֲשֶׁ֣ר' - Current buffer: 'אֲשֶׁ֣ר'
# --- Final word text: 'אֲשֶׁ֣ר', with ID: word_1_1_3 ---
# Created <w> element with ID: word_1_1_4
# Accumulating text: 'הָיָ֗ה' - Current buffer: 'הָיָ֗ה'
# --- Final word text: 'הָיָ֗ה', with ID: word_1_1_4 ---
# Created <w> element with ID: word_1_1_5
# Accumulating text: 'אֶל' - Current buffer: 'אֶל'
# --- Final word text: 'אֶל', with ID: word_1_1_5 ---
# Added special marker: ־
# Created <w> element with ID: word_1_1_6
# Accumulating text: 'הוֹשֵׁעַ֙' - Current buffer: 'הוֹשֵׁעַ֙'
# --- Final word text: 'הוֹשֵׁעַ֙', with ID: word_1_1_6 ---
# Created <w> element with ID: word_1_1_7
# Accumulating text: 'בֶּן' - Current buffer: 'בֶּן'
# --- Final word text: 'בֶּן', with ID: word_1_1_7 ---
# Added special marker: ־
# Created <w> element with ID: word_1_1_8
# Accumulating text: 'בְּאֵ' - Current buffer: 'בְּאֵ'
# Appending text before overdot: 'בְּאֵ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'רִ֔י' - Current buffer: 'רִ֔י'
# Appending remaining text after overdot: 'רִ֔י' to <w> element
# --- Final word text: 'בְּאֵ', with ID: word_1_1_8 ---
# Created <w> element with ID: word_1_1_9
# Accumulating text: 'בִּימֵ֨י' - Current buffer: 'בִּימֵ֨י'
# --- Final word text: 'בִּימֵ֨י', with ID: word_1_1_9 ---
# Created <w> element with ID: word_1_1_10
# Accumulating text: 'עֻזִּיָּ֥ה' - Current buffer: 'עֻזִּיָּ֥ה'
# --- Final word text: 'עֻזִּיָּ֥ה', with ID: word_1_1_10 ---
# Created <w> element with ID: word_1_1_11
# Accumulating text: 'יוֹתָ֛ם' - Current buffer: 'יוֹתָ֛ם'
# --- Final word text: 'יוֹתָ֛ם', with ID: word_1_1_11 ---
# Created <w> element with ID: word_1_1_12
# Accumulating text: 'אָחָ֥ז' - Current buffer: 'אָחָ֥ז'
# --- Final word text: 'אָחָ֥ז', with ID: word_1_1_12 ---
# Created <w> element with ID: word_1_1_13
# Accumulating text: 'יְחִזְקִ' - Current buffer: 'יְחִזְקִ'
# Appending text before overdot: 'יְחִזְקִ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'יָּ֖ה' - Current buffer: 'יָּ֖ה'
# Appending remaining text after overdot: 'יָּ֖ה' to <w> element
# --- Final word text: 'יְחִזְקִ', with ID: word_1_1_13 ---
# Created <w> element with ID: word_1_1_14
# Accumulating text: 'מַלְכֵ֣י' - Current buffer: 'מַלְכֵ֣י'
# --- Final word text: 'מַלְכֵ֣י', with ID: word_1_1_14 ---
# Created <w> element with ID: word_1_1_15
# Accumulating text: 'יְהוּדָ֑ה' - Current buffer: 'יְהוּדָ֑ה'
# --- Final word text: 'יְהוּדָ֑ה', with ID: word_1_1_15 ---
# Created <w> element with ID: word_1_1_16
# Accumulating text: 'וּבִימֵ֛י' - Current buffer: 'וּבִימֵ֛י'
# --- Final word text: 'וּבִימֵ֛י', with ID: word_1_1_16 ---
# Created <w> element with ID: word_1_1_17
# Accumulating text: 'יָרָבְעָ֥ם' - Current buffer: 'יָרָבְעָ֥ם'
# --- Final word text: 'יָרָבְעָ֥ם', with ID: word_1_1_17 ---
# Created <w> element with ID: word_1_1_18
# Accumulating text: 'בֶּן' - Current buffer: 'בֶּן'
# --- Final word text: 'בֶּן', with ID: word_1_1_18 ---
# Added special marker: ־
# Created <w> element with ID: word_1_1_19
# Accumulating text: 'יוֹאָ֖שׁ' - Current buffer: 'יוֹאָ֖שׁ'
# --- Final word text: 'יוֹאָ֖שׁ', with ID: word_1_1_19 ---
# Created <w> element with ID: word_1_1_20
# Accumulating text: 'מֶ֥לֶךְ' - Current buffer: 'מֶ֥לֶךְ'
# --- Final word text: 'מֶ֥לֶךְ', with ID: word_1_1_20 ---
# Created <w> element with ID: word_1_1_21
# Accumulating text: 'יִשְׂרָאֵֽל' - Current buffer: 'יִשְׂרָאֵֽל'
# --- Final word text: 'יִשְׂרָאֵֽל', with ID: word_1_1_21 ---
# Added special verse end.
# Started new verse 2 in chapter 1
# Created <w> element with ID: word_1_2_1
# Accumulating text: 'תְּחִלַּ֥' - Current buffer: 'תְּחִלַּ֥'
# Appending text before overdot: 'תְּחִלַּ֥' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ת' - Current buffer: 'ת'
# Appending remaining text after overdot: 'ת' to <w> element
# --- Final word text: 'תְּחִלַּ֥', with ID: word_1_2_1 ---
# Created <w> element with ID: word_1_2_2
# Accumulating text: 'דִּבֶּר' - Current buffer: 'דִּבֶּר'
# --- Final word text: 'דִּבֶּר', with ID: word_1_2_2 ---
# Added special marker: ־
# Created <w> element with ID: word_1_2_3
# Accumulating text: 'יְהוָ֖ה' - Current buffer: 'יְהוָ֖ה'
# --- Final word text: 'יְהוָ֖ה', with ID: word_1_2_3 ---
# Created <w> element with ID: word_1_2_4
# Accumulating text: 'בְּ' - Current buffer: 'בְּ'
# Appending text before overdot: 'בְּ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'הוֹשֵׁ֑עַ' - Current buffer: 'הוֹשֵׁ֑עַ'
# Appending remaining text after overdot: 'הוֹשֵׁ֑עַ' to <w> element
# --- Final word text: 'בְּ', with ID: word_1_2_4 ---
# Added special marker: [פ]
# Created <w> element with ID: word_1_2_5
# Accumulating text: 'וַיֹּ֨אמֶר' - Current buffer: 'וַיֹּ֨אמֶר'
# --- Final word text: 'וַיֹּ֨אמֶר', with ID: word_1_2_5 ---
# Created <w> element with ID: word_1_2_6
# Accumulating text: 'יְהוָ֜ה' - Current buffer: 'יְהוָ֜ה'
# --- Final word text: 'יְהוָ֜ה', with ID: word_1_2_6 ---
# Created <w> element with ID: word_1_2_7
# Accumulating text: 'אֶל' - Current buffer: 'אֶל'
# --- Final word text: 'אֶל', with ID: word_1_2_7 ---
# Added special marker: ־
# Created <w> element with ID: word_1_2_8
# Accumulating text: 'הוֹשֵׁ֗עַ' - Current buffer: 'הוֹשֵׁ֗עַ'
# --- Final word text: 'הוֹשֵׁ֗עַ', with ID: word_1_2_8 ---
# Created <w> element with ID: word_1_2_9
# Accumulating text: 'לֵ֣ךְ' - Current buffer: 'לֵ֣ךְ'
# --- Final word text: 'לֵ֣ךְ', with ID: word_1_2_9 ---
# Created <w> element with ID: word_1_2_10
# Accumulating text: 'קַח' - Current buffer: 'קַח'
# --- Final word text: 'קַח', with ID: word_1_2_10 ---
# Added special marker: ־
# Created <w> element with ID: word_1_2_11
# Accumulating text: 'לְךָ֞' - Current buffer: 'לְךָ֞'
# --- Final word text: 'לְךָ֞', with ID: word_1_2_11 ---
# Created <w> element with ID: word_1_2_12
# Accumulating text: 'אֵ֤שֶׁת' - Current buffer: 'אֵ֤שֶׁת'
# --- Final word text: 'אֵ֤שֶׁת', with ID: word_1_2_12 ---
# Created <w> element with ID: word_1_2_13
# Accumulating text: 'זְנוּנִים֙' - Current buffer: 'זְנוּנִים֙'
# --- Final word text: 'זְנוּנִים֙', with ID: word_1_2_13 ---
# Created <w> element with ID: word_1_2_14
# Accumulating text: 'וְיַלְ' - Current buffer: 'וְיַלְ'
# Appending text before overdot: 'וְיַלְ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'דֵ֣י' - Current buffer: 'דֵ֣י'
# Appending remaining text after overdot: 'דֵ֣י' to <w> element
# --- Final word text: 'וְיַלְ', with ID: word_1_2_14 ---
# Created <w> element with ID: word_1_2_15
# Accumulating text: 'זְנוּנִ֔ים' - Current buffer: 'זְנוּנִ֔ים'
# --- Final word text: 'זְנוּנִ֔ים', with ID: word_1_2_15 ---
# Created <w> element with ID: word_1_2_16
# Accumulating text: 'כִּֽי' - Current buffer: 'כִּֽי'
# --- Final word text: 'כִּֽי', with ID: word_1_2_16 ---
# Added special marker: ־
# Created <w> element with ID: word_1_2_17
# Accumulating text: 'זָנֹ֤ה' - Current buffer: 'זָנֹ֤ה'
# Appending text before overdot: 'זָנֹ֤ה' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: '' - Current buffer: ''
# --- Final word text: 'זָנֹ֤ה', with ID: word_1_2_17 ---
# Created <w> element with ID: word_1_2_18
# Accumulating text: 'תִזְנֶה֙' - Current buffer: 'תִזְנֶה֙'
# --- Final word text: 'תִזְנֶה֙', with ID: word_1_2_18 ---
# Created <w> element with ID: word_1_2_19
# Accumulating text: 'הָאָ֔רֶץ' - Current buffer: 'הָאָ֔רֶץ'
# --- Final word text: 'הָאָ֔רֶץ', with ID: word_1_2_19 ---
# Created <w> element with ID: word_1_2_20
# Accumulating text: 'מֵאַחֲרֵ֖י' - Current buffer: 'מֵאַחֲרֵ֖י'
# --- Final word text: 'מֵאַחֲרֵ֖י', with ID: word_1_2_20 ---
# Created <w> element with ID: word_1_2_21
# Accumulating text: 'יְהוָֽה' - Current buffer: 'יְהוָֽה'
# --- Final word text: 'יְהוָֽה', with ID: word_1_2_21 ---
# Added standard verse end.
# Started new verse 3 in chapter 1
# Created <w> element with ID: word_1_3_1
# Accumulating text: 'וַיֵּ֙לֶךְ֙' - Current buffer: 'וַיֵּ֙לֶךְ֙'
# --- Final word text: 'וַיֵּ֙לֶךְ֙', with ID: word_1_3_1 ---
# Created <w> element with ID: word_1_3_2
# Accumulating text: 'וַיִּקַּ֔ח' - Current buffer: 'וַיִּקַּ֔ח'
# --- Final word text: 'וַיִּקַּ֔ח', with ID: word_1_3_2 ---
# Created <w> element with ID: word_1_3_3
# Accumulating text: 'אֶת' - Current buffer: 'אֶת'
# --- Final word text: 'אֶת', with ID: word_1_3_3 ---
# Added special marker: ־
# Created <w> element with ID: word_1_3_4
# Accumulating text: 'גֹּ֖מֶר' - Current buffer: 'גֹּ֖מֶר'
# --- Final word text: 'גֹּ֖מֶר', with ID: word_1_3_4 ---
# Created <w> element with ID: word_1_3_5
# Accumulating text: 'בַּת' - Current buffer: 'בַּת'
# --- Final word text: 'בַּת', with ID: word_1_3_5 ---
# Added special marker: ־
# Created <w> element with ID: word_1_3_6
# Accumulating text: 'דִּבְ' - Current buffer: 'דִּבְ'
# Appending text before overdot: 'דִּבְ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'לָ֑יִם' - Current buffer: 'לָ֑יִם'
# Appending remaining text after overdot: 'לָ֑יִם' to <w> element
# --- Final word text: 'דִּבְ', with ID: word_1_3_6 ---
# Created <w> element with ID: word_1_3_7
# Accumulating text: 'וַתַּ֥הַר' - Current buffer: 'וַתַּ֥הַר'
# --- Final word text: 'וַתַּ֥הַר', with ID: word_1_3_7 ---
# Created <w> element with ID: word_1_3_8
# Accumulating text: 'וַתֵּלֶד' - Current buffer: 'וַתֵּלֶד'
# --- Final word text: 'וַתֵּלֶד', with ID: word_1_3_8 ---
# Added special marker: ־
# Created <w> element with ID: word_1_3_9
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ל֖וֹ' - Current buffer: 'ל֖וֹ'
# --- Final word text: 'ל֖וֹ', with ID: word_1_3_9 ---
# Created <w> element with ID: word_1_3_10
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $4 - Added overdot type 4 inside <w> element
# Accumulating text: 'בֵּֽן' - Current buffer: 'בֵּֽן'
# --- Final word text: 'בֵּֽן', with ID: word_1_3_10 ---
# Added standard verse end.
# Started new verse 4 in chapter 1
# Created <w> element with ID: word_1_4_1
# Accumulating text: 'וַיֹּ֤אמֶר' - Current buffer: 'וַיֹּ֤אמֶר'
# --- Final word text: 'וַיֹּ֤אמֶר', with ID: word_1_4_1 ---
# Created <w> element with ID: word_1_4_2
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'יְהוָה֙' - Current buffer: 'יְהוָה֙'
# --- Final word text: 'יְהוָה֙', with ID: word_1_4_2 ---
# Created <w> element with ID: word_1_4_3
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $4 - Added overdot type 4 inside <w> element
# Accumulating text: 'אֵלָ֔יו' - Current buffer: 'אֵלָ֔יו'
# --- Final word text: 'אֵלָ֔יו', with ID: word_1_4_3 ---
# Created <w> element with ID: word_1_4_4
# Accumulating text: 'קְרָ֥א' - Current buffer: 'קְרָ֥א'
# --- Final word text: 'קְרָ֥א', with ID: word_1_4_4 ---
# Created <w> element with ID: word_1_4_5
# Accumulating text: 'שְׁמ֖וֹ' - Current buffer: 'שְׁמ֖וֹ'
# --- Final word text: 'שְׁמ֖וֹ', with ID: word_1_4_5 ---
# Created <w> element with ID: word_1_4_6
# Accumulating text: 'יִזְרְעֶ֑אל' - Current buffer: 'יִזְרְעֶ֑אל'
# --- Final word text: 'יִזְרְעֶ֑אל', with ID: word_1_4_6 ---
# Created <w> element with ID: word_1_4_7
# Accumulating text: 'כִּי' - Current buffer: 'כִּי'
# --- Final word text: 'כִּי', with ID: word_1_4_7 ---
# Added special marker: ־
# Created <w> element with ID: word_1_4_8
# Accumulating text: 'ע֣וֹד' - Current buffer: 'ע֣וֹד'
# --- Final word text: 'ע֣וֹד', with ID: word_1_4_8 ---
# Created <w> element with ID: word_1_4_9
# Accumulating text: 'מְעַ֗ט' - Current buffer: 'מְעַ֗ט'
# --- Final word text: 'מְעַ֗ט', with ID: word_1_4_9 ---
# Created <w> element with ID: word_1_4_10
# Accumulating text: 'וּפָ֨קַדְתִּ֜י' - Current buffer: 'וּפָ֨קַדְתִּ֜י'
# --- Final word text: 'וּפָ֨קַדְתִּ֜י', with ID: word_1_4_10 ---
# Created <w> element with ID: word_1_4_11
# Accumulating text: 'אֶת' - Current buffer: 'אֶת'
# --- Final word text: 'אֶת', with ID: word_1_4_11 ---
# Added special marker: ־
# Created <w> element with ID: word_1_4_12
# Accumulating text: 'דְּמֵ֤י' - Current buffer: 'דְּמֵ֤י'
# --- Final word text: 'דְּמֵ֤י', with ID: word_1_4_12 ---
# Created <w> element with ID: word_1_4_13
# Accumulating text: 'יִזְרְעֶאל֙' - Current buffer: 'יִזְרְעֶאל֙'
# --- Final word text: 'יִזְרְעֶאל֙', with ID: word_1_4_13 ---
# Created <w> element with ID: word_1_4_14
# Accumulating text: 'עַל' - Current buffer: 'עַל'
# --- Final word text: 'עַל', with ID: word_1_4_14 ---
# Added special marker: ־
# Created <w> element with ID: word_1_4_15
# Accumulating text: 'בֵּ֣ית' - Current buffer: 'בֵּ֣ית'
# --- Final word text: 'בֵּ֣ית', with ID: word_1_4_15 ---
# Created <w> element with ID: word_1_4_16
# Accumulating text: 'יֵה֔וּא' - Current buffer: 'יֵה֔וּא'
# --- Final word text: 'יֵה֔וּא', with ID: word_1_4_16 ---
# Created <w> element with ID: word_1_4_17
# Accumulating text: 'וְהִ֨שְׁבַּתִּ֔י' - Current buffer: 'וְהִ֨שְׁבַּתִּ֔י'
# --- Final word text: 'וְהִ֨שְׁבַּתִּ֔י', with ID: word_1_4_17 ---
# Created <w> element with ID: word_1_4_18
# Accumulating text: 'מַמְ' - Current buffer: 'מַמְ'
# Appending text before overdot: 'מַמְ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'לְכ֖וּת' - Current buffer: 'לְכ֖וּת'
# Appending remaining text after overdot: 'לְכ֖וּת' to <w> element
# --- Final word text: 'מַמְ', with ID: word_1_4_18 ---
# Created <w> element with ID: word_1_4_19
# Accumulating text: 'בֵּ֥ית' - Current buffer: 'בֵּ֥ית'
# --- Final word text: 'בֵּ֥ית', with ID: word_1_4_19 ---
# Created <w> element with ID: word_1_4_20
# Accumulating text: 'יִשְׂרָאֵֽל' - Current buffer: 'יִשְׂרָאֵֽל'
# --- Final word text: 'יִשְׂרָאֵֽל', with ID: word_1_4_20 ---
# Added standard verse end.
# Started new verse 5 in chapter 1
# Created <w> element with ID: word_1_5_1
# Accumulating text: 'וְהָיָ֖ה' - Current buffer: 'וְהָיָ֖ה'
# --- Final word text: 'וְהָיָ֖ה', with ID: word_1_5_1 ---
# Created <w> element with ID: word_1_5_2
# Accumulating text: 'בַּיּ֣וֹם' - Current buffer: 'בַּיּ֣וֹם'
# --- Final word text: 'בַּיּ֣וֹם', with ID: word_1_5_2 ---
# Created <w> element with ID: word_1_5_3
# Accumulating text: 'הַה֑וּא' - Current buffer: 'הַה֑וּא'
# --- Final word text: 'הַה֑וּא', with ID: word_1_5_3 ---
# Created <w> element with ID: word_1_5_4
# Accumulating text: 'וְשָֽׁבַרְתִּי֙' - Current buffer: 'וְשָֽׁבַרְתִּי֙'
# --- Final word text: 'וְשָֽׁבַרְתִּי֙', with ID: word_1_5_4 ---
# Created <w> element with ID: word_1_5_5
# Accumulating text: 'אֶת' - Current buffer: 'אֶת'
# --- Final word text: 'אֶת', with ID: word_1_5_5 ---
# Added special marker: ־
# Created <w> element with ID: word_1_5_6
# Accumulating text: 'קֶ֣שֶׁת' - Current buffer: 'קֶ֣שֶׁת'
# --- Final word text: 'קֶ֣שֶׁת', with ID: word_1_5_6 ---
# Created <w> element with ID: word_1_5_7
# Accumulating text: 'יִשְׂרָאֵ֔ל' - Current buffer: 'יִשְׂרָאֵ֔ל'
# --- Final word text: 'יִשְׂרָאֵ֔ל', with ID: word_1_5_7 ---
# Created <w> element with ID: word_1_5_8
# Accumulating text: 'בְּעֵ֖מֶק' - Current buffer: 'בְּעֵ֖מֶק'
# --- Final word text: 'בְּעֵ֖מֶק', with ID: word_1_5_8 ---
# Created <w> element with ID: word_1_5_9
# Accumulating text: 'יִזְרְעֶֽאל' - Current buffer: 'יִזְרְעֶֽאל'
# --- Final word text: 'יִזְרְעֶֽאל', with ID: word_1_5_9 ---
# Added special verse end.
# Started new verse 6 in chapter 1
# Created <w> element with ID: word_1_6_1
# Accumulating text: 'וַתַּ֤הַר' - Current buffer: 'וַתַּ֤הַר'
# --- Final word text: 'וַתַּ֤הַר', with ID: word_1_6_1 ---
# Created <w> element with ID: word_1_6_2
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'עוֹד֙' - Current buffer: 'עוֹד֙'
# --- Final word text: 'עוֹד֙', with ID: word_1_6_2 ---
# Created <w> element with ID: word_1_6_3
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $4 - Added overdot type 4 inside <w> element
# Accumulating text: 'וַתֵּ֣לֶד' - Current buffer: 'וַתֵּ֣לֶד'
# --- Final word text: 'וַתֵּ֣לֶד', with ID: word_1_6_3 ---
# Created <w> element with ID: word_1_6_4
# Accumulating text: 'בַּ֔ת' - Current buffer: 'בַּ֔ת'
# --- Final word text: 'בַּ֔ת', with ID: word_1_6_4 ---
# Created <w> element with ID: word_1_6_5
# Accumulating text: 'וַיֹּ֣אמֶר' - Current buffer: 'וַיֹּ֣אמֶר'
# --- Final word text: 'וַיֹּ֣אמֶר', with ID: word_1_6_5 ---
# Created <w> element with ID: word_1_6_6
# Accumulating text: 'ל֔וֹ' - Current buffer: 'ל֔וֹ'
# --- Final word text: 'ל֔וֹ', with ID: word_1_6_6 ---
# Created <w> element with ID: word_1_6_7
# Accumulating text: 'קְרָ֥א' - Current buffer: 'קְרָ֥א'
# --- Final word text: 'קְרָ֥א', with ID: word_1_6_7 ---
# Created <w> element with ID: word_1_6_8
# Accumulating text: 'שְׁמָ֖הּ' - Current buffer: 'שְׁמָ֖הּ'
# --- Final word text: 'שְׁמָ֖הּ', with ID: word_1_6_8 ---
# Created <w> element with ID: word_1_6_9
# Accumulating text: 'לֹ֣א' - Current buffer: 'לֹ֣א'
# --- Final word text: 'לֹ֣א', with ID: word_1_6_9 ---
# Created <w> element with ID: word_1_6_10
# Accumulating text: 'רֻחָ֑מָה' - Current buffer: 'רֻחָ֑מָה'
# --- Final word text: 'רֻחָ֑מָה', with ID: word_1_6_10 ---
# Created <w> element with ID: word_1_6_11
# Accumulating text: 'כִּי֩' - Current buffer: 'כִּי֩'
# --- Final word text: 'כִּי֩', with ID: word_1_6_11 ---
# Created <w> element with ID: word_1_6_12
# Accumulating text: 'לֹ֨א' - Current buffer: 'לֹ֨א'
# --- Final word text: 'לֹ֨א', with ID: word_1_6_12 ---
# Created <w> element with ID: word_1_6_13
# Accumulating text: 'אוֹסִ֜יף' - Current buffer: 'אוֹסִ֜יף'
# --- Final word text: 'אוֹסִ֜יף', with ID: word_1_6_13 ---
# Created <w> element with ID: word_1_6_14
# Accumulating text: 'ע֗וֹד' - Current buffer: 'ע֗וֹד'
# --- Final word text: 'ע֗וֹד', with ID: word_1_6_14 ---
# Created <w> element with ID: word_1_6_15
# Accumulating text: 'אֲרַחֵם֙' - Current buffer: 'אֲרַחֵם֙'
# --- Final word text: 'אֲרַחֵם֙', with ID: word_1_6_15 ---
# Created <w> element with ID: word_1_6_16
# Accumulating text: 'אֶת' - Current buffer: 'אֶת'
# --- Final word text: 'אֶת', with ID: word_1_6_16 ---
# Added special marker: ־
# Created <w> element with ID: word_1_6_17
# Accumulating text: 'בֵּ֣ית' - Current buffer: 'בֵּ֣ית'
# --- Final word text: 'בֵּ֣ית', with ID: word_1_6_17 ---
# Created <w> element with ID: word_1_6_18
# Accumulating text: 'יִשְׂרָאֵ֔ל' - Current buffer: 'יִשְׂרָאֵ֔ל'
# --- Final word text: 'יִשְׂרָאֵ֔ל', with ID: word_1_6_18 ---
# Created <w> element with ID: word_1_6_19
# Accumulating text: 'כִּֽי' - Current buffer: 'כִּֽי'
# --- Final word text: 'כִּֽי', with ID: word_1_6_19 ---
# Added special marker: ־
# Created <w> element with ID: word_1_6_20
# Accumulating text: 'נָשֹׂ֥א' - Current buffer: 'נָשֹׂ֥א'
# --- Final word text: 'נָשֹׂ֥א', with ID: word_1_6_20 ---
# Created <w> element with ID: word_1_6_21
# Accumulating text: 'אֶשָּׂ֖א' - Current buffer: 'אֶשָּׂ֖א'
# --- Final word text: 'אֶשָּׂ֖א', with ID: word_1_6_21 ---
# Created <w> element with ID: word_1_6_22
# Accumulating text: 'לָהֶֽם' - Current buffer: 'לָהֶֽם'
# --- Final word text: 'לָהֶֽם', with ID: word_1_6_22 ---
# Added standard verse end.
# Started new verse 7 in chapter 1
# Created <w> element with ID: word_1_7_1
# Accumulating text: 'וְאֶת' - Current buffer: 'וְאֶת'
# --- Final word text: 'וְאֶת', with ID: word_1_7_1 ---
# Added special marker: ־
# Created <w> element with ID: word_1_7_2
# Accumulating text: 'בֵּ֤ית' - Current buffer: 'בֵּ֤ית'
# --- Final word text: 'בֵּ֤ית', with ID: word_1_7_2 ---
# Created <w> element with ID: word_1_7_3
# Accumulating text: 'יְהוּדָה֙' - Current buffer: 'יְהוּדָה֙'
# --- Final word text: 'יְהוּדָה֙', with ID: word_1_7_3 ---
# Created <w> element with ID: word_1_7_4
# Accumulating text: 'אֲרַחֵ֔ם' - Current buffer: 'אֲרַחֵ֔ם'
# --- Final word text: 'אֲרַחֵ֔ם', with ID: word_1_7_4 ---
# Created <w> element with ID: word_1_7_5
# Accumulating text: 'וְהוֹשַׁעְ' - Current buffer: 'וְהוֹשַׁעְ'
# Appending text before overdot: 'וְהוֹשַׁעְ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'תִּ֖ים' - Current buffer: 'תִּ֖ים'
# Appending remaining text after overdot: 'תִּ֖ים' to <w> element
# --- Final word text: 'וְהוֹשַׁעְ', with ID: word_1_7_5 ---
# Created <w> element with ID: word_1_7_6
# Accumulating text: 'בַּיהוָ֣ה' - Current buffer: 'בַּיהוָ֣ה'
# --- Final word text: 'בַּיהוָ֣ה', with ID: word_1_7_6 ---
# Created <w> element with ID: word_1_7_7
# Accumulating text: 'אֱלֹהֵיהֶ֑ם' - Current buffer: 'אֱלֹהֵיהֶ֑ם'
# --- Final word text: 'אֱלֹהֵיהֶ֑ם', with ID: word_1_7_7 ---
# Created <w> element with ID: word_1_7_8
# Accumulating text: 'וְלֹ֣א' - Current buffer: 'וְלֹ֣א'
# --- Final word text: 'וְלֹ֣א', with ID: word_1_7_8 ---
# Created <w> element with ID: word_1_7_9
# Accumulating text: 'אוֹשִׁיעֵ֗ם' - Current buffer: 'אוֹשִׁיעֵ֗ם'
# --- Final word text: 'אוֹשִׁיעֵ֗ם', with ID: word_1_7_9 ---
# Created <w> element with ID: word_1_7_10
# Accumulating text: 'בְּקֶ֤' - Current buffer: 'בְּקֶ֤'
# Appending text before overdot: 'בְּקֶ֤' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'שֶׁת' - Current buffer: 'שֶׁת'
# Appending remaining text after overdot: 'שֶׁת' to <w> element
# --- Final word text: 'בְּקֶ֤', with ID: word_1_7_10 ---
# Created <w> element with ID: word_1_7_11
# Accumulating text: 'וּבְחֶ֙רֶב֙' - Current buffer: 'וּבְחֶ֙רֶב֙'
# --- Final word text: 'וּבְחֶ֙רֶב֙', with ID: word_1_7_11 ---
# Created <w> element with ID: word_1_7_12
# Accumulating text: 'וּבְמִלְ' - Current buffer: 'וּבְמִלְ'
# Appending text before overdot: 'וּבְמִלְ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'חָמָ֔ה' - Current buffer: 'חָמָ֔ה'
# Appending remaining text after overdot: 'חָמָ֔ה' to <w> element
# --- Final word text: 'וּבְמִלְ', with ID: word_1_7_12 ---
# Created <w> element with ID: word_1_7_13
# Accumulating text: 'בְּסוּסִ֖ים' - Current buffer: 'בְּסוּסִ֖ים'
# --- Final word text: 'בְּסוּסִ֖ים', with ID: word_1_7_13 ---
# Created <w> element with ID: word_1_7_14
# Accumulating text: 'וּבְפָרָשִֽׁים' - Current buffer: 'וּבְפָרָשִֽׁים'
# --- Final word text: 'וּבְפָרָשִֽׁים', with ID: word_1_7_14 ---
# Added special verse end.
# Started new verse 8 in chapter 1
# Created <w> element with ID: word_1_8_1
# Accumulating text: 'וַתִּגְמֹ֖ל' - Current buffer: 'וַתִּגְמֹ֖ל'
# --- Final word text: 'וַתִּגְמֹ֖ל', with ID: word_1_8_1 ---
# Created <w> element with ID: word_1_8_2
# Accumulating text: 'אֶת' - Current buffer: 'אֶת'
# --- Final word text: 'אֶת', with ID: word_1_8_2 ---
# Added special marker: ־
# Created <w> element with ID: word_1_8_3
# Accumulating text: 'לֹ֣א' - Current buffer: 'לֹ֣א'
# --- Final word text: 'לֹ֣א', with ID: word_1_8_3 ---
# Created <w> element with ID: word_1_8_4
# Accumulating text: 'רֻחָ֑מָה' - Current buffer: 'רֻחָ֑מָה'
# --- Final word text: 'רֻחָ֑מָה', with ID: word_1_8_4 ---
# Created <w> element with ID: word_1_8_5
# Accumulating text: 'וַתַּ֖הַר' - Current buffer: 'וַתַּ֖הַר'
# --- Final word text: 'וַתַּ֖הַר', with ID: word_1_8_5 ---
# Created <w> element with ID: word_1_8_6
# Accumulating text: 'וַתֵּ֥לֶד' - Current buffer: 'וַתֵּ֥לֶד'
# --- Final word text: 'וַתֵּ֥לֶד', with ID: word_1_8_6 ---
# Created <w> element with ID: word_1_8_7
# Accumulating text: 'בֵּֽן' - Current buffer: 'בֵּֽן'
# --- Final word text: 'בֵּֽן', with ID: word_1_8_7 ---
# Added standard verse end.
# Started new verse 9 in chapter 1
# Created <w> element with ID: word_1_9_1
# Accumulating text: 'וַיֹּ֕אמֶר' - Current buffer: 'וַיֹּ֕אמֶר'
# --- Final word text: 'וַיֹּ֕אמֶר', with ID: word_1_9_1 ---
# Created <w> element with ID: word_1_9_2
# Accumulating text: 'קְרָ֥א' - Current buffer: 'קְרָ֥א'
# --- Final word text: 'קְרָ֥א', with ID: word_1_9_2 ---
# Created <w> element with ID: word_1_9_3
# Accumulating text: 'שְׁמ֖וֹ' - Current buffer: 'שְׁמ֖וֹ'
# --- Final word text: 'שְׁמ֖וֹ', with ID: word_1_9_3 ---
# Created <w> element with ID: word_1_9_4
# Accumulating text: 'לֹ֣א' - Current buffer: 'לֹ֣א'
# --- Final word text: 'לֹ֣א', with ID: word_1_9_4 ---
# Created <w> element with ID: word_1_9_5
# Accumulating text: 'עַמִּ֑י' - Current buffer: 'עַמִּ֑י'
# --- Final word text: 'עַמִּ֑י', with ID: word_1_9_5 ---
# Created <w> element with ID: word_1_9_6
# Accumulating text: 'כִּ֤י' - Current buffer: 'כִּ֤י'
# --- Final word text: 'כִּ֤י', with ID: word_1_9_6 ---
# Created <w> element with ID: word_1_9_7
# Accumulating text: 'אַתֶּם֙' - Current buffer: 'אַתֶּם֙'
# --- Final word text: 'אַתֶּם֙', with ID: word_1_9_7 ---
# Created <w> element with ID: word_1_9_8
# Accumulating text: 'לֹ֣א' - Current buffer: 'לֹ֣א'
# --- Final word text: 'לֹ֣א', with ID: word_1_9_8 ---
# Created <w> element with ID: word_1_9_9
# Accumulating text: 'עַמִּ֔י' - Current buffer: 'עַמִּ֔י'
# --- Final word text: 'עַמִּ֔י', with ID: word_1_9_9 ---
# Created <w> element with ID: word_1_9_10
# Accumulating text: 'וְאָנֹכִ֖י' - Current buffer: 'וְאָנֹכִ֖י'
# --- Final word text: 'וְאָנֹכִ֖י', with ID: word_1_9_10 ---
# Created <w> element with ID: word_1_9_11
# Accumulating text: 'לֹא' - Current buffer: 'לֹא'
# --- Final word text: 'לֹא', with ID: word_1_9_11 ---
# Added special marker: ־
# Created <w> element with ID: word_1_9_12
# Accumulating text: 'אֶהְיֶ֥ה' - Current buffer: 'אֶהְיֶ֥ה'
# --- Final word text: 'אֶהְיֶ֥ה', with ID: word_1_9_12 ---
# Created <w> element with ID: word_1_9_13
# Accumulating text: 'לָכֶֽם' - Current buffer: 'לָכֶֽם'
# --- Final word text: 'לָכֶֽם', with ID: word_1_9_13 ---
# Added standard verse end.
# Started new verse 10 in chapter 1
# Added special marker: [פ]
# Processing line:
# Processing line: פרק ב
# Closed chapter 1
# Started chapter 2
# Processing line: וְֽ֠הָיָה מִסְפַּ֤ר בְּנֵֽי־יִשְׂרָאֵל֙ כְּח֣וֹל הַיָּ֔ם אֲשֶׁ֥ר לֹֽא־$2יִמַּ֖ד וְלֹ֣א$2 יִסָּפֵ֑ר וְֽ֠הָיָה בִּמְק֞וֹם אֲשֶׁר־יֵאָמֵ֤ר לָהֶם֙ לֹא־עַמִּ֣י אַתֶּ֔ם יֵאָמֵ֥ר לָהֶ֖ם בְּנֵ֥י אֵֽל־חָֽי: וְ֠נִקְבְּצוּ בְּנֵֽי־$2יְהוּדָ֤ה וּבְנֵֽי־$2יִשְׂרָאֵל֙ יַחְדָּ֔ו וְשָׂמ֥וּ לָהֶ֛ם רֹ֥אשׁ אֶחָ֖ד וְעָל֣וּ מִן־הָאָ֑רֶץ כִּ֥י גָד֖וֹל י֥וֹם יִזְרְעֶֽאל$1 אִמְר֥וּ לַאֲחֵיכֶ֖ם עַמִּ֑י וְלַאֲ$3חוֹתֵיכֶ֖ם רֻחָֽמָה$1 רִ֤יבוּ בְאִמְּכֶם֙ רִ֔יבוּ כִּי־הִיא֙ לֹ֣א אִשְׁתִּ֔י וְאָנֹכִ֖י לֹ֣א אִישָׁ֑הּ וְתָסֵ֤$3ר זְנוּנֶ֙יהָ֙ מִפָּנֶ֔יהָ וְנַאֲפוּ$2פֶ֖יהָ מִבֵּ֥ין שָׁדֶֽיהָ: פֶּן־אַפְשִׁיטֶ֣$2נָּה עֲרֻמָּ֔ה וְהִ֨צַּ$3גְתִּ֔יהָ כְּ$2י֖וֹם הִוָּֽ$3לְדָ֑הּ וְשַׂמְתִּ֣יהָ כַמִּ$2דְבָּ֗ר וְשַׁתִּ$2הָ֙ כְּאֶ֣רֶ$2ץ צִיָּ֔ה וַהֲמִ$2תִּ֖יהָ בַּצָּמָֽא$1 וְאֶת־$2בָּנֶ֖יהָ לֹ֣א אֲרַחֵ֑ם כִּֽי־בְנֵ֥י זְנוּנִ֖ים הֵֽמָּה$1 כִּ֤י זָֽנְתָה֙ אִמָּ֔ם הֹבִ֖ישָׁה הוֹרָתָ֑ם$2 כִּ֣י אָמְרָ֗ה אֵלְכָ֞ה אַחֲרֵ֤י מְאַֽהֲבַי֙ נֹתְנֵ֤י לַחְמִי֙ וּמֵימַ֔י צַמְ$2רִ֣י וּפִשְׁתִּ֔י שַׁמְנִ֖י וְשִׁקּ$2וּיָֽי: לָכֵ֛ן הִנְנִי־שָׂ֥$2ךְ אֶת־דַּרְכֵּ֖ךְ בַּסִּ$2ירִ֑ים וְגָֽדַרְתִּי֙ אֶת־גְּדֵרָ֔הּ$2 וּנְתִיבוֹתֶ֖יהָ לֹ֥א תִמְצָֽא: וְרִ$2דְּפָ֤ה אֶת־מְאַהֲבֶ֙יהָ֙ וְלֹא־$2תַשִּׂ֣יג אֹתָ֔ם וּבִקְ$2שָׁ֖תַם וְלֹ֣א $2תִמְצָ֑א וְאָמְרָ֗ה אֵלְכָ֤ה וְאָשׁ֙וּבָה֙ אֶל־אִישִׁ֣י הָרִאשׁ֔וֹן כִּ֣י ט֥וֹב לִ֛י אָ֖ז מֵעָֽתָּה: וְהִיא֙ לֹ֣א יָֽדְעָ֔ה כִּ֤י אָֽנֹכִי֙ $2נָתַ֣תִּי לָ֔הּ הַדָּגָ֖ן וְהַתִּיר֣וֹ$2שׁ וְהַיִּצְהָ֑ר וְכֶ֨סֶף הִרְבֵּ֥יתִי לָ֛הּ וְזָהָ֖ב עָשׂ֥וּ לַבָּֽעַל: לָכֵ֣ן אָשׁ֔וּב וְלָקַחְתִּ֤י דְגָנִי֙ בְּעִתּ֔וֹ וְתִירוֹשִׁ֖י בְּמוֹעֲד֑וֹ וְהִצַּלְתִּי֙ צַמְרִ֣י וּפִ$2שְׁתִּ֔י לְכַסּ֖וֹת אֶת־עֶרְוָתָֽהּ$1 וְעַתָּ֛ה אֲ$3גַלֶּ֥ה אֶת־נַבְ$2לֻתָ֖הּ לְעֵינֵ֣י מְאַהֲבֶ֑יהָ וְאִ֖ישׁ לֹא־יַצִּילֶ֥נָּה מִיָּדִֽי: וְהִשְׁבַּתִּי֙ כָּל־מְ‍$3שׂוֹשָׂ֔הּ חַגָּ֖$2הּ חָדְשָׁ֣$2הּ וְשַׁבַּ$2תָּ֑הּ וְכֹ֖ל מוֹעֲ$2דָֽהּ: וַהֲשִׁמֹּתִ֗י גַּפְנָהּ֙ וּתְאֵ֣נָתָ֔הּ אֲשֶׁ֣ר אָמְרָ֗ה אֶ$2תְנָ֥ה הֵ֙מָּה֙ לִ֔י אֲשֶׁ֥ר נָתְנוּ־לִ֖י מְאַהֲבָ֑י וְשַׂמְתִּ֣ים לְיַ֔עַר וַאֲ‍$3כָלָ֖תַם חַיַּ֥ת הַשָּׂדֶֽה: וּפָקַדְתִּ֣י עָלֶ֗יהָ אֶת־יְמֵ֤י הַבְּעָלִים֙ אֲשֶׁ֣ר תַּקְטִ֣יר לָהֶ֔ם וַתַּ֤עַ$2ד נִזְמָ$2הּ֙ וְחֶ$2לְיָתָ֔הּ וַתֵּ֖לֶךְ אַחֲרֵ֣י מְאַהֲבֶ֑יהָ וְאֹתִ֥י שָׁכְחָ֖ה נְאֻם־יְהוָֽה:     [ס]     לָכֵ֗ן הִנֵּ֤ה אָנֹכִי֙ מְפַ$2תֶּ֔יהָ וְהֹ$2לַכְתִּ֖יהָ הַמִּדְבָּ֑ר וְדִבַּרְתִּ֖י עַל־לִבָּֽהּ: וְנָתַ֨תִּי לָ֤הּ אֶת־כְּרָמֶ֙יהָ֙ מִשָּׁ֔ם וְאֶת־$2עֵ֥מֶק עָכ֖וֹר לְפֶ֣תַח תִּקְוָ֑ה וְעָ֤נְ$2תָה שָּׁ֙מָּה֙ כִּימֵ֣י נְעוּרֶ֔יהָ וּ$2כְי֖וֹם עֲלוֹתָ֥$3הּ מֵאֶרֶץ־מִצְרָֽיִם$1 וְהָיָ֤ה בַיּוֹם־הַהוּא֙ נְאֻם־יְהוָ֔ה תִּקְרְאִ֖י אִישִׁ֑י וְלֹא־תִקְרְאִי־לִ֥י ע֖וֹד בַּעְלִֽי$1 וַהֲסִרֹתִ֛י אֶת־שְׁמ֥וֹת הַבְּעָלִ֖ים מִפִּ֑יהָ וְלֹא־יִזָּכְר֥וּ ע֖וֹד בִּשְׁמָֽם: וְכָרַתִּ֨י לָהֶ֤ם בְּרִית֙ בַּיּ֣וֹם הַה֔וּא עִם־חַיַּ֤ת הַשָּׂדֶה֙ וְעִם־ע֣וֹף הַשָּׁמַ֔יִם וְרֶ֖מֶשׂ הָאֲדָמָ֑ה וְקֶ֨שֶׁת וְחֶ֤רֶב וּמִלְחָמָה֙ אֶשְׁ‍$3בּ֣וֹר מִן־הָאָ֔רֶץ וְהִ$2שְׁכַּבְתִּ֖ים לָבֶֽטַח: וְאֵרַ$2שְׂתִּ֥יךְ לִ֖י לְעוֹלָ֑ם וְאֵרַשְׂתִּ֥יךְ לִי֙ בְּצֶ֣דֶק וּבְמִשְׁפָּ֔ט וּבְחֶ֖סֶד וּֽבְרַחֲמִֽ$2ים$1 וְאֵרַשְׂתִּ֥יךְ לִ֖י בֶּאֱמוּנָ֑ה וְיָדַ֖עַתְּ$2 אֶת־יְהוָֽה:     [פ]     וְהָיָ֣$2ה ׀ בַּיּ֣וֹם הַה֗וּא אֶֽעֱנֶה֙ נְאֻם־יְהוָ֔ה אֶעֱנֶ֖ה אֶת־הַשָּׁמָ֑יִם וְהֵ֖ם יַעֲנ֥וּ אֶת־הָאָֽרֶץ$1 וְהָאָ֣‍$3רֶץ תַּעֲנֶ֔ה אֶת־הַדָּגָ֖ן וְאֶת־הַתִּיר֣וֹשׁ וְאֶת־הַיִּצְהָ֑ר וְהֵ֖ם יַעֲנ֥וּ אֶֽת־יִזְרְעֶֽאל: וּזְרַעְ$2תִּ֤יהָ לִּי֙ בָּאָ֔רֶץ וְרִחַמְתִּ֖י אֶת־לֹ֣א רֻחָ֑מָה וְאָמַרְתִּ֤י לְלֹֽ$2א־עַמִּי֙ עַמִּי־אַ֔תָּה וְה֖וּא יֹאמַ֥ר $2אֱלֹהָֽי$1     [פ]
# Started verse 1 in chapter 2
# Created <w> element with ID: word_2_1_1
# Accumulating text: 'וְֽ֠הָיָה' - Current buffer: 'וְֽ֠הָיָה'
# --- Final word text: 'וְֽ֠הָיָה', with ID: word_2_1_1 ---
# Created <w> element with ID: word_2_1_2
# Accumulating text: 'מִסְפַּ֤ר' - Current buffer: 'מִסְפַּ֤ר'
# --- Final word text: 'מִסְפַּ֤ר', with ID: word_2_1_2 ---
# Created <w> element with ID: word_2_1_3
# Accumulating text: 'בְּנֵֽי' - Current buffer: 'בְּנֵֽי'
# --- Final word text: 'בְּנֵֽי', with ID: word_2_1_3 ---
# Added special marker: ־
# Created <w> element with ID: word_2_1_4
# Accumulating text: 'יִשְׂרָאֵל֙' - Current buffer: 'יִשְׂרָאֵל֙'
# --- Final word text: 'יִשְׂרָאֵל֙', with ID: word_2_1_4 ---
# Created <w> element with ID: word_2_1_5
# Accumulating text: 'כְּח֣וֹל' - Current buffer: 'כְּח֣וֹל'
# --- Final word text: 'כְּח֣וֹל', with ID: word_2_1_5 ---
# Created <w> element with ID: word_2_1_6
# Accumulating text: 'הַיָּ֔ם' - Current buffer: 'הַיָּ֔ם'
# --- Final word text: 'הַיָּ֔ם', with ID: word_2_1_6 ---
# Created <w> element with ID: word_2_1_7
# Accumulating text: 'אֲשֶׁ֥ר' - Current buffer: 'אֲשֶׁ֥ר'
# --- Final word text: 'אֲשֶׁ֥ר', with ID: word_2_1_7 ---
# Created <w> element with ID: word_2_1_8
# Accumulating text: 'לֹֽא' - Current buffer: 'לֹֽא'
# --- Final word text: 'לֹֽא', with ID: word_2_1_8 ---
# Added special marker: ־
# Created <w> element with ID: word_2_1_9
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'יִמַּ֖ד' - Current buffer: 'יִמַּ֖ד'
# --- Final word text: 'יִמַּ֖ד', with ID: word_2_1_9 ---
# Created <w> element with ID: word_2_1_10
# Accumulating text: 'וְלֹ֣א' - Current buffer: 'וְלֹ֣א'
# Appending text before overdot: 'וְלֹ֣א' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: '' - Current buffer: ''
# --- Final word text: 'וְלֹ֣א', with ID: word_2_1_10 ---
# Created <w> element with ID: word_2_1_11
# Accumulating text: 'יִסָּפֵ֑ר' - Current buffer: 'יִסָּפֵ֑ר'
# --- Final word text: 'יִסָּפֵ֑ר', with ID: word_2_1_11 ---
# Created <w> element with ID: word_2_1_12
# Accumulating text: 'וְֽ֠הָיָה' - Current buffer: 'וְֽ֠הָיָה'
# --- Final word text: 'וְֽ֠הָיָה', with ID: word_2_1_12 ---
# Created <w> element with ID: word_2_1_13
# Accumulating text: 'בִּמְק֞וֹם' - Current buffer: 'בִּמְק֞וֹם'
# --- Final word text: 'בִּמְק֞וֹם', with ID: word_2_1_13 ---
# Created <w> element with ID: word_2_1_14
# Accumulating text: 'אֲשֶׁר' - Current buffer: 'אֲשֶׁר'
# --- Final word text: 'אֲשֶׁר', with ID: word_2_1_14 ---
# Added special marker: ־
# Created <w> element with ID: word_2_1_15
# Accumulating text: 'יֵאָמֵ֤ר' - Current buffer: 'יֵאָמֵ֤ר'
# --- Final word text: 'יֵאָמֵ֤ר', with ID: word_2_1_15 ---
# Created <w> element with ID: word_2_1_16
# Accumulating text: 'לָהֶם֙' - Current buffer: 'לָהֶם֙'
# --- Final word text: 'לָהֶם֙', with ID: word_2_1_16 ---
# Created <w> element with ID: word_2_1_17
# Accumulating text: 'לֹא' - Current buffer: 'לֹא'
# --- Final word text: 'לֹא', with ID: word_2_1_17 ---
# Added special marker: ־
# Created <w> element with ID: word_2_1_18
# Accumulating text: 'עַמִּ֣י' - Current buffer: 'עַמִּ֣י'
# --- Final word text: 'עַמִּ֣י', with ID: word_2_1_18 ---
# Created <w> element with ID: word_2_1_19
# Accumulating text: 'אַתֶּ֔ם' - Current buffer: 'אַתֶּ֔ם'
# --- Final word text: 'אַתֶּ֔ם', with ID: word_2_1_19 ---
# Created <w> element with ID: word_2_1_20
# Accumulating text: 'יֵאָמֵ֥ר' - Current buffer: 'יֵאָמֵ֥ר'
# --- Final word text: 'יֵאָמֵ֥ר', with ID: word_2_1_20 ---
# Created <w> element with ID: word_2_1_21
# Accumulating text: 'לָהֶ֖ם' - Current buffer: 'לָהֶ֖ם'
# --- Final word text: 'לָהֶ֖ם', with ID: word_2_1_21 ---
# Created <w> element with ID: word_2_1_22
# Accumulating text: 'בְּנֵ֥י' - Current buffer: 'בְּנֵ֥י'
# --- Final word text: 'בְּנֵ֥י', with ID: word_2_1_22 ---
# Created <w> element with ID: word_2_1_23
# Accumulating text: 'אֵֽל' - Current buffer: 'אֵֽל'
# --- Final word text: 'אֵֽל', with ID: word_2_1_23 ---
# Added special marker: ־
# Created <w> element with ID: word_2_1_24
# Accumulating text: 'חָֽי' - Current buffer: 'חָֽי'
# --- Final word text: 'חָֽי', with ID: word_2_1_24 ---
# Added standard verse end.
# Started new verse 2 in chapter 2
# Created <w> element with ID: word_2_2_1
# Accumulating text: 'וְ֠נִקְבְּצוּ' - Current buffer: 'וְ֠נִקְבְּצוּ'
# --- Final word text: 'וְ֠נִקְבְּצוּ', with ID: word_2_2_1 ---
# Created <w> element with ID: word_2_2_2
# Accumulating text: 'בְּנֵֽי' - Current buffer: 'בְּנֵֽי'
# --- Final word text: 'בְּנֵֽי', with ID: word_2_2_2 ---
# Added special marker: ־
# Created <w> element with ID: word_2_2_3
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'יְהוּדָ֤ה' - Current buffer: 'יְהוּדָ֤ה'
# --- Final word text: 'יְהוּדָ֤ה', with ID: word_2_2_3 ---
# Created <w> element with ID: word_2_2_4
# Accumulating text: 'וּבְנֵֽי' - Current buffer: 'וּבְנֵֽי'
# --- Final word text: 'וּבְנֵֽי', with ID: word_2_2_4 ---
# Added special marker: ־
# Created <w> element with ID: word_2_2_5
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'יִשְׂרָאֵל֙' - Current buffer: 'יִשְׂרָאֵל֙'
# --- Final word text: 'יִשְׂרָאֵל֙', with ID: word_2_2_5 ---
# Created <w> element with ID: word_2_2_6
# Accumulating text: 'יַחְדָּ֔ו' - Current buffer: 'יַחְדָּ֔ו'
# --- Final word text: 'יַחְדָּ֔ו', with ID: word_2_2_6 ---
# Created <w> element with ID: word_2_2_7
# Accumulating text: 'וְשָׂמ֥וּ' - Current buffer: 'וְשָׂמ֥וּ'
# --- Final word text: 'וְשָׂמ֥וּ', with ID: word_2_2_7 ---
# Created <w> element with ID: word_2_2_8
# Accumulating text: 'לָהֶ֛ם' - Current buffer: 'לָהֶ֛ם'
# --- Final word text: 'לָהֶ֛ם', with ID: word_2_2_8 ---
# Created <w> element with ID: word_2_2_9
# Accumulating text: 'רֹ֥אשׁ' - Current buffer: 'רֹ֥אשׁ'
# --- Final word text: 'רֹ֥אשׁ', with ID: word_2_2_9 ---
# Created <w> element with ID: word_2_2_10
# Accumulating text: 'אֶחָ֖ד' - Current buffer: 'אֶחָ֖ד'
# --- Final word text: 'אֶחָ֖ד', with ID: word_2_2_10 ---
# Created <w> element with ID: word_2_2_11
# Accumulating text: 'וְעָל֣וּ' - Current buffer: 'וְעָל֣וּ'
# --- Final word text: 'וְעָל֣וּ', with ID: word_2_2_11 ---
# Created <w> element with ID: word_2_2_12
# Accumulating text: 'מִן' - Current buffer: 'מִן'
# --- Final word text: 'מִן', with ID: word_2_2_12 ---
# Added special marker: ־
# Created <w> element with ID: word_2_2_13
# Accumulating text: 'הָאָ֑רֶץ' - Current buffer: 'הָאָ֑רֶץ'
# --- Final word text: 'הָאָ֑רֶץ', with ID: word_2_2_13 ---
# Created <w> element with ID: word_2_2_14
# Accumulating text: 'כִּ֥י' - Current buffer: 'כִּ֥י'
# --- Final word text: 'כִּ֥י', with ID: word_2_2_14 ---
# Created <w> element with ID: word_2_2_15
# Accumulating text: 'גָד֖וֹל' - Current buffer: 'גָד֖וֹל'
# --- Final word text: 'גָד֖וֹל', with ID: word_2_2_15 ---
# Created <w> element with ID: word_2_2_16
# Accumulating text: 'י֥וֹם' - Current buffer: 'י֥וֹם'
# --- Final word text: 'י֥וֹם', with ID: word_2_2_16 ---
# Created <w> element with ID: word_2_2_17
# Accumulating text: 'יִזְרְעֶֽאל' - Current buffer: 'יִזְרְעֶֽאל'
# --- Final word text: 'יִזְרְעֶֽאל', with ID: word_2_2_17 ---
# Added special verse end.
# Started new verse 3 in chapter 2
# Created <w> element with ID: word_2_3_1
# Accumulating text: 'אִמְר֥וּ' - Current buffer: 'אִמְר֥וּ'
# --- Final word text: 'אִמְר֥וּ', with ID: word_2_3_1 ---
# Created <w> element with ID: word_2_3_2
# Accumulating text: 'לַאֲחֵיכֶ֖ם' - Current buffer: 'לַאֲחֵיכֶ֖ם'
# --- Final word text: 'לַאֲחֵיכֶ֖ם', with ID: word_2_3_2 ---
# Created <w> element with ID: word_2_3_3
# Accumulating text: 'עַמִּ֑י' - Current buffer: 'עַמִּ֑י'
# --- Final word text: 'עַמִּ֑י', with ID: word_2_3_3 ---
# Created <w> element with ID: word_2_3_4
# Accumulating text: 'וְלַאֲ' - Current buffer: 'וְלַאֲ'
# Appending text before overdot: 'וְלַאֲ' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'חוֹתֵיכֶ֖ם' - Current buffer: 'חוֹתֵיכֶ֖ם'
# Appending remaining text after overdot: 'חוֹתֵיכֶ֖ם' to <w> element
# --- Final word text: 'וְלַאֲ', with ID: word_2_3_4 ---
# Created <w> element with ID: word_2_3_5
# Accumulating text: 'רֻחָֽמָה' - Current buffer: 'רֻחָֽמָה'
# --- Final word text: 'רֻחָֽמָה', with ID: word_2_3_5 ---
# Added special verse end.
# Started new verse 4 in chapter 2
# Created <w> element with ID: word_2_4_1
# Accumulating text: 'רִ֤יבוּ' - Current buffer: 'רִ֤יבוּ'
# --- Final word text: 'רִ֤יבוּ', with ID: word_2_4_1 ---
# Created <w> element with ID: word_2_4_2
# Accumulating text: 'בְאִמְּכֶם֙' - Current buffer: 'בְאִמְּכֶם֙'
# --- Final word text: 'בְאִמְּכֶם֙', with ID: word_2_4_2 ---
# Created <w> element with ID: word_2_4_3
# Accumulating text: 'רִ֔יבוּ' - Current buffer: 'רִ֔יבוּ'
# --- Final word text: 'רִ֔יבוּ', with ID: word_2_4_3 ---
# Created <w> element with ID: word_2_4_4
# Accumulating text: 'כִּי' - Current buffer: 'כִּי'
# --- Final word text: 'כִּי', with ID: word_2_4_4 ---
# Added special marker: ־
# Created <w> element with ID: word_2_4_5
# Accumulating text: 'הִיא֙' - Current buffer: 'הִיא֙'
# --- Final word text: 'הִיא֙', with ID: word_2_4_5 ---
# Created <w> element with ID: word_2_4_6
# Accumulating text: 'לֹ֣א' - Current buffer: 'לֹ֣א'
# --- Final word text: 'לֹ֣א', with ID: word_2_4_6 ---
# Created <w> element with ID: word_2_4_7
# Accumulating text: 'אִשְׁתִּ֔י' - Current buffer: 'אִשְׁתִּ֔י'
# --- Final word text: 'אִשְׁתִּ֔י', with ID: word_2_4_7 ---
# Created <w> element with ID: word_2_4_8
# Accumulating text: 'וְאָנֹכִ֖י' - Current buffer: 'וְאָנֹכִ֖י'
# --- Final word text: 'וְאָנֹכִ֖י', with ID: word_2_4_8 ---
# Created <w> element with ID: word_2_4_9
# Accumulating text: 'לֹ֣א' - Current buffer: 'לֹ֣א'
# --- Final word text: 'לֹ֣א', with ID: word_2_4_9 ---
# Created <w> element with ID: word_2_4_10
# Accumulating text: 'אִישָׁ֑הּ' - Current buffer: 'אִישָׁ֑הּ'
# --- Final word text: 'אִישָׁ֑הּ', with ID: word_2_4_10 ---
# Created <w> element with ID: word_2_4_11
# Accumulating text: 'וְתָסֵ֤' - Current buffer: 'וְתָסֵ֤'
# Appending text before overdot: 'וְתָסֵ֤' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'ר' - Current buffer: 'ר'
# Appending remaining text after overdot: 'ר' to <w> element
# --- Final word text: 'וְתָסֵ֤', with ID: word_2_4_11 ---
# Created <w> element with ID: word_2_4_12
# Accumulating text: 'זְנוּנֶ֙יהָ֙' - Current buffer: 'זְנוּנֶ֙יהָ֙'
# --- Final word text: 'זְנוּנֶ֙יהָ֙', with ID: word_2_4_12 ---
# Created <w> element with ID: word_2_4_13
# Accumulating text: 'מִפָּנֶ֔יהָ' - Current buffer: 'מִפָּנֶ֔יהָ'
# --- Final word text: 'מִפָּנֶ֔יהָ', with ID: word_2_4_13 ---
# Created <w> element with ID: word_2_4_14
# Accumulating text: 'וְנַאֲפוּ' - Current buffer: 'וְנַאֲפוּ'
# Appending text before overdot: 'וְנַאֲפוּ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'פֶ֖יהָ' - Current buffer: 'פֶ֖יהָ'
# Appending remaining text after overdot: 'פֶ֖יהָ' to <w> element
# --- Final word text: 'וְנַאֲפוּ', with ID: word_2_4_14 ---
# Created <w> element with ID: word_2_4_15
# Accumulating text: 'מִבֵּ֥ין' - Current buffer: 'מִבֵּ֥ין'
# --- Final word text: 'מִבֵּ֥ין', with ID: word_2_4_15 ---
# Created <w> element with ID: word_2_4_16
# Accumulating text: 'שָׁדֶֽיהָ' - Current buffer: 'שָׁדֶֽיהָ'
# --- Final word text: 'שָׁדֶֽיהָ', with ID: word_2_4_16 ---
# Added standard verse end.
# Started new verse 5 in chapter 2
# Created <w> element with ID: word_2_5_1
# Accumulating text: 'פֶּן' - Current buffer: 'פֶּן'
# --- Final word text: 'פֶּן', with ID: word_2_5_1 ---
# Added special marker: ־
# Created <w> element with ID: word_2_5_2
# Accumulating text: 'אַפְשִׁיטֶ֣' - Current buffer: 'אַפְשִׁיטֶ֣'
# Appending text before overdot: 'אַפְשִׁיטֶ֣' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'נָּה' - Current buffer: 'נָּה'
# Appending remaining text after overdot: 'נָּה' to <w> element
# --- Final word text: 'אַפְשִׁיטֶ֣', with ID: word_2_5_2 ---
# Created <w> element with ID: word_2_5_3
# Accumulating text: 'עֲרֻמָּ֔ה' - Current buffer: 'עֲרֻמָּ֔ה'
# --- Final word text: 'עֲרֻמָּ֔ה', with ID: word_2_5_3 ---
# Created <w> element with ID: word_2_5_4
# Accumulating text: 'וְהִ֨צַּ' - Current buffer: 'וְהִ֨צַּ'
# Appending text before overdot: 'וְהִ֨צַּ' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'גְתִּ֔יהָ' - Current buffer: 'גְתִּ֔יהָ'
# Appending remaining text after overdot: 'גְתִּ֔יהָ' to <w> element
# --- Final word text: 'וְהִ֨צַּ', with ID: word_2_5_4 ---
# Created <w> element with ID: word_2_5_5
# Accumulating text: 'כְּ' - Current buffer: 'כְּ'
# Appending text before overdot: 'כְּ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'י֖וֹם' - Current buffer: 'י֖וֹם'
# Appending remaining text after overdot: 'י֖וֹם' to <w> element
# --- Final word text: 'כְּ', with ID: word_2_5_5 ---
# Created <w> element with ID: word_2_5_6
# Accumulating text: 'הִוָּֽ' - Current buffer: 'הִוָּֽ'
# Appending text before overdot: 'הִוָּֽ' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'לְדָ֑הּ' - Current buffer: 'לְדָ֑הּ'
# Appending remaining text after overdot: 'לְדָ֑הּ' to <w> element
# --- Final word text: 'הִוָּֽ', with ID: word_2_5_6 ---
# Created <w> element with ID: word_2_5_7
# Accumulating text: 'וְשַׂמְתִּ֣יהָ' - Current buffer: 'וְשַׂמְתִּ֣יהָ'
# --- Final word text: 'וְשַׂמְתִּ֣יהָ', with ID: word_2_5_7 ---
# Created <w> element with ID: word_2_5_8
# Accumulating text: 'כַמִּ' - Current buffer: 'כַמִּ'
# Appending text before overdot: 'כַמִּ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'דְבָּ֗ר' - Current buffer: 'דְבָּ֗ר'
# Appending remaining text after overdot: 'דְבָּ֗ר' to <w> element
# --- Final word text: 'כַמִּ', with ID: word_2_5_8 ---
# Created <w> element with ID: word_2_5_9
# Accumulating text: 'וְשַׁתִּ' - Current buffer: 'וְשַׁתִּ'
# Appending text before overdot: 'וְשַׁתִּ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'הָ֙' - Current buffer: 'הָ֙'
# Appending remaining text after overdot: 'הָ֙' to <w> element
# --- Final word text: 'וְשַׁתִּ', with ID: word_2_5_9 ---
# Created <w> element with ID: word_2_5_10
# Accumulating text: 'כְּאֶ֣רֶ' - Current buffer: 'כְּאֶ֣רֶ'
# Appending text before overdot: 'כְּאֶ֣רֶ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ץ' - Current buffer: 'ץ'
# Appending remaining text after overdot: 'ץ' to <w> element
# --- Final word text: 'כְּאֶ֣רֶ', with ID: word_2_5_10 ---
# Created <w> element with ID: word_2_5_11
# Accumulating text: 'צִיָּ֔ה' - Current buffer: 'צִיָּ֔ה'
# --- Final word text: 'צִיָּ֔ה', with ID: word_2_5_11 ---
# Created <w> element with ID: word_2_5_12
# Accumulating text: 'וַהֲמִ' - Current buffer: 'וַהֲמִ'
# Appending text before overdot: 'וַהֲמִ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'תִּ֖יהָ' - Current buffer: 'תִּ֖יהָ'
# Appending remaining text after overdot: 'תִּ֖יהָ' to <w> element
# --- Final word text: 'וַהֲמִ', with ID: word_2_5_12 ---
# Created <w> element with ID: word_2_5_13
# Accumulating text: 'בַּצָּמָֽא' - Current buffer: 'בַּצָּמָֽא'
# --- Final word text: 'בַּצָּמָֽא', with ID: word_2_5_13 ---
# Added special verse end.
# Started new verse 6 in chapter 2
# Created <w> element with ID: word_2_6_1
# Accumulating text: 'וְאֶת' - Current buffer: 'וְאֶת'
# --- Final word text: 'וְאֶת', with ID: word_2_6_1 ---
# Added special marker: ־
# Created <w> element with ID: word_2_6_2
# Accumulating text: '' - Current buffer: ''
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'בָּנֶ֖יהָ' - Current buffer: 'בָּנֶ֖יהָ'
# --- Final word text: 'בָּנֶ֖יהָ', with ID: word_2_6_2 ---
# Created <w> element with ID: word_2_6_3
# Accumulating text: 'לֹ֣א' - Current buffer: 'לֹ֣א'
# --- Final word text: 'לֹ֣א', with ID: word_2_6_3 ---
# Created <w> element with ID: word_2_6_4
# Accumulating text: 'אֲרַחֵ֑ם' - Current buffer: 'אֲרַחֵ֑ם'
# --- Final word text: 'אֲרַחֵ֑ם', with ID: word_2_6_4 ---
# Created <w> element with ID: word_2_6_5
# Accumulating text: 'כִּֽי' - Current buffer: 'כִּֽי'
# --- Final word text: 'כִּֽי', with ID: word_2_6_5 ---
# Added special marker: ־
# Created <w> element with ID: word_2_6_6
# Accumulating text: 'בְנֵ֥י' - Current buffer: 'בְנֵ֥י'
# --- Final word text: 'בְנֵ֥י', with ID: word_2_6_6 ---
# Created <w> element with ID: word_2_6_7
# Accumulating text: 'זְנוּנִ֖ים' - Current buffer: 'זְנוּנִ֖ים'
# --- Final word text: 'זְנוּנִ֖ים', with ID: word_2_6_7 ---
# Created <w> element with ID: word_2_6_8
# Accumulating text: 'הֵֽמָּה' - Current buffer: 'הֵֽמָּה'
# --- Final word text: 'הֵֽמָּה', with ID: word_2_6_8 ---
# Added special verse end.
# Started new verse 7 in chapter 2
# Created <w> element with ID: word_2_7_1
# Accumulating text: 'כִּ֤י' - Current buffer: 'כִּ֤י'
# --- Final word text: 'כִּ֤י', with ID: word_2_7_1 ---
# Created <w> element with ID: word_2_7_2
# Accumulating text: 'זָֽנְתָה֙' - Current buffer: 'זָֽנְתָה֙'
# --- Final word text: 'זָֽנְתָה֙', with ID: word_2_7_2 ---
# Created <w> element with ID: word_2_7_3
# Accumulating text: 'אִמָּ֔ם' - Current buffer: 'אִמָּ֔ם'
# --- Final word text: 'אִמָּ֔ם', with ID: word_2_7_3 ---
# Created <w> element with ID: word_2_7_4
# Accumulating text: 'הֹבִ֖ישָׁה' - Current buffer: 'הֹבִ֖ישָׁה'
# --- Final word text: 'הֹבִ֖ישָׁה', with ID: word_2_7_4 ---
# Created <w> element with ID: word_2_7_5
# Accumulating text: 'הוֹרָתָ֑ם' - Current buffer: 'הוֹרָתָ֑ם'
# Appending text before overdot: 'הוֹרָתָ֑ם' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: '' - Current buffer: ''
# --- Final word text: 'הוֹרָתָ֑ם', with ID: word_2_7_5 ---
# Created <w> element with ID: word_2_7_6
# Accumulating text: 'כִּ֣י' - Current buffer: 'כִּ֣י'
# --- Final word text: 'כִּ֣י', with ID: word_2_7_6 ---
# Created <w> element with ID: word_2_7_7
# Accumulating text: 'אָמְרָ֗ה' - Current buffer: 'אָמְרָ֗ה'
# --- Final word text: 'אָמְרָ֗ה', with ID: word_2_7_7 ---
# Created <w> element with ID: word_2_7_8
# Accumulating text: 'אֵלְכָ֞ה' - Current buffer: 'אֵלְכָ֞ה'
# --- Final word text: 'אֵלְכָ֞ה', with ID: word_2_7_8 ---
# Created <w> element with ID: word_2_7_9
# Accumulating text: 'אַחֲרֵ֤י' - Current buffer: 'אַחֲרֵ֤י'
# --- Final word text: 'אַחֲרֵ֤י', with ID: word_2_7_9 ---
# Created <w> element with ID: word_2_7_10
# Accumulating text: 'מְאַֽהֲבַי֙' - Current buffer: 'מְאַֽהֲבַי֙'
# --- Final word text: 'מְאַֽהֲבַי֙', with ID: word_2_7_10 ---
# Created <w> element with ID: word_2_7_11
# Accumulating text: 'נֹתְנֵ֤י' - Current buffer: 'נֹתְנֵ֤י'
# ...
# Added special marker: ־
# Created <w> element with ID: word_104_4_9
# Accumulating text: 'נֹ֥אמַר' - Current buffer: 'נֹ֥אמַר'
# --- Final word text: 'נֹ֥אמַר', with ID: word_104_4_9 ---
# Created <w> element with ID: word_104_4_10
# Accumulating text: 'ע֛וֹד' - Current buffer: 'ע֛וֹד'
# --- Final word text: 'ע֛וֹד', with ID: word_104_4_10 ---
# Created <w> element with ID: word_104_4_11
# Accumulating text: 'אֱלֹהֵ֖ינוּ' - Current buffer: 'אֱלֹהֵ֖ינוּ'
# --- Final word text: 'אֱלֹהֵ֖ינוּ', with ID: word_104_4_11 ---
# Created <w> element with ID: word_104_4_12
# Accumulating text: 'לְמַעֲשֵׂ֣ה' - Current buffer: 'לְמַעֲשֵׂ֣ה'
# --- Final word text: 'לְמַעֲשֵׂ֣ה', with ID: word_104_4_12 ---
# Created <w> element with ID: word_104_4_13
# Accumulating text: 'יָדֵ֑י‍' - Current buffer: 'יָדֵ֑י‍'
# Appending text before overdot: 'יָדֵ֑י‍' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'נוּ' - Current buffer: 'נוּ'
# Appending remaining text after overdot: 'נוּ' to <w> element
# --- Final word text: 'יָדֵ֑י‍', with ID: word_104_4_13 ---
# Created <w> element with ID: word_104_4_14
# Accumulating text: 'אֲשֶׁר' - Current buffer: 'אֲשֶׁר'
# --- Final word text: 'אֲשֶׁר', with ID: word_104_4_14 ---
# Added special marker: ־
# Created <w> element with ID: word_104_4_15
# Accumulating text: 'בְּךָ֖' - Current buffer: 'בְּךָ֖'
# --- Final word text: 'בְּךָ֖', with ID: word_104_4_15 ---
# Created <w> element with ID: word_104_4_16
# Accumulating text: 'יְרֻחַ֥' - Current buffer: 'יְרֻחַ֥'
# Appending text before overdot: 'יְרֻחַ֥' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ם' - Current buffer: 'ם'
# Appending remaining text after overdot: 'ם' to <w> element
# --- Final word text: 'יְרֻחַ֥', with ID: word_104_4_16 ---
# Created <w> element with ID: word_104_4_17
# Accumulating text: 'יָתֽוֹם' - Current buffer: 'יָתֽוֹם'
# --- Final word text: 'יָתֽוֹם', with ID: word_104_4_17 ---
# Added standard verse end.
# Started new verse 5 in chapter 104
# Created <w> element with ID: word_104_5_1
# Accumulating text: 'אֶרְפָּא֙' - Current buffer: 'אֶרְפָּא֙'
# --- Final word text: 'אֶרְפָּא֙', with ID: word_104_5_1 ---
# Created <w> element with ID: word_104_5_2
# Accumulating text: 'מְשׁ֣וּבָתָ֔ם' - Current buffer: 'מְשׁ֣וּבָתָ֔ם'
# --- Final word text: 'מְשׁ֣וּבָתָ֔ם', with ID: word_104_5_2 ---
# Created <w> element with ID: word_104_5_3
# Accumulating text: 'אֹהֲבֵ֖ם' - Current buffer: 'אֹהֲבֵ֖ם'
# Appending text before overdot: 'אֹהֲבֵ֖ם' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: '' - Current buffer: ''
# --- Final word text: 'אֹהֲבֵ֖ם', with ID: word_104_5_3 ---
# Created <w> element with ID: word_104_5_4
# Accumulating text: 'נְדָבָ֑ה' - Current buffer: 'נְדָבָ֑ה'
# --- Final word text: 'נְדָבָ֑ה', with ID: word_104_5_4 ---
# Created <w> element with ID: word_104_5_5
# Accumulating text: 'כִּ֛י' - Current buffer: 'כִּ֛י'
# --- Final word text: 'כִּ֛י', with ID: word_104_5_5 ---
# Created <w> element with ID: word_104_5_6
# Accumulating text: 'שָׁ֥ב' - Current buffer: 'שָׁ֥ב'
# --- Final word text: 'שָׁ֥ב', with ID: word_104_5_6 ---
# Created <w> element with ID: word_104_5_7
# Accumulating text: 'אַפִּ֖י' - Current buffer: 'אַפִּ֖י'
# --- Final word text: 'אַפִּ֖י', with ID: word_104_5_7 ---
# Created <w> element with ID: word_104_5_8
# Accumulating text: 'מִמֶּֽנּוּ' - Current buffer: 'מִמֶּֽנּוּ'
# --- Final word text: 'מִמֶּֽנּוּ', with ID: word_104_5_8 ---
# Added standard verse end.
# Started new verse 6 in chapter 104
# Created <w> element with ID: word_104_6_1
# Accumulating text: 'אֶהְיֶ֤ה' - Current buffer: 'אֶהְיֶ֤ה'
# --- Final word text: 'אֶהְיֶ֤ה', with ID: word_104_6_1 ---
# Created <w> element with ID: word_104_6_2
# Accumulating text: 'כַטַּ‍' - Current buffer: 'כַטַּ‍'
# Appending text before overdot: 'כַטַּ‍' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'ל֙' - Current buffer: 'ל֙'
# Appending remaining text after overdot: 'ל֙' to <w> element
# --- Final word text: 'כַטַּ‍', with ID: word_104_6_2 ---
# Created <w> element with ID: word_104_6_3
# Accumulating text: 'לְיִשְׂרָאֵ֔ל' - Current buffer: 'לְיִשְׂרָאֵ֔ל'
# --- Final word text: 'לְיִשְׂרָאֵ֔ל', with ID: word_104_6_3 ---
# Created <w> element with ID: word_104_6_4
# Accumulating text: 'יִפְרַ֖ח' - Current buffer: 'יִפְרַ֖ח'
# Appending text before overdot: 'יִפְרַ֖ח' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: '' - Current buffer: ''
# --- Final word text: 'יִפְרַ֖ח', with ID: word_104_6_4 ---
# Created <w> element with ID: word_104_6_5
# Accumulating text: 'כַּשּׁוֹשַׁנָּ֑ה' - Current buffer: 'כַּשּׁוֹשַׁנָּ֑ה'
# --- Final word text: 'כַּשּׁוֹשַׁנָּ֑ה', with ID: word_104_6_5 ---
# Created <w> element with ID: word_104_6_6
# Accumulating text: 'וְיַ֥' - Current buffer: 'וְיַ֥'
# Appending text before overdot: 'וְיַ֥' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ךְ' - Current buffer: 'ךְ'
# Appending remaining text after overdot: 'ךְ' to <w> element
# --- Final word text: 'וְיַ֥', with ID: word_104_6_6 ---
# Created <w> element with ID: word_104_6_7
# Accumulating text: 'שָׁרָשָׁ֖יו' - Current buffer: 'שָׁרָשָׁ֖יו'
# --- Final word text: 'שָׁרָשָׁ֖יו', with ID: word_104_6_7 ---
# Created <w> element with ID: word_104_6_8
# Accumulating text: 'כַּלְּבָ' - Current buffer: 'כַּלְּבָ'
# Appending text before overdot: 'כַּלְּבָ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'נֽוֹן' - Current buffer: 'נֽוֹן'
# Appending remaining text after overdot: 'נֽוֹן' to <w> element
# --- Final word text: 'כַּלְּבָ', with ID: word_104_6_8 ---
# Added standard verse end.
# Started new verse 7 in chapter 104
# Created <w> element with ID: word_104_7_1
# Accumulating text: 'יֵֽלְכוּ֙' - Current buffer: 'יֵֽלְכוּ֙'
# --- Final word text: 'יֵֽלְכוּ֙', with ID: word_104_7_1 ---
# Created <w> element with ID: word_104_7_2
# Accumulating text: 'יֹֽנְ‍' - Current buffer: 'יֹֽנְ‍'
# Appending text before overdot: 'יֹֽנְ‍' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'קוֹתָ֔יו' - Current buffer: 'קוֹתָ֔יו'
# Appending remaining text after overdot: 'קוֹתָ֔יו' to <w> element
# --- Final word text: 'יֹֽנְ‍', with ID: word_104_7_2 ---
# Created <w> element with ID: word_104_7_3
# Accumulating text: 'וִיהִ֥י' - Current buffer: 'וִיהִ֥י'
# --- Final word text: 'וִיהִ֥י', with ID: word_104_7_3 ---
# Created <w> element with ID: word_104_7_4
# Accumulating text: 'כַזַּ֖יִת' - Current buffer: 'כַזַּ֖יִת'
# --- Final word text: 'כַזַּ֖יִת', with ID: word_104_7_4 ---
# Created <w> element with ID: word_104_7_5
# Accumulating text: 'ה' - Current buffer: 'ה'
# Appending text before overdot: 'ה' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'וֹד֑וֹ' - Current buffer: 'וֹד֑וֹ'
# Appending remaining text after overdot: 'וֹד֑וֹ' to <w> element
# --- Final word text: 'ה', with ID: word_104_7_5 ---
# Created <w> element with ID: word_104_7_6
# Accumulating text: 'וְרֵ֥יחַֽ' - Current buffer: 'וְרֵ֥יחַֽ'
# --- Final word text: 'וְרֵ֥יחַֽ', with ID: word_104_7_6 ---
# Created <w> element with ID: word_104_7_7
# Accumulating text: 'ל֖וֹ' - Current buffer: 'ל֖וֹ'
# --- Final word text: 'ל֖וֹ', with ID: word_104_7_7 ---
# Created <w> element with ID: word_104_7_8
# Accumulating text: 'כַּלְּבָנֽוֹן' - Current buffer: 'כַּלְּבָנֽוֹן'
# --- Final word text: 'כַּלְּבָנֽוֹן', with ID: word_104_7_8 ---
# Added special verse end.
# Started new verse 8 in chapter 104
# Created <w> element with ID: word_104_8_1
# Accumulating text: 'יָשֻׁ֙בוּ֙' - Current buffer: 'יָשֻׁ֙בוּ֙'
# --- Final word text: 'יָשֻׁ֙בוּ֙', with ID: word_104_8_1 ---
# Created <w> element with ID: word_104_8_2
# Accumulating text: 'יֹשְׁבֵ֣י' - Current buffer: 'יֹשְׁבֵ֣י'
# --- Final word text: 'יֹשְׁבֵ֣י', with ID: word_104_8_2 ---
# Created <w> element with ID: word_104_8_3
# Accumulating text: 'בְצִלּ֔וֹ' - Current buffer: 'בְצִלּ֔וֹ'
# --- Final word text: 'בְצִלּ֔וֹ', with ID: word_104_8_3 ---
# Created <w> element with ID: word_104_8_4
# Accumulating text: 'יְחַ' - Current buffer: 'יְחַ'
# Appending text before overdot: 'יְחַ' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'יּ֥וּ' - Current buffer: 'יּ֥וּ'
# Appending remaining text after overdot: 'יּ֥וּ' to <w> element
# --- Final word text: 'יְחַ', with ID: word_104_8_4 ---
# Created <w> element with ID: word_104_8_5
# Accumulating text: 'דָגָ֖ן' - Current buffer: 'דָגָ֖ן'
# --- Final word text: 'דָגָ֖ן', with ID: word_104_8_5 ---
# Created <w> element with ID: word_104_8_6
# Accumulating text: 'וְיִפְרְח֣וּ' - Current buffer: 'וְיִפְרְח֣וּ'
# --- Final word text: 'וְיִפְרְח֣וּ', with ID: word_104_8_6 ---
# Created <w> element with ID: word_104_8_7
# Accumulating text: 'כַגָּ֑פֶן' - Current buffer: 'כַגָּ֑פֶן'
# --- Final word text: 'כַגָּ֑פֶן', with ID: word_104_8_7 ---
# Created <w> element with ID: word_104_8_8
# Accumulating text: 'זִכְר֖וֹ' - Current buffer: 'זִכְר֖וֹ'
# --- Final word text: 'זִכְר֖וֹ', with ID: word_104_8_8 ---
# Created <w> element with ID: word_104_8_9
# Accumulating text: 'כְּיֵ֥ין' - Current buffer: 'כְּיֵ֥ין'
# --- Final word text: 'כְּיֵ֥ין', with ID: word_104_8_9 ---
# Created <w> element with ID: word_104_8_10
# Accumulating text: 'לְבָנֽוֹן' - Current buffer: 'לְבָנֽוֹן'
# --- Final word text: 'לְבָנֽוֹן', with ID: word_104_8_10 ---
# Added standard verse end.
# Started new verse 9 in chapter 104
# Created <w> element with ID: word_104_9_1
# Accumulating text: 'אֶפְרַ֕יִם' - Current buffer: 'אֶפְרַ֕יִם'
# --- Final word text: 'אֶפְרַ֕יִם', with ID: word_104_9_1 ---
# Created <w> element with ID: word_104_9_2
# Accumulating text: 'מַה' - Current buffer: 'מַה'
# --- Final word text: 'מַה', with ID: word_104_9_2 ---
# Added special marker: ־
# Created <w> element with ID: word_104_9_3
# Accumulating text: 'לִּ֥י' - Current buffer: 'לִּ֥י'
# --- Final word text: 'לִּ֥י', with ID: word_104_9_3 ---
# Created <w> element with ID: word_104_9_4
# Accumulating text: 'ע֖וֹד' - Current buffer: 'ע֖וֹד'
# --- Final word text: 'ע֖וֹד', with ID: word_104_9_4 ---
# Created <w> element with ID: word_104_9_5
# Accumulating text: 'לָעֲצַבִּ֑ים' - Current buffer: 'לָעֲצַבִּ֑ים'
# --- Final word text: 'לָעֲצַבִּ֑ים', with ID: word_104_9_5 ---
# Created <w> element with ID: word_104_9_6
# Accumulating text: 'אֲנִ֧י' - Current buffer: 'אֲנִ֧י'
# --- Final word text: 'אֲנִ֧י', with ID: word_104_9_6 ---
# Created <w> element with ID: word_104_9_7
# Accumulating text: 'עָנִ֣יתִי' - Current buffer: 'עָנִ֣יתִי'
# --- Final word text: 'עָנִ֣יתִי', with ID: word_104_9_7 ---
# Created <w> element with ID: word_104_9_8
# Accumulating text: 'וַאֲשׁ' - Current buffer: 'וַאֲשׁ'
# Appending text before overdot: 'וַאֲשׁ' to <w> element
# Overdot encountered: $3 - Added overdot type 3 inside <w> element
# Accumulating text: 'וּרֶ֗נּוּ' - Current buffer: 'וּרֶ֗נּוּ'
# Appending remaining text after overdot: 'וּרֶ֗נּוּ' to <w> element
# --- Final word text: 'וַאֲשׁ', with ID: word_104_9_8 ---
# Created <w> element with ID: word_104_9_9
# Accumulating text: 'אֲנִי֙' - Current buffer: 'אֲנִי֙'
# --- Final word text: 'אֲנִי֙', with ID: word_104_9_9 ---
# Created <w> element with ID: word_104_9_10
# Accumulating text: 'כִּבְר֣' - Current buffer: 'כִּבְר֣'
# Appending text before overdot: 'כִּבְר֣' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'וֹשׁ' - Current buffer: 'וֹשׁ'
# Appending remaining text after overdot: 'וֹשׁ' to <w> element
# --- Final word text: 'כִּבְר֣', with ID: word_104_9_10 ---
# Created <w> element with ID: word_104_9_11
# Accumulating text: 'רַעֲנָ֔ן' - Current buffer: 'רַעֲנָ֔ן'
# --- Final word text: 'רַעֲנָ֔ן', with ID: word_104_9_11 ---
# Created <w> element with ID: word_104_9_12
# Accumulating text: 'מִמֶּ֖נִּי' - Current buffer: 'מִמֶּ֖נִּי'
# --- Final word text: 'מִמֶּ֖נִּי', with ID: word_104_9_12 ---
# Created <w> element with ID: word_104_9_13
# Accumulating text: 'פֶּרְ' - Current buffer: 'פֶּרְ'
# Appending text before overdot: 'פֶּרְ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'יְךָ֥' - Current buffer: 'יְךָ֥'
# Appending remaining text after overdot: 'יְךָ֥' to <w> element
# --- Final word text: 'פֶּרְ', with ID: word_104_9_13 ---
# Created <w> element with ID: word_104_9_14
# Accumulating text: 'נִמְצָֽא' - Current buffer: 'נִמְצָֽא'
# --- Final word text: 'נִמְצָֽא', with ID: word_104_9_14 ---
# Added special verse end.
# Started new verse 10 in chapter 104
# Created <w> element with ID: word_104_10_1
# Accumulating text: 'מִ֤י' - Current buffer: 'מִ֤י'
# --- Final word text: 'מִ֤י', with ID: word_104_10_1 ---
# Created <w> element with ID: word_104_10_2
# Accumulating text: 'חָכָם֙' - Current buffer: 'חָכָם֙'
# --- Final word text: 'חָכָם֙', with ID: word_104_10_2 ---
# Created <w> element with ID: word_104_10_3
# Accumulating text: 'וְיָ֣בֵֽ' - Current buffer: 'וְיָ֣בֵֽ'
# Appending text before overdot: 'וְיָ֣בֵֽ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ן' - Current buffer: 'ן'
# Appending remaining text after overdot: 'ן' to <w> element
# --- Final word text: 'וְיָ֣בֵֽ', with ID: word_104_10_3 ---
# Created <w> element with ID: word_104_10_4
# Accumulating text: 'אֵ֔לֶּה' - Current buffer: 'אֵ֔לֶּה'
# --- Final word text: 'אֵ֔לֶּה', with ID: word_104_10_4 ---
# Created <w> element with ID: word_104_10_5
# Accumulating text: 'נָב֖וֹן' - Current buffer: 'נָב֖וֹן'
# --- Final word text: 'נָב֖וֹן', with ID: word_104_10_5 ---
# Created <w> element with ID: word_104_10_6
# Accumulating text: 'וְיֵדָעֵ֑' - Current buffer: 'וְיֵדָעֵ֑'
# Appending text before overdot: 'וְיֵדָעֵ֑' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ם' - Current buffer: 'ם'
# Appending remaining text after overdot: 'ם' to <w> element
# --- Final word text: 'וְיֵדָעֵ֑', with ID: word_104_10_6 ---
# Created <w> element with ID: word_104_10_7
# Accumulating text: 'כִּֽי' - Current buffer: 'כִּֽי'
# --- Final word text: 'כִּֽי', with ID: word_104_10_7 ---
# Added special marker: ־
# Created <w> element with ID: word_104_10_8
# Accumulating text: 'יְשָׁרִ֞ים' - Current buffer: 'יְשָׁרִ֞ים'
# --- Final word text: 'יְשָׁרִ֞ים', with ID: word_104_10_8 ---
# Created <w> element with ID: word_104_10_9
# Accumulating text: 'דַּרְכֵ֣י' - Current buffer: 'דַּרְכֵ֣י'
# --- Final word text: 'דַּרְכֵ֣י', with ID: word_104_10_9 ---
# Created <w> element with ID: word_104_10_10
# Accumulating text: 'יְהוָ֗ה' - Current buffer: 'יְהוָ֗ה'
# --- Final word text: 'יְהוָ֗ה', with ID: word_104_10_10 ---
# Created <w> element with ID: word_104_10_11
# Accumulating text: 'וְצַדִּקִ' - Current buffer: 'וְצַדִּקִ'
# Appending text before overdot: 'וְצַדִּקִ' to <w> element
# Overdot encountered: $2 - Added overdot type 2 inside <w> element
# Accumulating text: 'ים֙' - Current buffer: 'ים֙'
# Appending remaining text after overdot: 'ים֙' to <w> element
# --- Final word text: 'וְצַדִּקִ', with ID: word_104_10_11 ---
# Created <w> element with ID: word_104_10_12
# Accumulating text: 'יֵ֣לְכוּ' - Current buffer: 'יֵ֣לְכוּ'
# --- Final word text: 'יֵ֣לְכוּ', with ID: word_104_10_12 ---
# Created <w> element with ID: word_104_10_13
# Accumulating text: 'בָ֔ם' - Current buffer: 'בָ֔ם'
# Appending text before overdot: 'בָ֔ם' to <w> element
# Overdot encountered: $5 - Added overdot type 5 inside <w> element
# Accumulating text: '' - Current buffer: ''
# --- Final word text: 'בָ֔ם', with ID: word_104_10_13 ---
# Created <w> element with ID: word_104_10_14
# Accumulating text: 'וּפֹשְׁעִ֖ים' - Current buffer: 'וּפֹשְׁעִ֖ים'
# --- Final word text: 'וּפֹשְׁעִ֖ים', with ID: word_104_10_14 ---
# Created <w> element with ID: word_104_10_15
# Accumulating text: 'יִכָּ֥שְׁלוּ' - Current buffer: 'יִכָּ֥שְׁלוּ'
# --- Final word text: 'יִכָּ֥שְׁלוּ', with ID: word_104_10_15 ---
# Created <w> element with ID: word_104_10_16
# Accumulating text: 'בָֽם' - Current buffer: 'בָֽם'
# --- Final word text: 'בָֽם', with ID: word_104_10_16 ---
# Added standard verse end.
# Started new verse 11 in chapter 104
# Closed chapter 104
# <ipython-input-8-18d256e25d12>:32: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   if current_chapter:
